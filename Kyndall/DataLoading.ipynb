# %%
# checking to see what the version of pandas i have for petpy
# !pip install petpy
# import pandas as pd
# pd.__version__

# %%
# upgrades to the lastest version of pandas
# !pip install -U pandas --user

# %%
# pd.__version__

# %%
import json
import requests
import pandas as pd
import petpy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import json
# ----> 2 import requests
#       3 import pandas as pd
#       4 import petpy
#
# ModuleNotFoundError: No module named 'requests'

# %%
key ="cKesBThlyw3n6lxFW4AXbsntBRK0CLEbAC5yzv6m4kZjjUYrp7"
secret ="Kbmyyp9Tkd3pWPT4NRorK5m7RrU7QOe1CWkGpHeA"
url = "https://api.petfinder.com/v2/oauth2/token"

# %%
# gets the access token using credentials
def get_access_token(url, client_id, client_secret):
    response = requests.post(
        url,
        data={"grant_type": "client_credentials"},
        auth=(key, secret),
    )
    return response.json()["access_token"]



token = get_access_token(url,key,secret)
get_access_token(url,key,secret)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..oIkEIkoCok-Pwdnexp8H54Fx1I0-tOwpFmPH8elErdNSF5tv87MiU4_Mfun0jdg1pDnlB0Jg84ZvYHZ5jOl_qq3rFakKwZ4-h7atSKSW9PxADKnlfCDLRlvhUt07uo0NoF4W0uH0FIvk_RR_eT9KZ84xfJJFWpAsc2hmq0ZmLxOO1Fsihz1IblpyNyOQI74VdrxCYmVdR0nUXx49YVx92OwscNjh76kVUbjMjXxzOo5yReg2gidv83oqsRSfWOIgLV82iBKjE6H5if0jYyHvr8QFqCC2gsRNhgOkCDxTZ5Mdp2ShreQDN67v8tR8146kST5q6j8jnpduUAwCk8ntiw'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }

param = {
   "page": 1,
    "limit": 100
    #these are not indented, so no problem there.
    }#close param

response = requests.get('https://api.petfinder.com/v2/animals', headers=headers, 
        params=param)
response = response.json()
response
# Out:
# {'animals': [{'id': 59397126,
#    'organization_id': 'OK471',
#    'url': 'https://www.petfinder.com/cat/schroeder-59397126/ok/noble/heartprints-animal-rescue-ok471/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Buff / Tan / Fawn',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': ['Friendly', 'Affectionate', 'Playful', 'Curious', 'Funny'],
#    'name': 'Schroeder',
#    'description': 'Precious 10 week old kitten.  He has age appropriate vaccinations.  Sweet and bouncy with bright eyes and full of life....',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/1/?bust=1673313185&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/1/?bust=1673313185&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/1/?bust=1673313185&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/1/?bust=1673313185'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/3/?bust=1673313186&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/3/?bust=1673313186&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/3/?bust=1673313186&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/3/?bust=1673313186'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/4/?bust=1673313187&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/4/?bust=1673313187&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/4/?bust=1673313187&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/4/?bust=1673313187'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/5/?bust=1673313188&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/5/?bust=1673313188&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/5/?bust=1673313188&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/5/?bust=1673313188'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/6/?bust=1673313188&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/6/?bust=1673313188&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/6/?bust=1673313188&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/6/?bust=1673313188'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397126/2/?bust=1673313186'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T01:13:10+0000',
#    'published_at': '2023-01-10T01:13:09+0000',
#    'distance': None,
#    'contact': {'email': 'heartprintsanimalrescue@gmail.com',
#     'phone': '(405) 514-5353',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Noble',
#      'state': 'OK',
#      'postcode': '73068',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59

#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397016/1/?bust=1673312107'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:21+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397016'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396985,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/julia-59396985/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': [],
#    'name': 'Julia',
#    'description': 'Buff and white social kitten - Julia with mom Jazzy and siblings Jillian, Julian were rescued from an overcrowded kill...',
#    'organization_animal_id': '18931277',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396985'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396986,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/tucker-59396986/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Tabby',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Tucker',
#    'description': 'Super outgoing kitten - Tucker and his mom and siblings were rescued from a crowded shelter that euthanizes for space',
#    'organization_animal_id': '18931281',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396986'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396987,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/madison-59396987/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Tabby',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Madison',
#    'description': 'beautiful brown and white tabby kitten - I was rescused with my siblings from a crowded kill shelter',
#    'organization_animal_id': '18931298',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396987'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396988,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/ernie-59396988/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Medium Hair',
#     'secondary': 'Tabby',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Ernie',
#    'description': 'Energetic boy looking for a home - Ernie and sibling Eddie were rescued from a kill shelter',
#    'organization_animal_id': '18931300',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396988'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396990,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/opal-59396990/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Opal',
#    'description': 'Opal is a super sweet kitten - Opal and her mom and siblngs were rescued from a crowded shelter that...',
#    'organization_animal_id': '18931283',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396990'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396991,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/pudgely-59396991/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Dilute Calico',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Pudgely',
#    'description': 'sweet petite kitten - I was rescued with my siblings from an overcrowded kill shelter',
#    'organization_animal_id': '18931286',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396991'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396992,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/liam-59396992/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Liam',
#    'description': 'Totally adorable young bachelor - I was rescued from a kill shelter',
#    'organization_animal_id': '18931296',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396992'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}},
#   {'id': 59396993,
#    'organization_id': 'KY382',
#    'url': 'https://www.petfinder.com/cat/max-59396993/ky/louisville/kentucky-pets-alive-ky382/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': 'Tuxedo',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Max',
#    'description': 'Max and his sister were rescued from a overcrowded county shelter.',
#    'organization_animal_id': '18931268',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:44:20+0000',
#    'published_at': '2023-01-10T00:44:19+0000',
#    'distance': None,
#    'contact': {'email': 'kentuckypetsalive@gmail.com',
#     'phone': '(502) 777-2968',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40299',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396993'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky382'}}}],
#  'pagination': {'count_per_page': 100,
#   'total_count': 252403,
#   'current_page': 1,
#   'total_pages': 2525,
#   '_links': {'next': {'href': '/v2/animals?limit=100&page=2'}}}}

# %%
response.keys()
# Out:
# dict_keys(['animals', 'pagination'])

# %%
df = pd.DataFrame(response['animals'])
df.head()
# Out:
#          id organization_id  \
# 0  59397126           OK471
# 1  59397125          FL1220
# 2  59397124           WI523
# 3  59397123          TX1660
# 4  59397122           IN487
#
#                                                  url type species  \
# 0  https://www.petfinder.com/cat/schroeder-593971...  Cat     Cat
# 1  https://www.petfinder.com/cat/kai-59397125/fl/...  Cat     Cat
# 2  https://www.petfinder.com/dog/kent-59397124/wi...  Dog     Dog
# 3  https://www.petfinder.com/dog/maggie-jane-5939...  Dog     Dog
# 4  https://www.petfinder.com/cat/kelly-59397122/i...  Cat     Cat
#
#                                               breeds  \
# 0  {'primary': 'Domestic Short Hair', 'secondary'...
# 1  {'primary': 'Domestic Short Hair', 'secondary'...
# 2  {'primary': 'German Shepherd Dog', 'secondary'...
# 3  {'primary': 'German Shepherd Dog', 'secondary'...
# 4  {'primary': 'Domestic Short Hair', 'secondary'...
#
#                                               colors    age  gender    size  \
# 0  {'primary': 'Buff / Tan / Fawn', 'secondary': ...   Baby    Male   Small
# 1  {'primary': 'Orange & White', 'secondary': Non...  Young    Male  Medium
# 2  {'primary': 'Black', 'secondary': None, 'terti...   Baby    Male   Large
# 3  {'primary': None, 'secondary': None, 'tertiary...  Young  Female   Large
# 4  {'primary': 'Torbie', 'secondary': None, 'tert...  Young  Female   Small
#
#    ... organization_animal_id  \
# 0  ...                   None
# 1  ...                   None
# 2  ...                   None
# 3  ...                   None
# 4  ...                   None
#
#                                               photos  \
# 0  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 1  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 2  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 3  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 4  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#                                primary_photo_cropped videos     status  \
# 0  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 1  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 2  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 3  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 4  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
#
#           status_changed_at              published_at distance  \
# 0  2023-01-10T01:13:10+0000  2023-01-10T01:13:09+0000     None
# 1  2023-01-10T01:12:09+0000  2023-01-10T01:12:08+0000     None
# 2  2023-01-10T01:11:06+0000  2023-01-10T01:11:05+0000     None
# 3  2023-01-10T01:10:01+0000  2023-01-10T01:10:00+0000     None
# 4  2023-01-10T01:09:53+0000  2023-01-10T01:09:52+0000     None
#
#                                              contact  \
# 0  {'email': 'heartprintsanimalrescue@gmail.com',...
# 1  {'email': 'whiskersandtailsrescue@hotmail.com'...
# 2  {'email': 'applications@almatailsofhope.com', ...
# 3  {'email': 'Inquire@Apollosupportandrescue.org'...
# 4  {'email': 'robinsnestindypp@gmail.com', 'phone...
#
#                                               _links
# 0  {'self': {'href': '/v2/animals/59397126'}, 'ty...
# 1  {'self': {'href': '/v2/animals/59397125'}, 'ty...
# 2  {'self': {'href': '/v2/animals/59397124'}, 'ty...
# 3  {'self': {'href': '/v2/animals/59397123'}, 'ty...
# 4  {'self': {'href': '/v2/animals/59397122'}, 'ty...
#
# [5 rows x 26 columns]

# %%
# Breaking out the primary,secondary and mixed (T/F) breeds from the tuple in df column 'breeds'
primary_breeds_dict = {}
primary_breeds = []
secondary_breeds_dict = {}
secondary_breeds = []
mixed_breeds_dict = {}
mixed_breeds = []

for x,y in zip(df['breeds'],df['id']):
#     print(x,y)
    primary_breeds_dict = {'id':y}
    secondary_breeds_dict = {'id':y}
    mixed_breeds_dict = {'id':y}
    if 'primary' in x:
        primary_breeds_dict['primary'] =x['primary']
#         print(primary_breeds_dict)
        primary_breeds.append(primary_breeds_dict)
    if 'secondary' in x:
        secondary_breeds_dict['secondary'] =x['secondary']
        secondary_breeds.append(secondary_breeds_dict) 
    if 'mixed' in x:
        mixed_breeds_dict['mixed'] =x['mixed']
        mixed_breeds.append(mixed_breeds_dict) 
# print(breeds)
breed_1_df = pd.DataFrame(primary_breeds)
breed_2_df = pd.DataFrame(secondary_breeds)
breed_3_df = pd.DataFrame(mixed_breeds)

df_breeds_incorp = df.merge(breed_1_df,on='id').merge(breed_2_df,on='id').merge(breed_3_df,on='id')
# df_breeds_incorp.dtypes
df_breeds_incorp
# Out:
#           id organization_id  \
# 0   59397126           OK471
# 1   59397125          FL1220
# 2   59397124           WI523
# 3   59397123          TX1660
# 4   59397122           IN487
# ..       ...             ...
# 95  59396988           KY382
# 96  59396990           KY382
# 97  59396991           KY382
# 98  59396992           KY382
# 99  59396993           KY382
#
#                                                   url type species  \
# 0   https://www.petfinder.com/cat/schroeder-593971...  Cat     Cat
# 1   https://www.petfinder.com/cat/kai-59397125/fl/...  Cat     Cat
# 2   https://www.petfinder.com/dog/kent-59397124/wi...  Dog     Dog
# 3   https://www.petfinder.com/dog/maggie-jane-5939...  Dog     Dog
# 4   https://www.petfinder.com/cat/kelly-59397122/i...  Cat     Cat
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/cat/ernie-59396988/k...  Cat     Cat
# 96  https://www.petfinder.com/cat/opal-59396990/ky...  Cat     Cat
# 97  https://www.petfinder.com/cat/pudgely-59396991...  Cat     Cat
# 98  https://www.petfinder.com/cat/liam-59396992/ky...  Cat     Cat
# 99  https://www.petfinder.com/cat/max-59396993/ky/...  Cat     Cat
#
#                                                breeds  \
# 0   {'primary': 'Domestic Short Hair', 'secondary'...
# 1   {'primary': 'Domestic Short Hair', 'secondary'...
# 2   {'primary': 'German Shepherd Dog', 'secondary'...
# 3   {'primary': 'German Shepherd Dog', 'secondary'...
# 4   {'primary': 'Domestic Short Hair', 'secondary'...
# ..                                                ...
# 95  {'primary': 'Domestic Medium Hair', 'secondary...
# 96  {'primary': 'Domestic Short Hair', 'secondary'...
# 97  {'primary': 'Dilute Calico', 'secondary': None...
# 98  {'primary': 'Domestic Short Hair', 'secondary'...
# 99  {'primary': 'Domestic Short Hair', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Buff / Tan / Fawn', 'secondary': ...   Baby    Male   Small
# 1   {'primary': 'Orange & White', 'secondary': Non...  Young    Male  Medium
# 2   {'primary': 'Black', 'secondary': None, 'terti...   Baby    Male   Large
# 3   {'primary': None, 'secondary': None, 'tertiary...  Young  Female   Large
# 4   {'primary': 'Torbie', 'secondary': None, 'tert...  Young  Female   Small
# ..                                                ...    ...     ...     ...
# 95  {'primary': None, 'secondary': None, 'tertiary...   Baby    Male  Medium
# 96  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female  Medium
# 97  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female  Medium
# 98  {'primary': None, 'secondary': None, 'tertiary...  Young    Male  Medium
# 99  {'primary': None, 'secondary': None, 'tertiary...   Baby    Male  Medium
#
#     ... videos     status         status_changed_at              published_at  \
# 0   ...     []  adoptable  2023-01-10T01:13:10+0000  2023-01-10T01:13:09+0000
# 1   ...     []  adoptable  2023-01-10T01:12:09+0000  2023-01-10T01:12:08+0000
# 2   ...     []  adoptable  2023-01-10T01:11:06+0000  2023-01-10T01:11:05+0000
# 3   ...     []  adoptable  2023-01-10T01:10:01+0000  2023-01-10T01:10:00+0000
# 4   ...     []  adoptable  2023-01-10T01:09:53+0000  2023-01-10T01:09:52+0000
# ..  ...    ...        ...                       ...                       ...
# 95  ...     []  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 96  ...     []  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 97  ...     []  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 98  ...     []  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 99  ...     []  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
#
#    distance                                            contact  \
# 0      None  {'email': 'heartprintsanimalrescue@gmail.com',...
# 1      None  {'email': 'whiskersandtailsrescue@hotmail.com'...
# 2      None  {'email': 'applications@almatailsofhope.com', ...
# 3      None  {'email': 'Inquire@Apollosupportandrescue.org'...
# 4      None  {'email': 'robinsnestindypp@gmail.com', 'phone...
# ..      ...                                                ...
# 95     None  {'email': 'kentuckypetsalive@gmail.com', 'phon...
# 96     None  {'email': 'kentuckypetsalive@gmail.com', 'phon...
# 97     None  {'email': 'kentuckypetsalive@gmail.com', 'phon...
# 98     None  {'email': 'kentuckypetsalive@gmail.com', 'phon...
# 99     None  {'email': 'kentuckypetsalive@gmail.com', 'phon...
#
#                                                _links               primary  \
# 0   {'self': {'href': '/v2/animals/59397126'}, 'ty...   Domestic Short Hair
# 1   {'self': {'href': '/v2/animals/59397125'}, 'ty...   Domestic Short Hair
# 2   {'self': {'href': '/v2/animals/59397124'}, 'ty...   German Shepherd Dog
# 3   {'self': {'href': '/v2/animals/59397123'}, 'ty...   German Shepherd Dog
# 4   {'self': {'href': '/v2/animals/59397122'}, 'ty...   Domestic Short Hair
# ..                                                ...                   ...
# 95  {'self': {'href': '/v2/animals/59396988'}, 'ty...  Domestic Medium Hair
# 96  {'self': {'href': '/v2/animals/59396990'}, 'ty...   Domestic Short Hair
# 97  {'self': {'href': '/v2/animals/59396991'}, 'ty...         Dilute Calico
# 98  {'self': {'href': '/v2/animals/59396992'}, 'ty...   Domestic Short Hair
# 99  {'self': {'href': '/v2/animals/59396993'}, 'ty...   Domestic Short Hair
#
#    secondary  mixed
# 0       None  False
# 1       None  False
# 2      Husky   True
# 3       None   True
# 4       None  False
# ..       ...    ...
# 95     Tabby   True
# 96      None  False
# 97      None  False
# 98      None  False
# 99    Tuxedo   True
#
# [100 rows x 29 columns]

# %%
# Breaking out the address from the contact info nested dict into a dataframe and joining to breeds
address1_dict = {}

address_df = pd.DataFrame()

for x,y in zip(df['contact'],df['id']):
#     print(x,y)
    address1_dict = {'id':y}
    if 'address' in x:
        address1_dict['address'] =x['address']
#         print(address1_dict)
        test_df = pd.DataFrame(pd.json_normalize(address1_dict))
        address_df = address_df.append(test_df)
address_df.dtypes
address_and_breeds_df = df_breeds_incorp.merge(address_df,left_on='id',right_on='id')

# Most current df with relevant data
address_and_breeds_df
# Out:
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
#           id organization_id  \
# 0   59397126           OK471
# 1   59397125          FL1220
# 2   59397124           WI523
# 3   59397123          TX1660
# 4   59397122           IN487
# ..       ...             ...
# 95  59396988           KY382
# 96  59396990           KY382
# 97  59396991           KY382
# 98  59396992           KY382
# 99  59396993           KY382
#
#                                                   url type species  \
# 0   https://www.petfinder.com/cat/schroeder-593971...  Cat     Cat
# 1   https://www.petfinder.com/cat/kai-59397125/fl/...  Cat     Cat
# 2   https://www.petfinder.com/dog/kent-59397124/wi...  Dog     Dog
# 3   https://www.petfinder.com/dog/maggie-jane-5939...  Dog     Dog
# 4   https://www.petfinder.com/cat/kelly-59397122/i...  Cat     Cat
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/cat/ernie-59396988/k...  Cat     Cat
# 96  https://www.petfinder.com/cat/opal-59396990/ky...  Cat     Cat
# 97  https://www.petfinder.com/cat/pudgely-59396991...  Cat     Cat
# 98  https://www.petfinder.com/cat/liam-59396992/ky...  Cat     Cat
# 99  https://www.petfinder.com/cat/max-59396993/ky/...  Cat     Cat
#
#                                                breeds  \
# 0   {'primary': 'Domestic Short Hair', 'secondary'...
# 1   {'primary': 'Domestic Short Hair', 'secondary'...
# 2   {'primary': 'German Shepherd Dog', 'secondary'...
# 3   {'primary': 'German Shepherd Dog', 'secondary'...
# 4   {'primary': 'Domestic Short Hair', 'secondary'...
# ..                                                ...
# 95  {'primary': 'Domestic Medium Hair', 'secondary...
# 96  {'primary': 'Domestic Short Hair', 'secondary'...
# 97  {'primary': 'Dilute Calico', 'secondary': None...
# 98  {'primary': 'Domestic Short Hair', 'secondary'...
# 99  {'primary': 'Domestic Short Hair', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Buff / Tan / Fawn', 'secondary': ...   Baby    Male   Small
# 1   {'primary': 'Orange & White', 'secondary': Non...  Young    Male  Medium
# 2   {'primary': 'Black', 'secondary': None, 'terti...   Baby    Male   Large
# 3   {'primary': None, 'secondary': None, 'tertiary...  Young  Female   Large
# 4   {'primary': 'Torbie', 'secondary': None, 'tert...  Young  Female   Small
# ..                                                ...    ...     ...     ...
# 95  {'primary': None, 'secondary': None, 'tertiary...   Baby    Male  Medium
# 96  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female  Medium
# 97  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female  Medium
# 98  {'primary': None, 'secondary': None, 'tertiary...  Young    Male  Medium
# 99  {'primary': None, 'secondary': None, 'tertiary...   Baby    Male  Medium
#
#     ...                                             _links  \
# 0   ...  {'self': {'href': '/v2/animals/59397126'}, 'ty...
# 1   ...  {'self': {'href': '/v2/animals/59397125'}, 'ty...
# 2   ...  {'self': {'href': '/v2/animals/59397124'}, 'ty...
# 3   ...  {'self': {'href': '/v2/animals/59397123'}, 'ty...
# 4   ...  {'self': {'href': '/v2/animals/59397122'}, 'ty...
# ..  ...                                                ...
# 95  ...  {'self': {'href': '/v2/animals/59396988'}, 'ty...
# 96  ...  {'self': {'href': '/v2/animals/59396990'}, 'ty...
# 97  ...  {'self': {'href': '/v2/animals/59396991'}, 'ty...
# 98  ...  {'self': {'href': '/v2/animals/59396992'}, 'ty...
# 99  ...  {'self': {'href': '/v2/animals/59396993'}, 'ty...
#
#                  primary secondary  mixed        address.address1  \
# 0    Domestic Short Hair      None  False                    None
# 1    Domestic Short Hair      None  False  13311 SW 88 Terrace #B
# 2    German Shepherd Dog     Husky   True                    None
# 3    German Shepherd Dog      None   True       1170 Dove Hill Rd
# 4    Domestic Short Hair      None  False       7565 US 31 Street
# ..                   ...       ...    ...                     ...
# 95  Domestic Medium Hair     Tabby   True                    None
# 96   Domestic Short Hair      None  False                    None
# 97         Dilute Calico      None  False                    None
# 98   Domestic Short Hair      None  False                    None
# 99   Domestic Short Hair    Tuxedo   True                    None
#
#    address.address2  address.city address.state address.postcode  \
# 0              None         Noble            OK            73068
# 1              None         Miami            FL            33186
# 2              None          Alma            WI            54610
# 3              None        Justin            TX            76247
# 4              None  Indianapolis            IN            46227
# ..              ...           ...           ...              ...
# 95             None    Louisville            KY            40299
# 96             None    Louisville            KY            40299
# 97             None    Louisville            KY            40299
# 98             None    Louisville            KY            40299
# 99             None    Louisville            KY            40299
#
#    address.country
# 0               US
# 1               US
# 2               US
# 3               US
# 4               US
# ..             ...
# 95              US
# 96              US
# 97              US
# 98              US
# 99              US
#
# [100 rows x 35 columns]

# %%
photo_dict = []
photo_df = pd.DataFrame()
test = {}
for x,y in zip(df['photos'],df['id']):
#     print(x,y)
    photo_dict = {'id':y,'photos':x}
    pd.json_normalize(photo_dict)
#     print(photo_dict)
    for i in photo_dict['photos']:
        temp_photo_dict = {'id':y,'small_photo': i['small'],'medium_photo': i['medium'],'large_photo': i['large']}
#         print(test)
        df_photos = pd.DataFrame(pd.json_normalize(temp_photo_dict))
        photo_df = photo_df.append(df_photos)
photo_df
photo_df = photo_df.groupby(['id'],sort=True).max()

# merging the breeds and address df to the photos df - this is the final cleaned df
cleaned_pet_df = address_and_breeds_df.merge(photo_df,how='left',left_on='id',right_on='id')
cleaned_pet_df
# Out:
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_45729/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
#           id organization_id  \
# 0   59397126           OK471
# 1   59397125          FL1220
# 2   59397124           WI523
# 3   59397123          TX1660
# 4   59397122           IN487
# ..       ...             ...
# 95  59396988           KY382
# 96  59396990           KY382
# 97  59396991           KY382
# 98  59396992           KY382
# 99  59396993           KY382
#
#                                                   url type species  \
# 0   https://www.petfinder.com/cat/schroeder-593971...  Cat     Cat
# 1   https://www.petfinder.com/cat/kai-59397125/fl/...  Cat     Cat
# 2   https://www.petfinder.com/dog/kent-59397124/wi...  Dog     Dog
# 3   https://www.petfinder.com/dog/maggie-jane-5939...  Dog     Dog
# 4   https://www.petfinder.com/cat/kelly-59397122/i...  Cat     Cat
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/cat/ernie-59396988/k...  Cat     Cat
# 96  https://www.petfinder.com/cat/opal-59396990/ky...  Cat     Cat
# 97  https://www.petfinder.com/cat/pudgely-59396991...  Cat     Cat
# 98  https://www.petfinder.com/cat/liam-59396992/ky...  Cat     Cat
# 99  https://www.petfinder.com/cat/max-59396993/ky/...  Cat     Cat
#
#                                                breeds  \
# 0   {'primary': 'Domestic Short Hair', 'secondary'...
# 1   {'primary': 'Domestic Short Hair', 'secondary'...
# 2   {'primary': 'German Shepherd Dog', 'secondary'...
# 3   {'primary': 'German Shepherd Dog', 'secondary'...
# 4   {'primary': 'Domestic Short Hair', 'secondary'...
# ..                                                ...
# 95  {'primary': 'Domestic Medium Hair', 'secondary...
# 96  {'primary': 'Domestic Short Hair', 'secondary'...
# 97  {'primary': 'Dilute Calico', 'secondary': None...
# 98  {'primary': 'Domestic Short Hair', 'secondary'...
# 99  {'primary': 'Domestic Short Hair', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Buff / Tan / Fawn', 'secondary': ...   Baby    Male   Small
# 1   {'primary': 'Orange & White', 'secondary': Non...  Young    Male  Medium
# 2   {'primary': 'Black', 'secondary': None, 'terti...   Baby    Male   Large
# 3   {'primary': None, 'secondary': None, 'tertiary...  Young  Female   Large
# 4   {'primary': 'Torbie', 'secondary': None, 'tert...  Young  Female   Small
# ..                                                ...    ...     ...     ...
# 95  {'primary': None, 'secondary': None, 'tertiary...   Baby    Male  Medium
# 96  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female  Medium
# 97  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female  Medium
# 98  {'primary': None, 'secondary': None, 'tertiary...  Young    Male  Medium
# 99  {'primary': None, 'secondary': None, 'tertiary...   Baby    Male  Medium
#
#     ...  mixed        address.address1 address.address2  address.city  \
# 0   ...  False                    None             None         Noble
# 1   ...  False  13311 SW 88 Terrace #B             None         Miami
# 2   ...   True                    None             None          Alma
# 3   ...   True       1170 Dove Hill Rd             None        Justin
# 4   ...  False       7565 US 31 Street             None  Indianapolis
# ..  ...    ...                     ...              ...           ...
# 95  ...   True                    None             None    Louisville
# 96  ...  False                    None             None    Louisville
# 97  ...  False                    None             None    Louisville
# 98  ...  False                    None             None    Louisville
# 99  ...   True                    None             None    Louisville
#
#    address.state address.postcode address.country  \
# 0             OK            73068              US
# 1             FL            33186              US
# 2             WI            54610              US
# 3             TX            76247              US
# 4             IN            46227              US
# ..           ...              ...             ...
# 95            KY            40299              US
# 96            KY            40299              US
# 97            KY            40299              US
# 98            KY            40299              US
# 99            KY            40299              US
#
#                                           small_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                          medium_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                           large_photo
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 38 columns]

# %%
# Cleaning the final DF to only the data we need
cleaned_pet_df.head()
cleaned_pet_df.dtypes
cleaned_pet_df = cleaned_pet_df.rename(columns={'address.address1':'address1',"address.address2":"address2",'address.city':"city",
                              "address.state":'state',"address.postcode":"zip","address.country":"country"
                              })
cleaned_pet_df = cleaned_pet_df[['id','url','age','gender','name','description','status','status_changed_at'
                                ,'published_at','primary','secondary','mixed','address1','address2','city','state',
                                 'zip','country','small_photo','medium_photo','large_photo'
                                ]]
cleaned_pet_df
# Out:
#           id                                                url    age  \
# 0   59397126  https://www.petfinder.com/cat/schroeder-593971...   Baby
# 1   59397125  https://www.petfinder.com/cat/kai-59397125/fl/...  Young
# 2   59397124  https://www.petfinder.com/dog/kent-59397124/wi...   Baby
# 3   59397123  https://www.petfinder.com/dog/maggie-jane-5939...  Young
# 4   59397122  https://www.petfinder.com/cat/kelly-59397122/i...  Young
# ..       ...                                                ...    ...
# 95  59396988  https://www.petfinder.com/cat/ernie-59396988/k...   Baby
# 96  59396990  https://www.petfinder.com/cat/opal-59396990/ky...   Baby
# 97  59396991  https://www.petfinder.com/cat/pudgely-59396991...   Baby
# 98  59396992  https://www.petfinder.com/cat/liam-59396992/ky...  Young
# 99  59396993  https://www.petfinder.com/cat/max-59396993/ky/...   Baby
#
#     gender         name                                        description  \
# 0     Male    Schroeder  Precious 10 week old kitten.  He has age appro...
# 1     Male          Kai  Kai is 5.5 months old as of 1/7/23. \na real h...
# 2     Male         Kent  Meet Kent\n\nGerman Shepherd/Husky Mix (best g...
# 3   Female  Maggie Jane  Maggie Jane is a two year old Shephard. She is...
# 4   Female        Kelly  Kelly is a quiet, gentle soul who is just look...
# ..     ...          ...                                                ...
# 95    Male        Ernie  Energetic boy looking for a home - Ernie and s...
# 96  Female         Opal  Opal is a super sweet kitten - Opal and her mo...
# 97  Female      Pudgely  sweet petite kitten - I was rescued with my si...
# 98    Male         Liam  Totally adorable young bachelor - I was rescue...
# 99    Male          Max  Max and his sister were rescued from a overcro...
#
#        status         status_changed_at              published_at  \
# 0   adoptable  2023-01-10T01:13:10+0000  2023-01-10T01:13:09+0000
# 1   adoptable  2023-01-10T01:12:09+0000  2023-01-10T01:12:08+0000
# 2   adoptable  2023-01-10T01:11:06+0000  2023-01-10T01:11:05+0000
# 3   adoptable  2023-01-10T01:10:01+0000  2023-01-10T01:10:00+0000
# 4   adoptable  2023-01-10T01:09:53+0000  2023-01-10T01:09:52+0000
# ..        ...                       ...                       ...
# 95  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 96  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 97  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 98  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
# 99  adoptable  2023-01-10T00:44:20+0000  2023-01-10T00:44:19+0000
#
#                  primary  ...  mixed                address1 address2  \
# 0    Domestic Short Hair  ...  False                    None     None
# 1    Domestic Short Hair  ...  False  13311 SW 88 Terrace #B     None
# 2    German Shepherd Dog  ...   True                    None     None
# 3    German Shepherd Dog  ...   True       1170 Dove Hill Rd     None
# 4    Domestic Short Hair  ...  False       7565 US 31 Street     None
# ..                   ...  ...    ...                     ...      ...
# 95  Domestic Medium Hair  ...   True                    None     None
# 96   Domestic Short Hair  ...  False                    None     None
# 97         Dilute Calico  ...  False                    None     None
# 98   Domestic Short Hair  ...  False                    None     None
# 99   Domestic Short Hair  ...   True                    None     None
#
#             city state    zip country  \
# 0          Noble    OK  73068      US
# 1          Miami    FL  33186      US
# 2           Alma    WI  54610      US
# 3         Justin    TX  76247      US
# 4   Indianapolis    IN  46227      US
# ..           ...   ...    ...     ...
# 95    Louisville    KY  40299      US
# 96    Louisville    KY  40299      US
# 97    Louisville    KY  40299      US
# 98    Louisville    KY  40299      US
# 99    Louisville    KY  40299      US
#
#                                           small_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                          medium_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                           large_photo
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 21 columns]

# %% [markdown]
# # Establishing a Connection to SQL for Data Organization

# %%
#Establish a connection to SQL: 
from sqlalchemy import create_engine

# Creating connection object
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5433
database_name = 'pets'

# %%
#Create engine connection:
connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'

engine = create_engine(connection_string)

# %%
cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
engine.execute("SELECT name, age, gender, city, state FROM adoptees ORDER BY state ASC").fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     254 """Called by subclasses to create a new ConnectionRecord."""
# --> 256 return _ConnectionRecord(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     660 self.starttime = time.time()
# --> 661 self.dbapi_connection = connection = pool._invoke_creator(self)
#     662 pool.logger.debug("Created new connection %r", connection)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5433 failed: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
#       2 engine.execute("SELECT name, age, gender, primary, city, state FROM adoptees ORDER BY state ASC").fetchall()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:1760, in SQLDatabase.has_table(self, name, schema)
#    1757 def has_table(self, name: str, schema: str | None = None):
#    1758     from sqlalchemy import inspect as sqlalchemy_inspect
# -> 1760     insp = sqlalchemy_inspect(self.connectable)
#    1761     return insp.has_table(name, schema or self.meta.schema)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/inspection.py:64, in inspect(subject, raiseerr)
#      62 if reg is True:
#      63     return subject
# ---> 64 ret = reg(subject)
#      65 if ret is not None:
#      66     break
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:182, in Inspector._engine_insp(bind)
#     180 @inspection._inspects(Engine)
#     181 def _engine_insp(bind):
# --> 182     return Inspector._construct(Inspector._init_engine, bind)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:117, in Inspector._construct(cls, init, bind)
#     114     cls = bind.dialect.inspector
#     116 self = cls.__new__(cls)
# --> 117 init(self, bind)
#     118 return self
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:128, in Inspector._init_engine(self, engine)
#     126 def _init_engine(self, engine):
#     127     self.bind = self.engine = engine
# --> 128     engine.connect().close()
#     129     self._op_context_requires_connect = True
#     130     self.dialect = self.engine.dialect
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3210, in Engine.connect(self, close_with_result)
#    3195 def connect(self, close_with_result=False):
#    3196     """Return a new :class:`_engine.Connection` object.
#    3197
#    3198     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3207
#    3208     """
# -> 3210     return self._connection_cls(self, close_with_result=close_with_result)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3289, in Engine.raw_connection(self, _connection)
#    3267 def raw_connection(self, _connection=None):
#    3268     """Return a "raw" DBAPI connection from the connection pool.
#    3269
#    3270     The returned object is a proxied version of the DBAPI
#    (...)
#    3287
#    3288     """
# -> 3289     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3259, in Engine._wrap_pool_connect(self, fn, connection)
#    3257 except dialect.dbapi.Error as e:
#    3258     if connection is None:
# -> 3259         Connection._handle_dbapi_exception_noconnection(
#    3260             e, dialect, self
#    3261         )
#    3262     else:
#    3263         util.raise_(
#    3264             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3265         )
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2106, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2104     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2105 elif should_wrap:
# -> 2106     util.raise_(
#    2107         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2108     )
#    2109 else:
#    2110     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3254 dialect = self.dialect
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#    3258     if connection is None:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     302 def connect(self):
#     303     """Return a DBAPI connection from the pool.
#     304
#     305     The connection is instrumented such that when its
#    (...)
#     308
#     309     """
# --> 310     return _ConnectionFairy._checkout(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     865 @classmethod
#     866 def _checkout(cls, pool, threadconns=None, fairy=None):
#     867     if not fairy:
# --> 868         fairy = _ConnectionRecord.checkout(pool)
#     870         fairy._pool = pool
#     871         fairy._counter = 0
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#     478         dbapi_connection = rec.get_connection()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     144     except:
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#     148     return self._do_get()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     253 def _create_connection(self):
#     254     """Called by subclasses to create a new ConnectionRecord."""
# --> 256     return _ConnectionRecord(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     369 self.__pool = pool
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     664 except Exception as e:
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#     670     if pool.dispatch.first_connect:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     659 try:
#     660     self.starttime = time.time()
# --> 661     self.dbapi_connection = connection = pool._invoke_creator(self)
#     662     pool.logger.debug("Created new connection %r", connection)
#     663     self.fresh = True
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     588         if connection is not None:
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5433 failed: FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
