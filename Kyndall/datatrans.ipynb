# %%
# upgrades to the lastest version of pandas
# !pip install -U pandas --user

# %%
#petpy module installation
# !pip install petpy

# %%
import numpy as np
import pandas as pd
import requests
import json
import petpy

pd.__version__
# Out:
# '1.5.2'

# %%
key ="uiBXxB3oxqBkmNo4AlNKvNmkbQy2lAgcUjqqd4tQPulwJOkIar"
secret ="7kU71uGX4miMqG8E6FJzSzdoaqalwLsG0bEthoo3"
url = "https://api.petfinder.com/v2/oauth2/token"

# %%
# gets the access token using credentials
def get_access_token(url, client_id, client_secret):
    response = requests.post(
        url,
        data={"grant_type": "client_credentials"},
        auth=(key, secret),
    )
    return response.json()["access_token"]


token = get_access_token(url, key, secret)
get_access_token(url, key , secret)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..Nt77KLdzb0tuUN5igU-2qD0zFtLyf1F_4HLl3XcQ0z4hCEPEsTvA7iSg_Mnramf6w2zNQIm9aXB59qg_NmU9SZPUwoWNs46Up8UhaX7oEAJZhDwh1vPhLC75JmMmiVsoRJot3IZr3BgSj7TBtJ13rL2tjA9HtvR-4PDMCfVxCisrJGEcSyBxUdtW8R9unbAJDA2iGG3nuFMEItQG688rLrY7otTwSzSA9RrnIsksghfNGj3eLhPNiwdowtSp6vkuMuWNGr7ldwY36ZlVDYXzszeV5GBxBjsaJ5c2BrsoWmX2Bhol0r90y5sMYfOi9uUnupNAd5r8tW2q8wZBNmGXqg'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }
param = {
    "page": 1,
    "limit": 100
    #these are not indented, so no problem there.
    }#close param
response = requests.get("https://api.petfinder.com/v2/animals").json()
content = json.dumps(response, indent = 4, sort_keys=True)

content
# Out:
# '{\n    "detail": "Access token invalid or expired",\n    "status": 401,\n    "title": "Unauthorized",\n    "type": "https://httpstatus.es/401"\n}'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }

param = {
    "type": "Dog",
    "gender": "Male",
    'location':'GA'
    #these are not indented, so no problem there.
    }#close param

response = requests.get('https://api.petfinder.com/v2/animals', headers=headers, 
        params=param)
response = response.json()
response
# Out:
# {'animals': [{'id': 59358838,
#    'organization_id': 'GA217',
#    'url': 'https://www.petfinder.com/dog/buddy-59358838/ga/atlanta/fulton-county-animal-services-ga217/?referrer_id=7663c3f9-cceb-4fa5-b168-9b9734fdd0dc',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'BUDDY',
#    'description': None,
#    'organization_animal_id': 'A895612',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59358838/1/?bust=1672968644&width=100',
# ...

# %%
pf = petpy.Petfinder(key=key,secret=secret)

animal_types = pf.animal_types()

for animal in animal_types['types']:
    print(animal['name'])
# Out:
# Dog
# Cat
# Rabbit
# Small & Furry
# Horse
# Bird
# Scales, Fins & Other
# Barnyard

# %%
pf = petpy.Petfinder(key=key,secret=secret)

# %%
response.keys()
# Out:
# dict_keys(['animals', 'pagination'])

# %%
pets = pd.DataFrame(response['animals'])

# %%
pets.head(25)
# Out:
#           id organization_id  \
# 0   59358838           GA217
# 1   59358461           GA261
# 2   59357761           GA914
# 3   59357585           GA423
# 4   59356783           GA217
# 5   59356784           GA217
# 6   59356712           GA247
# 7   59355793           GA299
# 8   59355463           AL469
# 9   59355426           GA423
# 10  59355423           GA423
# 11  59355341           GA217
# 12  59354405           GA423
# 13  59354196           GA357
# 14  59354061           GA217
# 15  59353413           GA217
# 16  59353411           GA217
# 17  59352626           GA247
# 18  59352114           GA247
# 19  59351144           GA232
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/buddy-59358838/g...  Dog     Dog
# 1   https://www.petfinder.com/dog/2023-01-020-5935...  Dog     Dog
# 2   https://www.petfinder.com/dog/chunks-59357761/...  Dog     Dog
# ...

# %%
response.items()
# Out:
# dict_items([('animals', [{'id': 59358838, 'organization_id': 'GA217', 'url': 'https://www.petfinder.com/dog/buddy-59358838/ga/atlanta/fulton-county-animal-services-ga217/?referrer_id=7663c3f9-cceb-4fa5-b168-9b9734fdd0dc', 'type': 'Dog', 'species': 'Dog', 'breeds': {'primary': 'Labrador Retriever', 'secondary': None, 'mixed': False, 'unknown': False}, 'colors': {'primary': None, 'secondary': None, 'tertiary': None}, 'age': 'Adult', 'gender': 'Male', 'size': 'Small', 'coat': None, 'attributes': {'spayed_neutered': True, 'house_trained': False, 'declawed': None, 'special_needs': False, 'shots_current': False}, 'environment': {'children': None, 'dogs': None, 'cats': None}, 'tags': [], 'name': 'BUDDY', 'description': None, 'organization_animal_id': 'A895612', 'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59358838/1/?bust=1672968644&width=100', 'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59358838/1/?bust=1672968644&width=300', 'large': 'https://dl5z
# ...

# %%
pets['breeds'] = pets['breeds'].str.split(';').str.join(',')

print(pets.to_string())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 pets['breeds'] = pets['breeds'].str.split(';').str.join(',')
#       3 print(pets.to_string())
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
type(pets['breeds'])
# Out:
# pandas.core.series.Series
