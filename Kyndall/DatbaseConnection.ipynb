# %%
import pandas as pd

cleaned_pet_df = pd.read_csv('/Users/kyndallbutler/GTECH/project_3_Web_Visualization/data/pet_data_cleaned.csv')
cleaned_pet_df.head()
# Out:
#    Unnamed: 0        id                                                url  \
# 0           0  59310612  https://www.petfinder.com/cat/ray-59310612/mi/...
# 1           1  59310606  https://www.petfinder.com/dog/rum-59310606/ca/...
# 2           2  59310593  https://www.petfinder.com/cat/flappy-59310593/...
# 3           3  59310592  https://www.petfinder.com/dog/kelan-59310592/t...
# 4           4  59310589  https://www.petfinder.com/cat/rosalind-5931058...
#
#      age  gender type species      name  \
# 0   Baby  Female  Cat     Cat       Ray
# 1  Young    Male  Dog     Dog       Rum
# 2   Baby  Female  Cat     Cat    Flappy
# 3  Young    Male  Dog     Dog     Kelan
# 4   Baby  Female  Cat     Cat  Rosalind
#
#                                          description   status  ...  mixed  \
# 0  Siblings Luke, Leia, &amp;amp; Ray were found ...  adopted  ...  False
# 1                                                NaN  adopted  ...  False
# 2  Hiya, I&#039;m sweet little baby Mafalda, I wa...  adopted  ...   True
# 3  Kelan is a Shepherd/Husky Mix. His owner can’t...  adopted  ...  False
# 4  Meet Rosalind!\n\nSpayed female\nDSH\nApprox. ...  adopted  ...  False
#
#                 address1           address2        city  state    zip country  \
# 0      2532 N. Dixie Hwy                NaN      Monroe     MI  48162      US
# 1  115 E. Wetmore Street                NaN     Manteca     CA  95337      US
# 2                    NaN                NaN    New York     NY  10009      US
# 3            PO Box 1014                NaN   Brentwood     TN  37024      US
# 4              PO BOX 62  Pearson Mill Road  New Castle     PA  16103      US
#
#                                          small_photo  \
# 0                                                NaN
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                         medium_photo  \
# 0                                                NaN
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                          large_photo
# 0                                                NaN
# 1  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
# [5 rows x 24 columns]

# %%
sr = cleaned_pet_df['primary']
print(sr)

cleaned_pet_df = cleaned_pet_df.assign(breed = sr)
# Out:
# 0       Domestic Short Hair
# 1        Labrador Retriever
# 2       Domestic Short Hair
# 3       German Shepherd Dog
# 4       Domestic Short Hair
#                ...
# 1295     Domestic Long Hair
# 1296          Tortoiseshell
# 1297                Terrier
# 1298              Chihuahua
# 1299     Labrador Retriever
# Name: primary, Length: 1300, dtype: object

# %%
#Establish a connection to SQL: 
from sqlalchemy import create_engine

# Creating connection object
protocol = 'postgresql'
username = 'postgres'
password = 'postgre'
host = 'localhost'
port = 5433
database_name = 'petfriends'

# %%
#Create engine connection:
connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'

engine = create_engine(connection_string)

# %%
cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
friends = engine.execute("SELECT id, url, species, type, name, age, gender, zip, status, large_photo, medium_photo, city, breed, state FROM adoptees ORDER BY state ASC").fetchall()

# %%
#Creating a new dataframe for adoptable pets:
adoptables = cleaned_pet_df[['id', 'type', 'name', 'age', 'gender', 'city', 'breed', 'city', 'zip', 'large_photo', 
https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    TX     Dog
# 301  78760  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    TX     Dog
# 302  78760  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    TX     Dog
# 303  93292  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    CA     Dog
# 304  71901  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    AR     Dog
# 305  14450                                                NaN    NY     Cat
# 306  48162  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MI     Cat
# 307  48162  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MI     Cat
# 308  71446  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    LA     Dog
# 309  08215  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    NJ     Cat
# 310  55066  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MN     Cat
# 311  95337  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    CA     Dog
# 312  08857  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    NJ     Cat
# 313  97204  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    OR     Dog
# 314  63118  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MO     Cat
# 315  63118  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MO     Cat
# 316  72560  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    AR     Cat
# 317  71901  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    AR     Dog
# 318  48325  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MI     Cat
# 319  51503  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    IA     Cat
# 320  85027  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    AZ     Cat
# 321  48325  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    MI     Cat
# 322  76065  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    TX     Cat
# 323  92067  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    CA     Dog
# 324  34266  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...    FL     Dog
#
#         status                                                url
# 300  adoptable  https://www.petfinder.com/dog/freckles-5931062...
# 301  adoptable  https://www.petfinder.com/dog/jojo-59310627/tx...
# 302  adoptable  https://www.petfinder.com/dog/ollie-59310625/t...
# 303  adoptable  https://www.petfinder.com/dog/brogan-59310620/...
# 304  adoptable  https://www.petfinder.com/dog/buster-59310617/...
# 305  adoptable  https://www.petfinder.com/cat/sashimi-59310614...
# 306  adoptable  https://www.petfinder.com/cat/jet-59310611/mi/...
# 307  adoptable  https://www.petfinder.com/cat/lady-59310610/mi...
# 308  adoptable  https://www.petfinder.com/dog/floppy-in-a-fost...
# 309  adoptable  https://www.petfinder.com/cat/paige-59310608/n...
# 310  adoptable  https://www.petfinder.com/cat/sunshine-5931059...
# 311  adoptable  https://www.petfinder.com/dog/bourbon-59310580...
# 312  adoptable  https://www.petfinder.com/cat/pepper-59310579/...
# 313  adoptable  https://www.petfinder.com/dog/lola-or-59310575...
# 314  adoptable  https://www.petfinder.com/cat/spooky-59310576/...
# 315  adoptable  https://www.petfinder.com/cat/pumpkin-butt-593...
# 316  adoptable  https://www.petfinder.com/cat/lulu-59310570/ar...
# 317  adoptable  https://www.petfinder.com/dog/cooper-59310562/...
# 318  adoptable  https://www.petfinder.com/cat/milky-way-sanche...
# 319  adoptable  https://www.petfinder.com/cat/macho-man-593105...
# 320  adoptable  https://www.petfinder.com/cat/greyson-greylock...
# 321  adoptable  https://www.petfinder.com/cat/midnight-sanchez...
# 322  adoptable  https://www.petfinder.com/cat/hallie-59310547/...
# 323  adoptable  https://www.petfinder.com/dog/eva-59310545/ca/...
# 324  adoptable  https://www.petfinder.com/dog/gizmo-59310543/f...

# %%
avail.describe()
# Out:
#                  id
# count  1.000000e+03
# mean   5.930895e+07
# std    2.281881e+03
# min    5.927557e+07
# 25%    5.930825e+07
# 50%    5.930911e+07
# 75%    5.930989e+07
# max    5.931063e+07

# %%
avail.to_csv('../data/adoptable_pets.csv')
