# %%
# checking to see what the version of pandas i have for petpy
# !pip install petpy
import pandas as pd
pd.__version__
# Out:
# C:\Users\alexc\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)
# '1.3.5'

# %%
# upgrades to the lastest version of pandas
# !pip install -U pandas --user
# Out:
# Requirement already up-to-date: pandas in c:\users\alexc\anaconda3\lib\site-packages (1.3.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in c:\users\alexc\anaconda3\lib\site-packages (from pandas) (1.21.6)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\alexc\anaconda3\lib\site-packages (from pandas) (2.7.5)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in c:\users\alexc\anaconda3\lib\site-packages (from pandas) (2018.7)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\alexc\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
import requests
import json
import petpy

# %%
key ="cKesBThlyw3n6lxFW4AXbsntBRK0CLEbAC5yzv6m4kZjjUYrp7"
secret ="Kbmyyp9Tkd3pWPT4NRorK5m7RrU7QOe1CWkGpHeA"
url = "https://api.petfinder.com/v2/oauth2/token"

# %%
# gets the access token using credentials
def get_access_token(url, client_id, client_secret):
    response = requests.post(
        url,
        data={"grant_type": "client_credentials"},
        auth=(key, secret),
    )
    return response.json()["access_token"]



token = get_access_token(url,key,secret)
get_access_token(url,key,secret)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..itouJMQHO8nXQY0Fujx5kATIL_lJ5oWyjMcJgNbgpcE3gZclDQtgRbjbt0LQD6F02hX1gfYEQOALq9AedzK5x5jFJQ6lgbL_rFrqg6o3FUk3h_gbdcQckIjAue3GOqAhq66JgyxqZN5FhlVy1ItVQogBcs06_fp2KW0upskZFiTagXf5Va0hRk2f0CVs4i_hk8tLO67tfH1NxLxg2cWpbC9S0zRsPjcMhBw1e9OSaHDIamFz3nxUYX0PpRblNw3YWFBpN0CvPi5_rzOwarKNTLZhUyWVLEzyFJe8lIb5tnB2DNU5Z1yzwUUhDcbzrxRjbne_yfO7LPpQbDiOdaWeew'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }

param = {
    "type": "Dog",
    "gender": "Male",
    'location':'GA'
    #these are not indented, so no problem there.
    }#close param

response = requests.get('https://api.petfinder.com/v2/animals', headers=headers, 
        params=param)
response = response.json()
response
# Out:
# {'animals': [{'id': 59334855,
#    'organization_id': 'GA76',
#    'url': 'https://www.petfinder.com/dog/gunther-59334855/ga/winder/pup-and-cat-co-ga76/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Cocker Spaniel',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Gunther',
#    'description': 'Gunther is such a sweet senior boy. He is blind in one eye, almost blind in the other eye and...',
#    'organization_animal_id': '18909163-Gunther122022',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T23:38:38+0000',
#    'published_at': '2023-01-03T23:38:37+0000',
#    'distance': 86.7607,
#    'contact': {'email': 'volunteers@pupandcatco.com',
#     'phone': '(770) 867-1622',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Winder',
#      'state': 'GA',
#      'postcode': '30680',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59334855'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga76'}}},
#   {'id': 59334210,
#    'organization_id': 'GA423',
#    'url': 'https://www.petfinder.com/dog/karlin-59334210/ga/chamblee/dekalb-county-animal-services-ga423/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Karlin',
#    'description': None,
#    'organization_animal_id': '51801513',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334210/1/?bust=1672786238'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T22:40:29+0000',
#    'published_at': '2023-01-03T22:40:27+0000',
#    'distance': 91.1641,
#    'contact': {'email': 'adoption@dekalbanimalservices.com',
#     'phone': '(404) 294-2165',
#     'address': {'address1': '3280 Chamblee Dunwoody Rd',
#      'address2': None,
#      'city': 'Chamblee',
#      'state': 'GA',
#      'postcode': '30341',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59334210'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga423'}}},
#   {'id': 59334209,
#    'organization_id': 'GA423',
#    'url': 'https://www.petfinder.com/dog/kevin-59334209/ga/chamblee/dekalb-county-animal-services-ga423/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Kevin',
#    'description': None,
#    'organization_animal_id': '51799880',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59334209/1/?bust=1672786243'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T22:40:28+0000',
#    'published_at': '2023-01-03T22:40:26+0000',
#    'distance': 91.1641,
#    'contact': {'email': 'adoption@dekalbanimalservices.com',
#     'phone': '(404) 294-2165',
#     'address': {'address1': '3280 Chamblee Dunwoody Rd',
#      'address2': None,
#      'city': 'Chamblee',
#      'state': 'GA',
#      'postcode': '30341',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59334209'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga423'}}},
#   {'id': 59334197,
#    'organization_id': 'GA181',
#    'url': 'https://www.petfinder.com/dog/malcolm-8015-59334197/ga/columbus/paws-humane-ga181/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Brindle', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Malcolm 8015',
#    'description': 'How I Got Here:\n- Columbus Animal Care and Control Center\n\nAcademics:\n- I&amp;#39;m learning to sit!\n\nRecess:\n- Playtime...',
#    'organization_animal_id': 'PHCV-A-15494',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T22:40:03+0000',
#    'published_at': '2023-01-03T22:40:02+0000',
#    'distance': 83.5197,
#    'contact': {'email': 'adoptions@pawshumane.org',
#     'phone': '(706) 565-0035',
#     'address': {'address1': '4900 Milgen Rd.',
#      'address2': None,
#      'city': 'Columbus',
#      'state': 'GA',
#      'postcode': '31908',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59334197'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga181'}}},
#   {'id': 59333198,
#    'organization_id': 'GA247',
#    'url': 'https://www.petfinder.com/dog/14961-59333198/ga/covington/newton-county-animal-control-ga247/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '14961',
#    'description': 'Primary Color: Brown Secondary Color: White',
#    'organization_animal_id': '14961',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59333198/1/?bust=1672782572'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T21:39:27+0000',
#    'published_at': '2023-01-03T21:39:25+0000',
#    'distance': 59.8791,
#    'contact': {'email': 'newtonac@co.newton.ga.us',
#     'phone': '(770) 786-9514',
#     'address': {'address1': '210 Lower River Rd.',
#      'address2': None,
#      'city': 'Covington',
#      'state': 'GA',
#      'postcode': '30016',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59333198'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga247'}}},
#   {'id': 59332661,
#    'organization_id': 'GA423',
#    'url': 'https://www.petfinder.com/dog/uni-59332661/ga/chamblee/dekalb-county-animal-services-ga423/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Uni',
#    'description': None,
#    'organization_animal_id': '51801281',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332661/1/?bust=1672786238'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:51:18+0000',
#    'published_at': '2023-01-03T20:51:16+0000',
#    'distance': 91.1641,
#    'contact': {'email': 'adoption@dekalbanimalservices.com',
#     'phone': '(404) 294-2165',
#     'address': {'address1': '3280 Chamblee Dunwoody Rd',
#      'address2': None,
#      'city': 'Chamblee',
#      'state': 'GA',
#      'postcode': '30341',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332661'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga423'}}},
#   {'id': 59332578,
#    'organization_id': 'GA217',
#    'url': 'https://www.petfinder.com/dog/tucker-59332578/ga/atlanta/fulton-county-animal-services-ga217/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'TUCKER',
#    'description': None,
#    'organization_animal_id': 'A895380',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332578/1/?bust=1672779282'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:44:37+0000',
#    'published_at': '2023-01-03T20:44:35+0000',
#    'distance': 89.0067,
#    'contact': {'email': 'adoptions@fultonanimalservices.com',
#     'phone': '(404) 613-0358',
#     'address': {'address1': '860 Marietta Blvd. NW',
#      'address2': None,
#      'city': 'Atlanta',
#      'state': 'GA',
#      'postcode': '30318',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332578'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga217'}}},
#   {'id': 59332237,
#    'organization_id': 'GA219',
#    'url': 'https://www.petfinder.com/dog/a207749-59332237/ga/augusta/augusta-animal-services-ga219/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Treeing Walker Coonhound',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A207749',
#    'description': None,
#    'organization_animal_id': 'A207749',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332237/1/?bust=1672777969'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:22:48+0000',
#    'published_at': '2023-01-03T20:22:46+0000',
#    'distance': 94.1,
#    'contact': {'email': None,
#     'phone': '706-790-6836   ',
#     'address': {'address1': '4164 Mack Lane',
#      'address2': None,
#      'city': 'Augusta',
#      'state': 'GA',
#      'postcode': '30906',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332237'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga219'}}},
#   {'id': 59332155,
#    'organization_id': 'GA247',
#    'url': 'https://www.petfinder.com/dog/zeus-59332155/ga/covington/newton-county-animal-control-ga247/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Zeus',
#    'description': 'Primary Color: Black Secondary Color: White',
#    'organization_animal_id': '14958',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332155/1/?bust=1672777742'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:19:01+0000',
#    'published_at': '2023-01-03T20:18:59+0000',
#    'distance': 59.8791,
#    'contact': {'email': 'newtonac@co.newton.ga.us',
#     'phone': '(770) 786-9514',
#     'address': {'address1': '210 Lower River Rd.',
#      'address2': None,
#      'city': 'Covington',
#      'state': 'GA',
#      'postcode': '30016',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332155'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga247'}}},
#   {'id': 59332129,
#    'organization_id': 'GA399',
#    'url': 'https://www.petfinder.com/dog/ac29244-rascal-59332129/ga/conyers/rockdale-county-animal-services-ga399/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': 'Dalmatian',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream',
#     'secondary': 'Black',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'AC29244    "Rascal"',
#    'description': None,
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332129/1/?bust=1672777028'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:17:10+0000',
#    'published_at': '2023-01-03T20:17:09+0000',
#    'distance': 71.3762,
#    'contact': {'email': 'Summer.Witt@RockdaleCountyGa.Gov',
#     'phone': '7702788403',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Conyers',
#      'state': 'GA',
#      'postcode': '30012',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332129'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga399'}}},
#   {'id': 59332087,
#    'organization_id': 'GA399',
#    'url': 'https://www.petfinder.com/dog/ac29242-max-59332087/ga/conyers/rockdale-county-animal-services-ga399/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': 'Dalmatian',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'AC29242    "Max"',
#    'description': None,
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332087/1/?bust=1672776776'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:12:59+0000',
#    'published_at': '2023-01-03T20:12:58+0000',
#    'distance': 71.3762,
#    'contact': {'email': 'Summer.Witt@RockdaleCountyGa.Gov',
#     'phone': '7702788403',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Conyers',
#      'state': 'GA',
#      'postcode': '30012',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332087'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga399'}}},
#   {'id': 59332049,
#    'organization_id': 'GA399',
#    'url': 'https://www.petfinder.com/dog/ac29251-sammy-59332049/ga/conyers/rockdale-county-animal-services-ga399/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': ['Friendly', 'Affectionate', 'Playful', 'Smart', 'Curious'],
#    'name': 'AC29251    "Sammy"',
#    'description': None,
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59332049/1/?bust=1672776631'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T20:10:33+0000',
#    'published_at': '2023-01-03T20:10:32+0000',
#    'distance': 71.3762,
#    'contact': {'email': 'Summer.Witt@RockdaleCountyGa.Gov',
#     'phone': '7702788403',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Conyers',
#      'state': 'GA',
#      'postcode': '30012',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59332049'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga399'}}},
#   {'id': 59331882,
#    'organization_id': 'GA357',
#    'url': 'https://www.petfinder.com/dog/pen-128c-ironman-hw-59331882/ga/lawrenceville/gwinnett-county-animal-control-and-welfare-ga357/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Rottweiler',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Pen 128c Ironman Hw++',
#    'description': 'Primary Color: Black Secondary Color: Rust Weight: 58lbs Age: 5yrs 2mths 3wks Animal has been Neutered',
#    'organization_animal_id': '91614',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/2/?bust=1672776045&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/2/?bust=1672776045&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/2/?bust=1672776045&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/2/?bust=1672776045'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/3/?bust=1672776045&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/3/?bust=1672776045&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/3/?bust=1672776045&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/3/?bust=1672776045'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331882/1/?bust=1672776042'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T19:50:39+0000',
#    'published_at': '2023-01-03T19:50:37+0000',
#    'distance': 88.2772,
#    'contact': {'email': 'animalwelfare@gwinnettcounty.com',
#     'phone': '(770) 339-3200',
#     'address': {'address1': '884 Winder Hwy (Rte 29)',
#      'address2': None,
#      'city': 'Lawrenceville',
#      'state': 'GA',
#      'postcode': '30045',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59331882'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga357'}}},
#   {'id': 59331840,
#    'organization_id': 'GA423',
#    'url': 'https://www.petfinder.com/dog/51799401-59331840/ga/chamblee/dekalb-county-animal-services-ga423/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '51799401',
#    'description': None,
#    'organization_animal_id': '51799401',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T19:46:07+0000',
#    'published_at': '2023-01-03T19:46:06+0000',
#    'distance': 91.1641,
#    'contact': {'email': 'adoption@dekalbanimalservices.com',
#     'phone': '(404) 294-2165',
#     'address': {'address1': '3280 Chamblee Dunwoody Rd',
#      'address2': None,
#      'city': 'Chamblee',
#      'state': 'GA',
#      'postcode': '30341',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59331840'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga423'}}},
#   {'id': 59331837,
#    'organization_id': 'GA423',
#    'url': 'https://www.petfinder.com/dog/roni-59331837/ga/chamblee/dekalb-county-animal-services-ga423/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Roni',
#    'description': None,
#    'organization_animal_id': '51799093',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331837/1/?bust=1672775774'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T19:46:08+0000',
#    'published_at': '2023-01-03T19:46:06+0000',
#    'distance': 91.1641,
#    'contact': {'email': 'adoption@dekalbanimalservices.com',
#     'phone': '(404) 294-2165',
#     'address': {'address1': '3280 Chamblee Dunwoody Rd',
#      'address2': None,
#      'city': 'Chamblee',
#      'state': 'GA',
#      'postcode': '30341',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59331837'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga423'}}},
#   {'id': 59331662,
#    'organization_id': 'GA70',
#    'url': 'https://www.petfinder.com/dog/thor-59331662/ga/greensboro/oconee-regional-humane-society-ga70/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Thor',
#    'description': None,
#    'organization_animal_id': '51797836',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331662/1/?bust=1672775306'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T19:38:23+0000',
#    'published_at': '2023-01-03T19:38:21+0000',
#    'distance': 51.5634,
#    'contact': {'email': 'ORHSpets@gmail.com',
#     'phone': '706-454-1508',
#     'address': {'address1': '1020 Park Ave',
#      'address2': 'Suite 101',
#      'city': 'Greensboro',
#      'state': 'GA',
#      'postcode': '30642',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59331662'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga70'}}},
#   {'id': 59331547,
#    'organization_id': 'GA1027',
#    'url': 'https://www.petfinder.com/dog/lemmy-59331547/ga/peachtree-corners/safe-haven-furever-pet-rescue-inc-ga1027/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'American Staffordshire Terrier',
#     'secondary': 'Great Dane',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': ['Friendly',
#     'Affectionate',
#     'Playful',
#     'Smart',
#     'Curious',
#     'Funny',
#     'Athletic',
#     'Loves kisses'],
#    'name': 'Lemmy',
#    'description': 'Meet Lemmy! He is a super friendly, handsome boy that is a cuddly puppy in a big dog body. Lemmy...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/2/?bust=1672773764&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/2/?bust=1672773764&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/2/?bust=1672773764&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/2/?bust=1672773764'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/3/?bust=1672773765&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/3/?bust=1672773765&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/3/?bust=1672773765&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/3/?bust=1672773765'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/4/?bust=1672773766&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/4/?bust=1672773766&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/4/?bust=1672773766&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/4/?bust=1672773766'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/5/?bust=1672773766&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/5/?bust=1672773766&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/5/?bust=1672773766&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/5/?bust=1672773766'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/6/?bust=1672773767&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/6/?bust=1672773767&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/6/?bust=1672773767&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/6/?bust=1672773767'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331547/1/?bust=1672773764'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T19:22:49+0000',
#    'published_at': '2023-01-03T19:22:48+0000',
#    'distance': 95.3574,
#    'contact': {'email': 'hollydeprimo@gmail.com',
#     'phone': '(678) 670-8046',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Peachtree Corners',
#      'state': 'GA',
#      'postcode': '30092',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59331547'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga1027'}}},
#   {'id': 59331267,
#    'organization_id': 'GA247',
#    'url': 'https://www.petfinder.com/dog/blue-59331267/ga/covington/newton-county-animal-control-ga247/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'American Bully',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Blue',
#    'description': 'Primary Color: Blue Secondary Color: White',
#    'organization_animal_id': '14957',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59331267/1/?bust=1672777743'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T19:03:32+0000',
#    'published_at': '2023-01-03T19:03:30+0000',
#    'distance': 59.8791,
#    'contact': {'email': 'newtonac@co.newton.ga.us',
#     'phone': '(770) 786-9514',
#     'address': {'address1': '210 Lower River Rd.',
#      'address2': None,
#      'city': 'Covington',
#      'state': 'GA',
#      'postcode': '30016',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59331267'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga247'}}},
#   {'id': 59330625,
#    'organization_id': 'GA247',
#    'url': 'https://www.petfinder.com/dog/seven-59330625/ga/covington/newton-county-animal-control-ga247/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Siberian Husky',
#     'secondary': 'Pit Bull Terrier',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Seven',
#    'description': 'Primary Color: Black Secondary Color: White Age: 0yrs 8mths 1wks Animal has been Neutered',
#    'organization_animal_id': '13251',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/2/?bust=1672770739&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/2/?bust=1672770739&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/2/?bust=1672770739&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/2/?bust=1672770739'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330625/1/?bust=1672770738'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T18:22:17+0000',
#    'published_at': '2023-01-03T18:22:15+0000',
#    'distance': 59.8791,
#    'contact': {'email': 'newtonac@co.newton.ga.us',
#     'phone': '(770) 786-9514',
#     'address': {'address1': '210 Lower River Rd.',
#      'address2': None,
#      'city': 'Covington',
#      'state': 'GA',
#      'postcode': '30016',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59330625'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga247'}}},
#   {'id': 59330011,
#    'organization_id': 'GA247',
#    'url': 'https://www.petfinder.com/dog/14955-59330011/ga/covington/newton-county-animal-control-ga247/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Siberian Husky',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '14955',
#    'description': 'Primary Color: Black Secondary Color: Brown',
#    'organization_animal_id': '14955',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59330011/1/?bust=1672767865'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-03T17:34:22+0000',
#    'published_at': '2023-01-03T17:34:20+0000',
#    'distance': 59.8791,
#    'contact': {'email': 'newtonac@co.newton.ga.us',
#     'phone': '(770) 786-9514',
#     'address': {'address1': '210 Lower River Rd.',
#      'address2': None,
#      'city': 'Covington',
#      'state': 'GA',
#      'postcode': '30016',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59330011'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga247'}}}],
#  'pagination': {'count_per_page': 20,
#   'total_count': 1903,
#   'current_page': 1,
#   'total_pages': 96,
#   '_links': {'next': {'href': '/v2/animals?gender=Male&location=GA&type=Dog&page=2'}}}}

# %%
pf = petpy.Petfinder(key=key,secret=secret)

# %%
animal_types = pf.animal_types()
animal_types
# Out:
# {'types': [{'name': 'Dog',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long', 'Wire', 'Curly'],
#    'colors': ['Apricot / Beige',
#     'Bicolor',
#     'Black',
#     'Brindle',
#     'Brown / Chocolate',
#     'Golden',
#     'Gray / Blue / Silver',
#     'Harlequin',
#     'Merle (Blue)',
#     'Merle (Red)',
#     'Red / Chestnut / Orange',
#     'Sable',
#     'Tricolor (Brown, Black, & White)',
#     'White / Cream',
#     'Yellow / Tan / Blond / Fawn'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/dog'},
#     'breeds': {'href': '/v2/types/dog/breeds'}}},
#   {'name': 'Cat',
#    'coats': ['Hairless', 'Short', 'Medium', 'Long'],
#    'colors': ['Black',
#     'Black & White / Tuxedo',
#     'Blue Cream',
#     'Blue Point',
#     'Brown / Chocolate',
#     'Buff & White',
#     'Buff / Tan / Fawn',
#     'Calico',
#     'Chocolate Point',
#     'Cream / Ivory',
#     'Cream Point',
#     'Dilute Calico',
#     'Dilute Tortoiseshell',
#     'Flame Point',
#     'Gray & White',
#     'Gray / Blue / Silver',
#     'Lilac Point',
#     'Orange & White',
#     'Orange / Red',
#     'Seal Point',
#     'Smoke',
#     'Tabby (Brown / Chocolate)',
#     'Tabby (Buff / Tan / Fawn)',
#     'Tabby (Gray / Blue / Silver)',
#     'Tabby (Leopard / Spotted)',
#     'Tabby (Orange / Red)',
#     'Tabby (Tiger Striped)',
#     'Torbie',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/cat'},
#     'breeds': {'href': '/v2/types/cat/breeds'}}},
#   {'name': 'Rabbit',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Cream',
#     'Lilac',
#     'Orange / Red',
#     'Sable',
#     'Silver Marten',
#     'Tan',
#     'Tortoiseshell',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/rabbit'},
#     'breeds': {'href': '/v2/types/rabbit/breeds'}}},
#   {'name': 'Small & Furry',
#    'coats': ['Hairless', 'Short', 'Long'],
#    'colors': ['Agouti',
#     'Albino',
#     'Black',
#     'Black Sable',
#     'Blue / Gray',
#     'Brown / Chocolate',
#     'Calico',
#     'Champagne',
#     'Cinnamon',
#     'Cream',
#     'Orange / Red',
#     'Sable',
#     'Tan',
#     'Tortoiseshell',
#     'White',
#     'White (Dark-Eyed)'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/small-furry'},
#     'breeds': {'href': '/v2/types/small-furry/breeds'}}},
#   {'name': 'Horse',
#    'coats': [],
#    'colors': ['Appaloosa',
#     'Bay',
#     'Bay Roan',
#     'Black',
#     'Blue Roan',
#     'Brown',
#     'Buckskin',
#     'Champagne',
#     'Chestnut / Sorrel',
#     'Cremello',
#     'Dapple Gray',
#     'Dun',
#     'Gray',
#     'Grullo',
#     'Liver',
#     'Paint',
#     'Palomino',
#     'Perlino',
#     'Piebald',
#     'Pinto',
#     'Red Roan',
#     'Silver Bay',
#     'Silver Buckskin',
#     'Silver Dapple',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/horse'},
#     'breeds': {'href': '/v2/types/horse/breeds'}}},
#   {'name': 'Bird',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Buff',
#     'Gray',
#     'Green',
#     'Olive',
#     'Orange',
#     'Pink',
#     'Purple / Violet',
#     'Red',
#     'Rust / Rufous',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/bird'},
#     'breeds': {'href': '/v2/types/bird/breeds'}}},
#   {'name': 'Scales, Fins & Other',
#    'coats': [],
#    'colors': ['Black',
#     'Blue',
#     'Brown',
#     'Gray',
#     'Green',
#     'Iridescent',
#     'Orange',
#     'Purple',
#     'Red',
#     'Tan',
#     'White',
#     'Yellow'],
#    'genders': ['Male', 'Female', 'Unknown'],
#    '_links': {'self': {'href': '/v2/types/scales-fins-other'},
#     'breeds': {'href': '/v2/types/scales-fins-other/breeds'}}},
#   {'name': 'Barnyard',
#    'coats': ['Short', 'Long'],
#    'colors': ['Agouti',
#     'Black',
#     'Black & White',
#     'Brindle',
#     'Brown',
#     'Gray',
#     'Pink',
#     'Red',
#     'Roan',
#     'Spotted',
#     'Tan',
#     'White'],
#    'genders': ['Male', 'Female'],
#    '_links': {'self': {'href': '/v2/types/barnyard'},
#     'breeds': {'href': '/v2/types/barnyard/breeds'}}}]}

# %%
# testing for 1 page but update to 100 pages later
everything = pf.animals(
    
    results_per_page=100,
    pages=1
)
everything['animals']
# Out:
# [{'id': 59336254,
#   'organization_id': 'TN977',
#   'url': 'https://www.petfinder.com/dog/natasha-and-bullwinkle-59336254/ri/warwick/whiskers-fund-tn977/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Shih Tzu',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Black',
#    'secondary': 'White / Cream',
#    'tertiary': 'Brown / Chocolate'},
#   'age': 'Adult',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': 'Medium',
#   'attributes': {'spayed_neutered': True,
#    'house_trained': True,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': True, 'dogs': True, 'cats': None},
#   'tags': ['Friendly',
#    'Affectionate',
#    'Loyal',
#    'Playful',
#    'Smart',
#    'Protective',
#    'Funny',
#    'Couch potato',
#    'Loves kisses',
#    'Curious'],
#   'name': 'Natasha & Bullwinkle',
#   'description': 'Currently located in: TN! Traveling up north soon! \nAdoptable in: ANYWHERE! (Transport available to most places!)\nGood with dogs: Yes,...',
#   'organization_animal_id': None,
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/2/?bust=1672796534&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/2/?bust=1672796534&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/2/?bust=1672796534&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/2/?bust=1672796534'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336254/1/?bust=1672796533'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:42:17+0000',
#   'published_at': '2023-01-04T01:42:16+0000',
#   'distance': None,
#   'contact': {'email': 'whiskersfunds@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Warwick ',
#     'state': 'RI',
#     'postcode': '02886',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336254'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/tn977'}}},
#  {'id': 59336250,
#   'organization_id': 'IL652',
#   'url': 'https://www.petfinder.com/dog/cora-59336250/il/orland-park/half-way-home-animal-rescue-il652/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Australian Shepherd',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Brown / Chocolate',
#    'secondary': 'White / Cream',
#    'tertiary': None},
#   'age': 'Baby',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': 'Medium',
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': True, 'dogs': True, 'cats': None},
#   'tags': ['Friendly',
#    'Affectionate',
#    'Loyal',
#    'Gentle',
#    'Playful',
#    'Smart',
#    'Funny',
#    'Athletic',
#    'Loves kisses'],
#   'name': 'Cora',
#   'description': 'Name: Cora\nage: 5 months old\nGender: female\nWeight: 25-30 lbs\nBreed: Australian Shepherd. \n\nCora is shy at first and...',
#   'organization_animal_id': None,
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/2/?bust=1672796483&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/2/?bust=1672796483&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/2/?bust=1672796483&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/2/?bust=1672796483'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336250/1/?bust=1672796482'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:41:26+0000',
#   'published_at': '2023-01-04T01:41:25+0000',
#   'distance': None,
#   'contact': {'email': 'info@hwhanimalrescue.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Orland Park',
#     'state': 'IL',
#     'postcode': '60462',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336250'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/il652'}}},
#  {'id': 59336236,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/checkers-59336236/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Long Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Orange / Red', 'secondary': None, 'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': ['Bonded'],
#   'name': 'Checkers',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101342',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336236'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336237,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/fefe-59336237/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Orange / Red',
#    'secondary': 'Black',
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Fefe',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101909',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336237'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336238,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/thomas-59336238/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Gray / Blue / Silver',
#    'secondary': 'White',
#    'tertiary': None},
#   'age': 'Baby',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Thomas',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101702',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336238'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336239,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/mcmuffin-59336239/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Long Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Brown / Chocolate',
#    'secondary': 'White',
#    'tertiary': None},
#   'age': 'Baby',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'McMuffin',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101853',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336239'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336240,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/baxter-59336240/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Black',
#    'secondary': 'Brown / Chocolate',
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': True, 'cats': True},
#   'tags': ['Good with Cats', 'Good with Children', 'Good with Dogs'],
#   'name': 'Baxter',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101897',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336240'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336241,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/citrine-59336241/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Long Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Orange / Red',
#    'secondary': 'Cream / Ivory',
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Citrine',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101899',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336241'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336242,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/chess-59336242/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Long Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Buff / Tan / Fawn',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': ['Bonded'],
#   'name': 'Chess',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101341',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336242'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336243,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/samantha-59336243/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Brown / Chocolate',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Baby',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Samantha',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101855',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336243'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336244,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/mugsy-59336244/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Orange / Red', 'secondary': None, 'tertiary': None},
#   'age': 'Baby',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Mugsy',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101910',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336244'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336245,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/hay-man-59336245/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Medium Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Black', 'secondary': 'White', 'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Hay Man',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101880',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336245'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336246,
#   'organization_id': 'WA48',
#   'url': 'https://www.petfinder.com/cat/aventurine-59336246/wa/spokane/spokanimal-wa48/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Cream / Ivory', 'secondary': None, 'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Large',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Aventurine',
#   'description': None,
#   'organization_animal_id': 'SPWA-A-101898',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:26+0000',
#   'published_at': '2023-01-04T01:40:25+0000',
#   'distance': None,
#   'contact': {'email': 'miracles@spokanimal.org',
#    'phone': '(509) 534-8133',
#    'address': {'address1': '710 N Napa Street',
#     'address2': None,
#     'city': 'Spokane',
#     'state': 'WA',
#     'postcode': '99202',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336246'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wa48'}}},
#  {'id': 59336227,
#   'organization_id': 'GA949',
#   'url': 'https://www.petfinder.com/dog/meeka-59336227/ga/gainesville/evelyns-place-rescue-ga949/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Miniature Pinscher',
#    'secondary': 'Chihuahua',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': 'Tricolor (Brown, Black, & White)',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': 'Short',
#   'attributes': {'spayed_neutered': False,
#    'house_trained': True,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': True, 'dogs': True, 'cats': None},
#   'tags': [],
#   'name': 'Meeka',
#   'description': 'Meeka is 18 months old, weighs 8.2lbs, loves to do zoomies and has lots of energy. She will do best...',
#   'organization_animal_id': None,
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/2/?bust=1672796410&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/2/?bust=1672796410&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/2/?bust=1672796410&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/2/?bust=1672796410'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336227/1/?bust=1672796409'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:12+0000',
#   'published_at': '2023-01-04T01:40:11+0000',
#   'distance': None,
#   'contact': {'email': 'epradoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Gainesville',
#     'state': 'GA',
#     'postcode': '30501',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336227'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/ga949'}}},
#  {'id': 59336232,
#   'organization_id': 'CO476',
#   'url': 'https://www.petfinder.com/dog/she-ra-59336232/co/fort-lupton/the-good-dog-rescue-co476/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Retriever',
#    'secondary': 'Shepherd',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': True, 'cats': None},
#   'tags': [],
#   'name': 'She-Ra',
#   'description': 'Hello Hello, I&amp;#39;m She-ra! I am the only female which automatically makes me the Princess right? I&amp;#39;m very sweet, but...',
#   'organization_animal_id': 'ps_1582985-1803660',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:10+0000',
#   'published_at': '2023-01-04T01:40:09+0000',
#   'distance': None,
#   'contact': {'email': 'thegooddogrescueadoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Fort Lupton',
#     'state': 'CO',
#     'postcode': '80621',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336232'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/co476'}}},
#  {'id': 59336233,
#   'organization_id': 'CO476',
#   'url': 'https://www.petfinder.com/dog/tippy-59336233/co/fort-lupton/the-good-dog-rescue-co476/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Retriever',
#    'secondary': 'Shepherd',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': 'Tricolor (Brown, Black, & White)',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': True, 'cats': None},
#   'tags': [],
#   'name': 'Tippy',
#   'description': 'Hiiiiii! I&amp;#39;m Tippy! I am super playful and I love to wrestle! But I am also very sweet and have...',
#   'organization_animal_id': 'ps_1582983-1803660',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:10+0000',
#   'published_at': '2023-01-04T01:40:09+0000',
#   'distance': None,
#   'contact': {'email': 'thegooddogrescueadoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Fort Lupton',
#     'state': 'CO',
#     'postcode': '80621',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336233'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/co476'}}},
#  {'id': 59336228,
#   'organization_id': 'CO476',
#   'url': 'https://www.petfinder.com/dog/skittles-59336228/co/fort-lupton/the-good-dog-rescue-co476/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Dachshund',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Brown / Chocolate',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Senior',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': False, 'dogs': True, 'cats': None},
#   'tags': [],
#   'name': 'Skittles',
#   'description': 'Hi! My name is Skittles and I am looking for a special person to take me home. I have recently...',
#   'organization_animal_id': 'ps_70339254',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:09+0000',
#   'published_at': '2023-01-04T01:40:08+0000',
#   'distance': None,
#   'contact': {'email': 'thegooddogrescueadoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Fort Lupton',
#     'state': 'CO',
#     'postcode': '80621',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336228'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/co476'}}},
#  {'id': 59336229,
#   'organization_id': 'CO476',
#   'url': 'https://www.petfinder.com/dog/jurojin-59336229/co/fort-lupton/the-good-dog-rescue-co476/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Retriever',
#    'secondary': 'Shepherd',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': 'Tricolor (Brown, Black, & White)',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': True, 'cats': None},
#   'tags': [],
#   'name': 'Jurojin',
#   'description': 'Hey! I&amp;#39;m Jurojin! I may have been the last one born, but I&amp;#39;m the first to do everything else! I&amp;#39;m...',
#   'organization_animal_id': 'ps_17240080',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:09+0000',
#   'published_at': '2023-01-04T01:40:08+0000',
#   'distance': None,
#   'contact': {'email': 'thegooddogrescueadoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Fort Lupton',
#     'state': 'CO',
#     'postcode': '80621',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336229'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/co476'}}},
#  {'id': 59336230,
#   'organization_id': 'CO476',
#   'url': 'https://www.petfinder.com/dog/sol-59336230/co/fort-lupton/the-good-dog-rescue-co476/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Husky',
#    'secondary': 'Boxer',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': True,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Sol',
#   'description': 'Hi! My name is Sol and I am the most beautifully unique dog around! I&amp;#39;m about a year and 1/2...',
#   'organization_animal_id': 'ps_80384768',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:09+0000',
#   'published_at': '2023-01-04T01:40:08+0000',
#   'distance': None,
#   'contact': {'email': 'thegooddogrescueadoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Fort Lupton',
#     'state': 'CO',
#     'postcode': '80621',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336230'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/co476'}}},
#  {'id': 59336231,
#   'organization_id': 'CO476',
#   'url': 'https://www.petfinder.com/dog/adam-59336231/co/fort-lupton/the-good-dog-rescue-co476/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Retriever',
#    'secondary': 'Shepherd',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': 'Tricolor (Brown, Black, & White)',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': True, 'cats': None},
#   'tags': [],
#   'name': 'Adam',
#   'description': 'Hi there, my name is Adam. My foster family says that I am beautiful, incredibly sweet, and a little bit...',
#   'organization_animal_id': 'ps_1582987-1803660',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:09+0000',
#   'published_at': '2023-01-04T01:40:08+0000',
#   'distance': None,
#   'contact': {'email': 'thegooddogrescueadoptions@gmail.com',
#    'phone': None,
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Fort Lupton',
#     'state': 'CO',
#     'postcode': '80621',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336231'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/co476'}}},
#  {'id': 59336225,
#   'organization_id': 'KS327',
#   'url': 'https://www.petfinder.com/dog/ruby-59336225/ks/shawnee/imagine-furever-ranch-ks327/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Mastiff',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Yellow / Tan / Blond / Fawn',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Senior',
#   'gender': 'Female',
#   'size': 'Extra Large',
#   'coat': 'Short',
#   'attributes': {'spayed_neutered': True,
#    'house_trained': True,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': True, 'dogs': True, 'cats': True},
#   'tags': ['Friendly',
#    'Affectionate',
#    'Loyal',
#    'Gentle',
#    'Playful',
#    'Smart',
#    'Loves kisses'],
#   'name': 'Ruby',
#   'description': 'Ruby has arrived at The Ranch!\n\nRuby is 160 lbs of English Mastiff love, and has THE BEST personality! She&#039;s...',
#   'organization_animal_id': None,
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/2/?bust=1672796405&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/2/?bust=1672796405&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/2/?bust=1672796405&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/2/?bust=1672796405'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/3/?bust=1672796406&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/3/?bust=1672796406&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/3/?bust=1672796406&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/3/?bust=1672796406'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336225/1/?bust=1672796404'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:08+0000',
#   'published_at': '2023-01-04T01:40:07+0000',
#   'distance': None,
#   'contact': {'email': 'imaginefureverranch.info@gmail.com',
#    'phone': None,
#    'address': {'address1': '20720 W. 47th Street',
#     'address2': None,
#     'city': 'Shawnee',
#     'state': 'KS',
#     'postcode': '66218',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336225'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/ks327'}}},
#  {'id': 59336224,
#   'organization_id': 'CA2537',
#   'url': 'https://www.petfinder.com/dog/bandit-59336224/ca/burbank/dachshunds-and-friends-rescue-ca2537/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Toy Fox Terrier',
#    'secondary': 'Mixed Breed',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Baby',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': True, 'dogs': True, 'cats': None},
#   'tags': ['Friendly', 'Playful', 'Curious'],
#   'name': 'Bandit',
#   'description': 'I’m Bandit. Being playful and loving are the things I love most. I love to play and run in the...',
#   'organization_animal_id': None,
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/2/?bust=1672796404&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/2/?bust=1672796404&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/2/?bust=1672796404&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/2/?bust=1672796404'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/3/?bust=1672796404&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/3/?bust=1672796404&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/3/?bust=1672796404&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/3/?bust=1672796404'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/4/?bust=1672796405&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/4/?bust=1672796405&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/4/?bust=1672796405&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/4/?bust=1672796405'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/5/?bust=1672796406&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/5/?bust=1672796406&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/5/?bust=1672796406&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/5/?bust=1672796406'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336224/1/?bust=1672796403'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:40:08+0000',
#   'published_at': '2023-01-04T01:40:07+0000',
#   'distance': None,
#   'contact': {'email': 'dachshundsandfriendsrescue@gmail.com',
#    'phone': '(818) 489-1513',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Burbank',
#     'state': 'CA',
#     'postcode': '91505',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336224'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/ca2537'}}},
#  {'id': 59336223,
#   'organization_id': 'WI276',
#   'url': 'https://www.petfinder.com/cat/reggie-59336223/wi/park-falls/catkins-animal-rescue-inc-wi276/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Black & White / Tuxedo',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': True,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': True},
#   'tags': [],
#   'name': 'Reggie',
#   'description': 'Reggie is a 1.5 y/o DSH male, black and white. He is a loving cat, though he likes to choose...',
#   'organization_animal_id': '18909507',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:39:49+0000',
#   'published_at': '2023-01-04T01:39:48+0000',
#   'distance': None,
#   'contact': {'email': 'catkins_wi@yahoo.com',
#    'phone': '(715) 762-0122',
#    'address': {'address1': 'N15262 Oak RD',
#     'address2': None,
#     'city': 'Park Falls',
#     'state': 'WI',
#     'postcode': '54552',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336223'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/wi276'}}},
#  {'id': 59336222,
#   'organization_id': 'IA14',
#   'url': 'https://www.petfinder.com/dog/daisy-lou-59336222/ia/des-moines/animal-rescue-league-of-iowa-inc-ia14/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Border Collie',
#    'secondary': None,
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Daisy Lou',
#   'description': 'Primary Color: Black Secondary Color: White Weight: 29.7lbs Age: 1yrs 2mths 2wks Animal has been Spayed',
#   'organization_animal_id': '226358',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:39:44+0000',
#   'published_at': '2023-01-04T01:39:43+0000',
#   'distance': None,
#   'contact': {'email': 'social@arl-iowa.org',
#    'phone': None,
#    'address': {'address1': '5452 N.E. 22nd St.',
#     'address2': None,
#     'city': 'Des Moines',
#     'state': 'IA',
#     'postcode': '50313',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336222'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/ia14'}}},
#  {'id': 59336221,
#   'organization_id': 'FL380',
#   'url': 'https://www.petfinder.com/dog/schnitzel-59336221/fl/green-cove-springs/clay-county-animal-services-fl380/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'German Shepherd Dog',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Yellow / Tan / Blond / Fawn',
#    'secondary': 'Black',
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Schnitzel',
#   'description': None,
#   'organization_animal_id': 'CLAY-A-4057',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:39:42+0000',
#   'published_at': '2023-01-04T01:39:41+0000',
#   'distance': None,
#   'contact': {'email': None,
#    'phone': '(904) 269-6342',
#    'address': {'address1': '3984 St. Rd. 16 W.',
#     'address2': None,
#     'city': 'Green Cove Springs',
#     'state': 'FL',
#     'postcode': '32043',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336221'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/fl380'}}},
#  {'id': 59336219,
#   'organization_id': 'HI06',
#   'url': 'https://www.petfinder.com/dog/alohi-59336219/hi/kailua-kona/hawaii-island-humane-society-hi06/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Mixed Breed',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'White / Cream',
#    'secondary': 'Brown / Chocolate',
#    'tertiary': None},
#   'age': 'Adult',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': ['THE ANIMAL COMMUNITY CENTER IN KONA'],
#   'name': 'Alohi',
#   'description': 'To adopt me: \nStart by clicking the &amp;#34;Apply to Adopt&amp;#34; button on my profile! \nOnce you have filled out the...',
#   'organization_animal_id': 'HIHS-A-7991',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:39:32+0000',
#   'published_at': '2023-01-04T01:39:31+0000',
#   'distance': None,
#   'contact': {'email': 'adopt@hihs.org',
#    'phone': '(808) 329-8002',
#    'address': {'address1': '78-6767 Mamalahoa Hwy',
#     'address2': None,
#     'city': 'Kailua Kona',
#     'state': 'HI',
#     'postcode': '96740',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336219'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/hi06'}}},
#  {'id': 59336220,
#   'organization_id': 'HI06',
#   'url': 'https://www.petfinder.com/dog/gingerbread-59336220/hi/kailua-kona/hawaii-island-humane-society-hi06/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Mixed Breed',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Red / Chestnut / Orange',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': ['Dog Social Friendly',
#    'Eligible for Foster to Adopt',
#    'THE ANIMAL COMMUNITY CENTER IN KONA'],
#   'name': 'Gingerbread',
#   'description': 'To adopt me:\nStart by clicking the &amp;#34;Apply to Adopt button on my profile! Once you have filled out the...',
#   'organization_animal_id': 'HIHS-A-7906',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:39:32+0000',
#   'published_at': '2023-01-04T01:39:31+0000',
#   'distance': None,
#   'contact': {'email': 'adopt@hihs.org',
#    'phone': '(808) 329-8002',
#    'address': {'address1': '78-6767 Mamalahoa Hwy',
#     'address2': None,
#     'city': 'Kailua Kona',
#     'state': 'HI',
#     'postcode': '96740',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336220'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/hi06'}}},
#  {'id': 59336217,
#   'organization_id': 'TN480',
#   'url': 'https://www.petfinder.com/cat/23843-59336217/tn/greeneville/greene-county-animal-control-tn480/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
# ...
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Lizzy King',
#   'description': None,
#   'organization_animal_id': 'FPVA-A-10294',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:06+0000',
#   'published_at': '2023-01-04T01:27:05+0000',
#   'distance': None,
#   'contact': {'email': 'info@fourpaws.org',
#    'phone': '(703) 715-6369',
#    'address': {'address1': 'P.O. Box 2908',
#     'address2': None,
#     'city': 'Merrifield',
#     'state': 'VA',
#     'postcode': '22116',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336130'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/va260'}}},
#  {'id': 59336131,
#   'organization_id': 'VA260',
#   'url': 'https://www.petfinder.com/cat/lawrence-rockbridge-59336131/va/merrifield/4paws-rescue-team-va260/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Bombay',
#    'secondary': 'Domestic Short Hair',
#    'mixed': True,
#    'unknown': False},
#   'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Lawrence Rockbridge',
#   'description': None,
#   'organization_animal_id': 'FPVA-A-10290',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:06+0000',
#   'published_at': '2023-01-04T01:27:05+0000',
#   'distance': None,
#   'contact': {'email': 'info@fourpaws.org',
#    'phone': '(703) 715-6369',
#    'address': {'address1': 'P.O. Box 2908',
#     'address2': None,
#     'city': 'Merrifield',
#     'state': 'VA',
#     'postcode': '22116',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336131'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/va260'}}},
#  {'id': 59336132,
#   'organization_id': 'VA260',
#   'url': 'https://www.petfinder.com/cat/carole-rockbridge-59336132/va/merrifield/4paws-rescue-team-va260/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Gray / Blue / Silver',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Carole Rockbridge',
#   'description': None,
#   'organization_animal_id': 'FPVA-A-10288',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:06+0000',
#   'published_at': '2023-01-04T01:27:05+0000',
#   'distance': None,
#   'contact': {'email': 'info@fourpaws.org',
#    'phone': '(703) 715-6369',
#    'address': {'address1': 'P.O. Box 2908',
#     'address2': None,
#     'city': 'Merrifield',
#     'state': 'VA',
#     'postcode': '22116',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336132'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/va260'}}},
#  {'id': 59336133,
#   'organization_id': 'VA260',
#   'url': 'https://www.petfinder.com/cat/phoebe-rockbridge-59336133/va/merrifield/4paws-rescue-team-va260/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Orange / Red',
#    'secondary': 'White',
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': False,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': False, 'dogs': None, 'cats': True},
#   'tags': ['Barn Cat', 'Bonded', 'Good with Cats', 'Not Good with Kids'],
#   'name': 'Phoebe Rockbridge',
#   'description': None,
#   'organization_animal_id': 'FPVA-A-10293',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:06+0000',
#   'published_at': '2023-01-04T01:27:05+0000',
#   'distance': None,
#   'contact': {'email': 'info@fourpaws.org',
#    'phone': '(703) 715-6369',
#    'address': {'address1': 'P.O. Box 2908',
#     'address2': None,
#     'city': 'Merrifield',
#     'state': 'VA',
#     'postcode': '22116',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336133'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/va260'}}},
#  {'id': 59336127,
#   'organization_id': 'VA260',
#   'url': 'https://www.petfinder.com/cat/monty-rockbridge-59336127/va/merrifield/4paws-rescue-team-va260/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': 'Buff / Tan / Fawn',
#    'secondary': None,
#    'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': True},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Monty Rockbridge',
#   'description': None,
#   'organization_animal_id': 'FPVA-A-10289',
#   'photos': [],
#   'primary_photo_cropped': None,
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:05+0000',
#   'published_at': '2023-01-04T01:27:04+0000',
#   'distance': None,
#   'contact': {'email': 'info@fourpaws.org',
#    'phone': '(703) 715-6369',
#    'address': {'address1': 'P.O. Box 2908',
#     'address2': None,
#     'city': 'Merrifield',
#     'state': 'VA',
#     'postcode': '22116',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336127'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/va260'}}},
#  {'id': 59336126,
#   'organization_id': 'NC249',
#   'url': 'https://www.petfinder.com/cat/seeker-59336126/nc/wilkesboro/humane-society-of-wilkes-nc249/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Seeker',
#   'description': 'Seeker is a 9 month old male DSH. He&amp;#39;s the perfect set of playful and sweet! He gets along well...',
#   'organization_animal_id': '51769572',
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/2/?bust=1672796225&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/2/?bust=1672796225&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/2/?bust=1672796225&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/2/?bust=1672796225'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/3/?bust=1672796226&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/3/?bust=1672796226&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/3/?bust=1672796226&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/3/?bust=1672796226'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336126/1/?bust=1672796230'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:04+0000',
#   'published_at': '2023-01-04T01:27:02+0000',
#   'distance': None,
#   'contact': {'email': 'INFO@humanesocietyofwilkes.org',
#    'phone': '(336) 838-9588',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Wilkesboro',
#     'state': 'NC',
#     'postcode': '28697',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336126'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/nc249'}}},
#  {'id': 59336125,
#   'organization_id': 'NC249',
#   'url': 'https://www.petfinder.com/dog/zuri-59336125/nc/wilkesboro/humane-society-of-wilkes-nc249/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Dog',
#   'species': 'Dog',
#   'breeds': {'primary': 'Mixed Breed',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Young',
#   'gender': 'Female',
#   'size': 'Medium',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': None,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Zuri',
#   'description': 'Zuri is a female mixed breed around a year and a half old and is full grown at 45lbs. She...',
#   'organization_animal_id': '51344753',
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/2/?bust=1672796225&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/2/?bust=1672796225&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/2/?bust=1672796225&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/2/?bust=1672796225'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/3/?bust=1672796230&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/3/?bust=1672796230&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/3/?bust=1672796230&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/3/?bust=1672796230'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336125/1/?bust=1672796225'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:04+0000',
#   'published_at': '2023-01-04T01:27:02+0000',
#   'distance': None,
#   'contact': {'email': 'INFO@humanesocietyofwilkes.org',
#    'phone': '(336) 838-9588',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Wilkesboro',
#     'state': 'NC',
#     'postcode': '28697',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336125'},
#    'type': {'href': '/v2/types/dog'},
#    'organization': {'href': '/v2/organizations/nc249'}}},
#  {'id': 59336124,
#   'organization_id': 'NC249',
#   'url': 'https://www.petfinder.com/cat/finnick-59336124/nc/wilkesboro/humane-society-of-wilkes-nc249/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#   'type': 'Cat',
#   'species': 'Cat',
#   'breeds': {'primary': 'Domestic Short Hair',
#    'secondary': None,
#    'mixed': False,
#    'unknown': False},
#   'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#   'age': 'Young',
#   'gender': 'Male',
#   'size': 'Small',
#   'coat': None,
#   'attributes': {'spayed_neutered': True,
#    'house_trained': False,
#    'declawed': False,
#    'special_needs': False,
#    'shots_current': False},
#   'environment': {'children': None, 'dogs': None, 'cats': None},
#   'tags': [],
#   'name': 'Finnick',
#   'description': 'Meet Finnick! This 6 month old male DSH. Finnick is an adorable playful little guy who can&amp;#39;t wait for his...',
#   'organization_animal_id': '51769580',
#   'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/2/?bust=1672796225&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/2/?bust=1672796225&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/2/?bust=1672796225&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/2/?bust=1672796225'},
#    {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/3/?bust=1672796224&width=100',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/3/?bust=1672796224&width=300',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/3/?bust=1672796224&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/3/?bust=1672796224'}],
#   'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225&width=300',
#    'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225&width=450',
#    'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225&width=600',
#    'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59336124/1/?bust=1672796225'},
#   'videos': [],
#   'status': 'adoptable',
#   'status_changed_at': '2023-01-04T01:27:04+0000',
#   'published_at': '2023-01-04T01:27:02+0000',
#   'distance': None,
#   'contact': {'email': 'INFO@humanesocietyofwilkes.org',
#    'phone': '(336) 838-9588',
#    'address': {'address1': None,
#     'address2': None,
#     'city': 'Wilkesboro',
#     'state': 'NC',
#     'postcode': '28697',
#     'country': 'US'}},
#   '_links': {'self': {'href': '/v2/animals/59336124'},
#    'type': {'href': '/v2/types/cat'},
#    'organization': {'href': '/v2/organizations/nc249'}}}]

# %%
everything = pf.animals(

)
len(everything['animals'])
# Out:
# 20

# %%
for animal in animal_types['types']:
    print(animal['name'])
# Out:
# Dog
# Cat
# Rabbit
# Small & Furry
# Horse
# Bird
# Scales, Fins & Other
# Barnyard
