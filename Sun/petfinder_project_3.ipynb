# %%
# checking to see what the version of pandas i have for petpy
# !pip install petpy
# import pandas as pd
# pd.__version__

# %%
# upgrades to the lastest version of pandas
# !pip install -U pandas --user

# %%
# pd.__version__

# %%
import requests
import json
import pandas as pd
import petpy
# Out:
# C:\Users\alexc\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
key ="cKesBThlyw3n6lxFW4AXbsntBRK0CLEbAC5yzv6m4kZjjUYrp7"
secret ="Kbmyyp9Tkd3pWPT4NRorK5m7RrU7QOe1CWkGpHeA"
url = "https://api.petfinder.com/v2/oauth2/token"

# %%
# gets the access token using credentials
def get_access_token(url, client_id, client_secret):
    response = requests.post(
        url,
        data={"grant_type": "client_credentials"},
        auth=(key, secret),
    )
    return response.json()["access_token"]



token = get_access_token(url,key,secret)
get_access_token(url,key,secret)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..H270zAo2S9QxdeyEx7hj_lKHpQzKKp1xEqqqblrjtIX2FBz-5IrlYn2Rh71FO2N9NqvANd-a4j2nBJckXlb1UlZaYvjdP3HqapZk8p6YCqLeeKK6LAJWUAiSWPCDLY6zTZPvnCQFEGXDZhjejdLvi4xoC57J1vq0KJVp7bcqGx7EpABzdsCfTbFcoKsy81lRuB6khHQF4pBlTCKvuVsA66h8N_AgLGl92WHXurzF5gSEONqSPtyxmc9cj6S2rMG0m9GXUXBocX9nIDXiX_kMqqtTEKPd13MPhrkV4-3uKQiYbmTTOlFI4_JnyJ3B92y9Tiim6b_fblOTGzusGZ5UJw'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }

param = {
   "page": 1,
    "limit": 100
    #these are not indented, so no problem there.
    }#close param

response = requests.get('https://api.petfinder.com/v2/animals', headers=headers, 
        params=param)
response = response.json()
response
# Out:
# {'animals': [{'id': 59395942,
#    'organization_id': 'CA765',
#    'url': 'https://www.petfinder.com/dog/champy-59395942/ca/chatsworth/city-of-los-angeles-west-valley-animal-shelter-ca765/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'CHAMPY',
#    'description': None,
#    'organization_animal_id': 'A1963702',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:57:19+0000',
#    'published_at': '2023-01-09T22:57:18+0000',
#    'distance': None,
#    'contact': {'email': None,
#     'phone': '(213) 485-8405',
#     'address': {'address1': '20655 Plummer Street',
#      'address2': None,
#      'city': 'Chatsworth',
#      'state': 'CA',
#      'postcode': '91311',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395942'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca765'}}},
#   {'id': 59395940,
#    'organization_id': 'GA697',
#    'url': 'https://www.petfinder.com/cat/wonder-59395940/ga/powder-springs/georgia-homeless-pets-ga697/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Siamese',
#     'secondary': 'Domestic Short Hair',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': [],
#    'name': 'Wonder',
#    'description': None,
#    'organization_animal_id': 'ps_1609302-702299',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:57:06+0000',
#    'published_at': '2023-01-09T22:57:05+0000',
#    'distance': None,
#    'contact': {'email': 'adoptions@gahomelesspets.com',
#     'phone': '(404) 590-3108',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Powder Springs',
#      'state': 'GA',
#      'postcode': '30127',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395940'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ga697'}}},
#   {'id': 59395938,
#    'organization_id': 'VA789',
#    'url': 'https://www.petfinder.com/dog/cassie-59395938/va/unionville/all-fur-animals-rescue-inc-va789/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Terrier',
#     'secondary': 'Hound',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': ['Friendly',
#     'Affectionate',
#     'Playful',
#     'Gentle',
#     'Curious',
#     'Loves kisses'],
#    'name': 'Cassie',
#    'description': 'This sweet mama came to rescue with a litter of puppies. They were all terribly malnourished, needed to be treated...',
#    'organization_animal_id': None,
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:57:00+0000',
#    'published_at': '2023-01-09T22:56:59+0000',
#    'distance': None,
#    'contact': {'email': 'allfuranimalsrescue@gmail.com',
#     'phone': '(540) 718-7658',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Unionville',
#      'state': 'VA',
#      'postcode': '22567',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395938'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/va789'}}},
#   {'id': 59395939,
#    'organization_id': 'KY102',
#    'url': 'https://www.petfinder.com/cat/miracle-59395939/ky/louisville/louisville-metro-animal-services-ky102/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'MIRACLE',
#    'description': None,
#    'organization_animal_id': 'A725889',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:59+0000',
#    'published_at': '2023-01-09T22:56:58+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServicesAdoption@louisvilleky.gov',
#     'phone': '(502) 473-7387',
#     'address': {'address1': '3528 Newburg Road',
#      'address2': None,
#      'city': 'Louisville',
#      'state': 'KY',
#      'postcode': '40218',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395939'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ky102'}}},
#   {'id': 59395929,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506253-59395929/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506253',
#    'description': None,
#    'organization_animal_id': 'A506253',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395929'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395930,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506255-59395930/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506255',
#    'description': None,
#    'organization_animal_id': 'A506255',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395930'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395931,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506252-59395931/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Australian Cattle Dog / Blue Heeler',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506252',
#    'description': None,
#    'organization_animal_id': 'A506252',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395931'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395932,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506254-59395932/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506254',
#    'description': None,
#    'organization_animal_id': 'A506254',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395932'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395933,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506256-59395933/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506256',
#    'description': None,
#    'organization_animal_id': 'A506256',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395933'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395934,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506251-59395934/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506251',
#    'description': None,
#    'organization_animal_id': 'A506251',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395934'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395935,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/dexter-59395935/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'DEXTER',
#    'description': None,
#    'organization_animal_id': 'A506266',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395935'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395936,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506249-59395936/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506249',
#    'description': None,
#    'organization_animal_id': 'A506249',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395936'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395937,
#    'organization_id': 'FL275',
#    'url': 'https://www.petfinder.com/dog/a506250-59395937/fl/orlando/orange-county-animal-services-fl275/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Beagle',
#     'secondary': 'Pointer',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A506250',
#    'description': None,
#    'organization_animal_id': 'A506250',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:55+0000',
#    'published_at': '2023-01-09T22:56:54+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@ocfl.net',
#     'phone': None,
#     'address': {'address1': '2769 Conroy Road',
#      'address2': None,
#      'city': 'Orlando',
#      'state': 'FL',
#      'postcode': '32839',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395937'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/fl275'}}},
#   {'id': 59395926,
#    'organization_id': 'CA763',
#    'url': 'https://www.petfinder.com/dog/lala-59395926/ca/los-angeles/city-of-los-angeles-north-central-animal-shelter-ca763/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'LALA',
#    'description': None,
#    'organization_animal_id': 'A2056277',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:45+0000',
#    'published_at': '2023-01-09T22:56:44+0000',
#    'distance': None,
#    'contact': {'email': None,
#     'phone': '(888) 452-7381',
#     'address': {'address1': '3201 Lacy Street',
#      'address2': None,
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'postcode': '90031',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395926'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca763'}}},
#   {'id': 59395927,
#    'organization_id': 'CA763',
#    'url': 'https://www.petfinder.com/cat/kodak-59395927/ca/los-angeles/city-of-los-angeles-north-central-animal-shelter-ca763/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'KODAK',
#    'description': None,
#    'organization_animal_id': 'A2064522',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:45+0000',
#    'published_at': '2023-01-09T22:56:44+0000',
#    'distance': None,
#    'contact': {'email': None,
#     'phone': '(888) 452-7381',
#     'address': {'address1': '3201 Lacy Street',
#      'address2': None,
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'postcode': '90031',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395927'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ca763'}}},
#   {'id': 59395928,
#    'organization_id': 'CA763',
#    'url': 'https://www.petfinder.com/dog/gizmo-59395928/ca/los-angeles/city-of-los-angeles-north-central-animal-shelter-ca763/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'GIZMO',
#    'description': None,
#    'organization_animal_id': 'A2057014',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:45+0000',
#    'published_at': '2023-01-09T22:56:44+0000',
#    'distance': None,
#    'contact': {'email': None,
#     'phone': '(888) 452-7381',
#     'address': {'address1': '3201 Lacy Street',
#      'address2': None,
#      'city': 'Los Angeles',
#      'state': 'CA',
#      'postcode': '90031',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395928'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca763'}}},
#   {'id': 59395915,
#    'organization_id': 'IN604',
#    'url': 'https://www.petfinder.com/dog/asher-59395915/in/indianapolis/heaven-after-hell-rescue-in604/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Border Collie',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': None},
#    'tags': ['Friendly'],
#    'name': 'Asher',
#    'description': 'Hi, my name is Asher, and I am a super smart adventurer that also melts for a good belly rub...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/2/?bust=1673304999&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/2/?bust=1673304999&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/2/?bust=1673304999&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/2/?bust=1673304999'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395915/1/?bust=1673304998'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:41+0000',
#    'published_at': '2023-01-09T22:56:40+0000',
#    'distance': None,
#    'contact': {'email': 'miranda@heavenafterhellrescue.org',
#     'phone': '(317) 455-5758',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Indianapolis',
#      'state': 'IN',
#      'postcode': '46214',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395915'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/in604'}}},
#   {'id': 59395914,
#    'organization_id': 'TX1866',
#    'url': 'https://www.petfinder.com/dog/goldie-59395914/tx/houston/houston-chow-chow-connection-tx1866/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Chow Chow',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Long',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': ['Gentle', 'Smart', 'Affectionate', 'Quiet', 'Dignified'],
#    'name': 'Goldie',
#    'description': 'Goldie is about 6 years old and 35lbs. She is nervous around new people, but she warms up fairly quickly...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/2/?bust=1673304985&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/2/?bust=1673304985&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/2/?bust=1673304985&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/2/?bust=1673304985'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/3/?bust=1673304985&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/3/?bust=1673304985&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/3/?bust=1673304985&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/3/?bust=1673304985'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/4/?bust=1673304986&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/4/?bust=1673304986&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/4/?bust=1673304986&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/4/?bust=1673304986'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395914/1/?bust=1673304984'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:28+0000',
#    'published_at': '2023-01-09T22:56:27+0000',
#    'distance': None,
#    'contact': {'email': 'chowmail.hccc@gmail.com',
#     'phone': None,
#     'address': {'address1': '448 West 15th Street',
#      'address2': 'Box 553',
#      'city': 'Houston',
#      'state': 'TX',
#      'postcode': '77008',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395914'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1866'}}},
#   {'id': 59395913,
#    'organization_id': 'VA176',
#    'url': 'https://www.petfinder.com/dog/cookie-59395913/va/lynchburg/lynchburg-humane-society-va176/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Cattle Dog',
#     'secondary': 'Cardigan Welsh Corgi',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream', 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Cookie',
#    'description': None,
#    'organization_animal_id': 'LNHS-A-63466',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:24+0000',
#    'published_at': '2023-01-09T22:56:23+0000',
#    'distance': None,
#    'contact': {'email': 'adoption@lynchburghumane.org',
#     'phone': '(434) 448-0088',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Lynchburg',
#      'state': 'VA',
#      'postcode': '24502',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395913'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/va176'}}},
#   {'id': 59395912,
#    'organization_id': 'ON387',
#    'url': 'https://www.petfinder.com/cat/oreo-59395912/on/pickering/saint-rescue-and-adoption-on387/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black & White / Tuxedo',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': ['Quiet'],
#    'name': 'Oreo',
#    'description': 'Oreo was relinquished to us because owner was no longer able to care for her.  When she knows you and...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/1/?bust=1673304980&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/1/?bust=1673304980&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/1/?bust=1673304980&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/1/?bust=1673304980'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395912/2/?bust=1673304981'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:23+0000',
#    'published_at': '2023-01-09T22:56:22+0000',
#    'distance': None,
#    'contact': {'email': 'catrescue1@hotmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Pickering',
#      'state': 'ON',
#      'postcode': 'L1V 1L1',
#      'country': 'CA'}},
#    '_links': {'self': {'href': '/v2/animals/59395912'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/on387'}}},
#   {'id': 59395909,
#    'organization_id': 'KY395',
#    'url': 'https://www.petfinder.com/dog/champ-59395909/md/frederick/bourbon-county-rescue-ky395/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': 'Terrier',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Brown / Chocolate',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': None},
#    'tags': ['Friendly', 'Athletic'],
#    'name': 'Champ',
#    'description': 'Champ-Lab/Terrier X male,  ~ 1-2 yr. (Jan. 2023)\nContact rescuebc@hotmail.com for application.\nChamp was left at a high kill rural...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/2/?bust=1673304963&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/2/?bust=1673304963&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/2/?bust=1673304963&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/2/?bust=1673304963'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/3/?bust=1673304964&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/3/?bust=1673304964&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/3/?bust=1673304964&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/3/?bust=1673304964'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395909/1/?bust=1673304963'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:56:06+0000',
#    'published_at': '2023-01-09T22:56:05+0000',
#    'distance': None,
#    'contact': {'email': 'RescueBC@hotmail.com',
#     'phone': 'Please Email for Inquiries',
#     'address': {'address1': '1275 W Patrick Street',
#      'address2': None,
#      'city': 'Frederick',
#      'state': 'MD',
#      'postcode': '21702',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395909'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ky395'}}},
#   {'id': 59395906,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/fabio-59395906/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream',
#     'secondary': 'Gray / Blue / Silver',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Fabio',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23231',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:58+0000',
#    'published_at': '2023-01-09T22:55:57+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395906'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395907,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/latte-59395907/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Chihuahua',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Brown / Chocolate',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Latte',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23233',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:58+0000',
#    'published_at': '2023-01-09T22:55:57+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395907'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395908,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/diablo-rn-59395908/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'German Shepherd Dog',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Brown / Chocolate',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Diablo RN',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23195',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:58+0000',
#    'published_at': '2023-01-09T22:55:57+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395908'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395905,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/minerva-59395905/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'German Shepherd Dog',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Yellow / Tan / Blond / Fawn',
#     'tertiary': None},
#    'age': 'Senior',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Minerva',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23191',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:57+0000',
#    'published_at': '2023-01-09T22:55:56+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395905'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395901,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/alakazam-59395901/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Brown / Chocolate',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Alakazam',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23226',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:57+0000',
#    'published_at': '2023-01-09T22:55:56+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395901'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395902,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/cheesestick-59395902/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream',
#     'secondary': 'Brown / Chocolate',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Cheesestick',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23221',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:57+0000',
#    'published_at': '2023-01-09T22:55:56+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395902'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395903,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/zaliki-59395903/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Brown / Chocolate',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Zaliki',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23215',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:55:56+0000',
#    'published_at': '2023-01-09T22:55:55+0000',
#    'distance': None,
#    'contact': {'email': 'Info@spcabc.org',
#     'phone': '(979) 285-2340',
#     'address': {'address1': '141 Canna Lane',
#      'address2': None,
#      'city': 'Lake Jackson',
#      'state': 'TX',
#      'postcode': '77566',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395903'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx571'}}},
#   {'id': 59395904,
#    'organization_id': 'TX571',
#    'url': 'https://www.petfinder.com/dog/mariposa-59395904/tx/lake-jackson/spca-of-brazoria-county-tx571/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Chihuahua',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Mariposa',
#    'description': None,
#    'organization_animal_id': 'BRAZ-A-23229',
#    'photos': [],
# ...
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': None},
#    'tags': ['Friendly', 'Sweet', 'Smart'],
#    'name': 'Ollie',
#    'description': 'Ollie-Am Staffordshire Terrier X male,  ~ 1 yr. (Jan. 2023)\nContact rescuebc@hotmail.com for application.\nOllie was left at a high...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/2/?bust=1673304687&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/2/?bust=1673304687&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/2/?bust=1673304687&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/2/?bust=1673304687'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/3/?bust=1673304688&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/3/?bust=1673304688&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/3/?bust=1673304688&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/3/?bust=1673304688'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395826/1/?bust=1673304687'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:51:30+0000',
#    'published_at': '2023-01-09T22:51:29+0000',
#    'distance': None,
#    'contact': {'email': 'RescueBC@hotmail.com',
#     'phone': 'Please Email for Inquiries',
#     'address': {'address1': '1275 W Patrick Street',
#      'address2': None,
#      'city': 'Frederick',
#      'state': 'MD',
#      'postcode': '21702',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395826'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ky395'}}},
#   {'id': 59395824,
#    'organization_id': 'MO633',
#    'url': 'https://www.petfinder.com/dog/ruby-lou-59395824/mo/springfield/rescue-one-mo633/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Hound',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'White / Cream',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Ruby Lou ',
#    'description': 'A free spirited gorgeous gal looking for the right someone to share my life with.    My name is Ruby Lou...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395824/1/?bust=1673304914'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:50:55+0000',
#    'published_at': '2023-01-09T22:50:52+0000',
#    'distance': None,
#    'contact': {'email': 'rescueonespringfield@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Springfield',
#      'state': 'MO',
#      'postcode': '65804',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395824'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/mo633'}}},
#   {'id': 59395823,
#    'organization_id': 'VA284',
#    'url': 'https://www.petfinder.com/dog/2301-0309-gale-available-01-13-59395823/va/virginia-beach/virginia-beach-animal-care-and-adoption-center-va284/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Hound',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '2301-0309 Gale (Available 01/13)',
#    'description': 'Gale was found as a stray and never reclaimed. He is now looking for a new home. He seems dog...',
#    'organization_animal_id': '18931334',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:50:32+0000',
#    'published_at': '2023-01-09T22:50:31+0000',
#    'distance': None,
#    'contact': {'email': 'vbpdac@vbgov.com',
#     'phone': '757-385-4444 ',
#     'address': {'address1': '341 S. Birdneck Road',
#      'address2': None,
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'postcode': '23451',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395823'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/va284'}}},
#   {'id': 59395822,
#    'organization_id': 'VA284',
#    'url': 'https://www.petfinder.com/dog/2301-1510-revel-59395822/va/virginia-beach/virginia-beach-animal-care-and-adoption-center-va284/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': '2301-1510 Revel',
#    'description': 'Revel came in as a stray and was never reclaimed. This big kid is now looking for a new home....',
#    'organization_animal_id': '18931337',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:50:30+0000',
#    'published_at': '2023-01-09T22:50:29+0000',
#    'distance': None,
#    'contact': {'email': 'vbpdac@vbgov.com',
#     'phone': '757-385-4444 ',
#     'address': {'address1': '341 S. Birdneck Road',
#      'address2': None,
#      'city': 'Virginia Beach',
#      'state': 'VA',
#      'postcode': '23451',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395822'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/va284'}}},
#   {'id': 59395821,
#    'organization_id': 'PA497',
#    'url': 'https://www.petfinder.com/cat/betz-59395821/pa/pittsburgh/animal-care-and-welfare-inc-pa497/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Tuxedo',
#     'secondary': 'Domestic Short Hair',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black & White / Tuxedo',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': ['Friendly',
#     'Gentle',
#     'Playful',
#     'Quiet',
#     'Curious',
#     'Brave',
#     'Loves kisses'],
#    'name': 'Betz',
#    'description': 'Betz is a cutie ready for adoption at 10 weeks old. She is curious, playful and cuddly.  Betz will love...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/1/?bust=1673304686&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/1/?bust=1673304686&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/1/?bust=1673304686&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/1/?bust=1673304686'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/3/?bust=1673304687&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/3/?bust=1673304687&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/3/?bust=1673304687&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/3/?bust=1673304687'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59395821/2/?bust=1673304687'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:50:21+0000',
#    'published_at': '2023-01-09T22:50:17+0000',
#    'distance': None,
#    'contact': {'email': 'animalcareandwelfare@yahoo.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Pittsburgh',
#      'state': 'PA',
#      'postcode': '15218',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395821'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/pa497'}}},
#   {'id': 59395820,
#    'organization_id': 'CA1164',
#    'url': 'https://www.petfinder.com/dog/bako-59395820/ca/monterey/the-spca-for-monterey-county-ca1164/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Australian Shepherd',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Bako',
#    'description': 'Hi humans, my name is Bako. I came to the SPCA because my previous owners could no longer afford to...',
#    'organization_animal_id': '146751',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:49:54+0000',
#    'published_at': '2023-01-09T22:49:53+0000',
#    'distance': None,
#    'contact': {'email': 'info@SPCAmc.org',
#     'phone': '831-373-2631',
#     'address': {'address1': '1002 Highway 68',
#      'address2': None,
#      'city': 'Monterey',
#      'state': 'CA',
#      'postcode': '93940',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395820'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca1164'}}},
#   {'id': 59395818,
#    'organization_id': 'TX424',
#    'url': 'https://www.petfinder.com/dog/a603243-59395818/tx/houston/harris-county-pets-tx424/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'German Shepherd Dog',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A603243',
#    'description': None,
#    'organization_animal_id': 'A603243',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:49:51+0000',
#    'published_at': '2023-01-09T22:49:50+0000',
#    'distance': None,
#    'contact': {'email': 'webmaster@countypets.com',
#     'phone': '(281) 999-3191',
#     'address': {'address1': '612 Canino Rd',
#      'address2': None,
#      'city': 'Houston',
#      'state': 'TX',
#      'postcode': '77076',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395818'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx424'}}},
#   {'id': 59395812,
#    'organization_id': 'TX424',
#    'url': 'https://www.petfinder.com/dog/a603246-59395812/tx/houston/harris-county-pets-tx424/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'German Shepherd Dog',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A603246',
#    'description': None,
#    'organization_animal_id': 'A603246',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-09T22:49:50+0000',
#    'published_at': '2023-01-09T22:49:49+0000',
#    'distance': None,
#    'contact': {'email': 'webmaster@countypets.com',
#     'phone': '(281) 999-3191',
#     'address': {'address1': '612 Canino Rd',
#      'address2': None,
#      'city': 'Houston',
#      'state': 'TX',
#      'postcode': '77076',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59395812'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx424'}}}],
#  'pagination': {'count_per_page': 100,
#   'total_count': 252465,
#   'current_page': 1,
#   'total_pages': 2525,
#   '_links': {'next': {'href': '/v2/animals?limit=100&page=2'}}}}

# %%
response.keys()
# Out:
# dict_keys(['animals', 'pagination'])

# %%
df = pd.DataFrame(response['animals'])
df.head()
# Out:
#          id organization_id  \
# 0  59395942           CA765
# 1  59395940           GA697
# 2  59395938           VA789
# 3  59395939           KY102
# 4  59395929           FL275
#
#                                                  url type species  \
# 0  https://www.petfinder.com/dog/champy-59395942/...  Dog     Dog
# 1  https://www.petfinder.com/cat/wonder-59395940/...  Cat     Cat
# 2  https://www.petfinder.com/dog/cassie-59395938/...  Dog     Dog
# 3  https://www.petfinder.com/cat/miracle-59395939...  Cat     Cat
# 4  https://www.petfinder.com/dog/a506253-59395929...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Mixed Breed', 'secondary': None, ...
# 1  {'primary': 'Siamese', 'secondary': 'Domestic ...
# 2  {'primary': 'Terrier', 'secondary': 'Hound', '...
# 3  {'primary': 'Domestic Short Hair', 'secondary'...
# 4  {'primary': 'Beagle', 'secondary': 'Pointer', ...
#
#                                               colors    age  gender    size  \
# 0  {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 1  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2  {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 3  {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 4  {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
#
#    ... organization_animal_id photos primary_photo_cropped videos     status  \
# 0  ...               A1963702     []                  None     []  adoptable
# 1  ...      ps_1609302-702299     []                  None     []  adoptable
# 2  ...                   None     []                  None     []  adoptable
# 3  ...                A725889     []                  None     []  adoptable
# 4  ...                A506253     []                  None     []  adoptable
#
#           status_changed_at              published_at distance  \
# 0  2023-01-09T22:57:19+0000  2023-01-09T22:57:18+0000     None
# 1  2023-01-09T22:57:06+0000  2023-01-09T22:57:05+0000     None
# 2  2023-01-09T22:57:00+0000  2023-01-09T22:56:59+0000     None
# 3  2023-01-09T22:56:59+0000  2023-01-09T22:56:58+0000     None
# 4  2023-01-09T22:56:55+0000  2023-01-09T22:56:54+0000     None
#
#                                              contact  \
# 0  {'email': None, 'phone': '(213) 485-8405', 'ad...
# 1  {'email': 'adoptions@gahomelesspets.com', 'pho...
# 2  {'email': 'allfuranimalsrescue@gmail.com', 'ph...
# 3  {'email': 'AnimalServicesAdoption@louisvilleky...
# 4  {'email': 'AnimalServices@ocfl.net', 'phone': ...
#
#                                               _links
# 0  {'self': {'href': '/v2/animals/59395942'}, 'ty...
# 1  {'self': {'href': '/v2/animals/59395940'}, 'ty...
# 2  {'self': {'href': '/v2/animals/59395938'}, 'ty...
# 3  {'self': {'href': '/v2/animals/59395939'}, 'ty...
# 4  {'self': {'href': '/v2/animals/59395929'}, 'ty...
#
# [5 rows x 26 columns]

# %%
# Breaking out the primary,secondary and mixed (T/F) breeds from the tuple in df column 'breeds'
primary_breeds_dict = {}
primary_breeds = []
secondary_breeds_dict = {}
secondary_breeds = []
mixed_breeds_dict = {}
mixed_breeds = []

for x,y in zip(df['breeds'],df['id']):
#     print(x,y)
    primary_breeds_dict = {'id':y}
    secondary_breeds_dict = {'id':y}
    mixed_breeds_dict = {'id':y}
    if 'primary' in x:
        primary_breeds_dict['primary'] =x['primary']
#         print(primary_breeds_dict)
        primary_breeds.append(primary_breeds_dict)
    if 'secondary' in x:
        secondary_breeds_dict['secondary'] =x['secondary']
        secondary_breeds.append(secondary_breeds_dict) 
    if 'mixed' in x:
        mixed_breeds_dict['mixed'] =x['mixed']
        mixed_breeds.append(mixed_breeds_dict) 
# print(breeds)
breed_1_df = pd.DataFrame(primary_breeds)
breed_2_df = pd.DataFrame(secondary_breeds)
breed_3_df = pd.DataFrame(mixed_breeds)

df_breeds_incorp = df.merge(breed_1_df,on='id').merge(breed_2_df,on='id').merge(breed_3_df,on='id')
# df_breeds_incorp.dtypes
df_breeds_incorp
# Out:
#           id organization_id  \
# 0   59395942           CA765
# 1   59395940           GA697
# 2   59395938           VA789
# 3   59395939           KY102
# 4   59395929           FL275
# ..       ...             ...
# 95  59395822           VA284
# 96  59395821           PA497
# 97  59395820          CA1164
# 98  59395818           TX424
# 99  59395812           TX424
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/champy-59395942/...  Dog     Dog
# 1   https://www.petfinder.com/cat/wonder-59395940/...  Cat     Cat
# 2   https://www.petfinder.com/dog/cassie-59395938/...  Dog     Dog
# 3   https://www.petfinder.com/cat/miracle-59395939...  Cat     Cat
# 4   https://www.petfinder.com/dog/a506253-59395929...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/dog/2301-1510-revel-...  Dog     Dog
# 96  https://www.petfinder.com/cat/betz-59395821/pa...  Cat     Cat
# 97  https://www.petfinder.com/dog/bako-59395820/ca...  Dog     Dog
# 98  https://www.petfinder.com/dog/a603243-59395818...  Dog     Dog
# 99  https://www.petfinder.com/dog/a603246-59395812...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Mixed Breed', 'secondary': None, ...
# 1   {'primary': 'Siamese', 'secondary': 'Domestic ...
# 2   {'primary': 'Terrier', 'secondary': 'Hound', '...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'Beagle', 'secondary': 'Pointer', ...
# ..                                                ...
# 95  {'primary': 'Pit Bull Terrier', 'secondary': N...
# 96  {'primary': 'Tuxedo', 'secondary': 'Domestic S...
# 97  {'primary': 'Australian Shepherd', 'secondary'...
# 98  {'primary': 'German Shepherd Dog', 'secondary'...
# 99  {'primary': 'German Shepherd Dog', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 1   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2   {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 3   {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 4   {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# ..                                                ...    ...     ...     ...
# 95  {'primary': None, 'secondary': None, 'tertiary...  Young    Male  Medium
# 96  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby  Female   Small
# 97  {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 98  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 99  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
#
#     ... videos     status         status_changed_at              published_at  \
# 0   ...     []  adoptable  2023-01-09T22:57:19+0000  2023-01-09T22:57:18+0000
# 1   ...     []  adoptable  2023-01-09T22:57:06+0000  2023-01-09T22:57:05+0000
# 2   ...     []  adoptable  2023-01-09T22:57:00+0000  2023-01-09T22:56:59+0000
# 3   ...     []  adoptable  2023-01-09T22:56:59+0000  2023-01-09T22:56:58+0000
# 4   ...     []  adoptable  2023-01-09T22:56:55+0000  2023-01-09T22:56:54+0000
# ..  ...    ...        ...                       ...                       ...
# 95  ...     []  adoptable  2023-01-09T22:50:30+0000  2023-01-09T22:50:29+0000
# 96  ...     []  adoptable  2023-01-09T22:50:21+0000  2023-01-09T22:50:17+0000
# 97  ...     []  adoptable  2023-01-09T22:49:54+0000  2023-01-09T22:49:53+0000
# 98  ...     []  adoptable  2023-01-09T22:49:51+0000  2023-01-09T22:49:50+0000
# 99  ...     []  adoptable  2023-01-09T22:49:50+0000  2023-01-09T22:49:49+0000
#
#    distance                                            contact  \
# 0      None  {'email': None, 'phone': '(213) 485-8405', 'ad...
# 1      None  {'email': 'adoptions@gahomelesspets.com', 'pho...
# 2      None  {'email': 'allfuranimalsrescue@gmail.com', 'ph...
# 3      None  {'email': 'AnimalServicesAdoption@louisvilleky...
# 4      None  {'email': 'AnimalServices@ocfl.net', 'phone': ...
# ..      ...                                                ...
# 95     None  {'email': 'vbpdac@vbgov.com', 'phone': '757-38...
# 96     None  {'email': 'animalcareandwelfare@yahoo.com', 'p...
# 97     None  {'email': 'info@SPCAmc.org', 'phone': '831-373...
# 98     None  {'email': 'webmaster@countypets.com', 'phone':...
# 99     None  {'email': 'webmaster@countypets.com', 'phone':...
#
#                                                _links              primary  \
# 0   {'self': {'href': '/v2/animals/59395942'}, 'ty...          Mixed Breed
# 1   {'self': {'href': '/v2/animals/59395940'}, 'ty...              Siamese
# 2   {'self': {'href': '/v2/animals/59395938'}, 'ty...              Terrier
# 3   {'self': {'href': '/v2/animals/59395939'}, 'ty...  Domestic Short Hair
# 4   {'self': {'href': '/v2/animals/59395929'}, 'ty...               Beagle
# ..                                                ...                  ...
# 95  {'self': {'href': '/v2/animals/59395822'}, 'ty...     Pit Bull Terrier
# 96  {'self': {'href': '/v2/animals/59395821'}, 'ty...               Tuxedo
# 97  {'self': {'href': '/v2/animals/59395820'}, 'ty...  Australian Shepherd
# 98  {'self': {'href': '/v2/animals/59395818'}, 'ty...  German Shepherd Dog
# 99  {'self': {'href': '/v2/animals/59395812'}, 'ty...  German Shepherd Dog
#
#               secondary  mixed
# 0                  None  False
# 1   Domestic Short Hair   True
# 2                 Hound   True
# 3                  None  False
# 4               Pointer   True
# ..                  ...    ...
# 95                 None  False
# 96  Domestic Short Hair   True
# 97                 None   True
# 98          Mixed Breed   True
# 99                 None  False
#
# [100 rows x 29 columns]

# %%
# Breaking out the address from the contact info nested dict into a dataframe and joining to breeds
address1_dict = {}

address_df = pd.DataFrame()

for x,y in zip(df['contact'],df['id']):
#     print(x,y)
    address1_dict = {'id':y}
    if 'address' in x:
        address1_dict['address'] =x['address']
#         print(address1_dict)
        test_df = pd.DataFrame(pd.json_normalize(address1_dict))
        address_df = address_df.append(test_df)
address_df.dtypes
address_and_breeds_df = df_breeds_incorp.merge(address_df,left_on='id',right_on='id')

# Most current df with relevant data
address_and_breeds_df
# Out:
#           id organization_id  \
# 0   59395942           CA765
# 1   59395940           GA697
# 2   59395938           VA789
# 3   59395939           KY102
# 4   59395929           FL275
# ..       ...             ...
# 95  59395822           VA284
# 96  59395821           PA497
# 97  59395820          CA1164
# 98  59395818           TX424
# 99  59395812           TX424
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/champy-59395942/...  Dog     Dog
# 1   https://www.petfinder.com/cat/wonder-59395940/...  Cat     Cat
# 2   https://www.petfinder.com/dog/cassie-59395938/...  Dog     Dog
# 3   https://www.petfinder.com/cat/miracle-59395939...  Cat     Cat
# 4   https://www.petfinder.com/dog/a506253-59395929...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/dog/2301-1510-revel-...  Dog     Dog
# 96  https://www.petfinder.com/cat/betz-59395821/pa...  Cat     Cat
# 97  https://www.petfinder.com/dog/bako-59395820/ca...  Dog     Dog
# 98  https://www.petfinder.com/dog/a603243-59395818...  Dog     Dog
# 99  https://www.petfinder.com/dog/a603246-59395812...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Mixed Breed', 'secondary': None, ...
# 1   {'primary': 'Siamese', 'secondary': 'Domestic ...
# 2   {'primary': 'Terrier', 'secondary': 'Hound', '...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'Beagle', 'secondary': 'Pointer', ...
# ..                                                ...
# 95  {'primary': 'Pit Bull Terrier', 'secondary': N...
# 96  {'primary': 'Tuxedo', 'secondary': 'Domestic S...
# 97  {'primary': 'Australian Shepherd', 'secondary'...
# 98  {'primary': 'German Shepherd Dog', 'secondary'...
# 99  {'primary': 'German Shepherd Dog', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 1   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2   {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 3   {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 4   {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# ..                                                ...    ...     ...     ...
# 95  {'primary': None, 'secondary': None, 'tertiary...  Young    Male  Medium
# 96  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby  Female   Small
# 97  {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 98  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 99  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
#
#     ...                                             _links  \
# 0   ...  {'self': {'href': '/v2/animals/59395942'}, 'ty...
# 1   ...  {'self': {'href': '/v2/animals/59395940'}, 'ty...
# 2   ...  {'self': {'href': '/v2/animals/59395938'}, 'ty...
# 3   ...  {'self': {'href': '/v2/animals/59395939'}, 'ty...
# 4   ...  {'self': {'href': '/v2/animals/59395929'}, 'ty...
# ..  ...                                                ...
# 95  ...  {'self': {'href': '/v2/animals/59395822'}, 'ty...
# 96  ...  {'self': {'href': '/v2/animals/59395821'}, 'ty...
# 97  ...  {'self': {'href': '/v2/animals/59395820'}, 'ty...
# 98  ...  {'self': {'href': '/v2/animals/59395818'}, 'ty...
# 99  ...  {'self': {'href': '/v2/animals/59395812'}, 'ty...
#
#                 primary            secondary  mixed      address.address1  \
# 0           Mixed Breed                 None  False  20655 Plummer Street
# 1               Siamese  Domestic Short Hair   True                  None
# 2               Terrier                Hound   True                  None
# 3   Domestic Short Hair                 None  False     3528 Newburg Road
# 4                Beagle              Pointer   True      2769 Conroy Road
# ..                  ...                  ...    ...                   ...
# 95     Pit Bull Terrier                 None  False  341 S. Birdneck Road
# 96               Tuxedo  Domestic Short Hair   True                  None
# 97  Australian Shepherd                 None   True       1002 Highway 68
# 98  German Shepherd Dog          Mixed Breed   True         612 Canino Rd
# 99  German Shepherd Dog                 None  False         612 Canino Rd
#
#    address.address2    address.city address.state address.postcode  \
# 0              None      Chatsworth            CA            91311
# 1              None  Powder Springs            GA            30127
# 2              None      Unionville            VA            22567
# 3              None      Louisville            KY            40218
# 4              None         Orlando            FL            32839
# ..              ...             ...           ...              ...
# 95             None  Virginia Beach            VA            23451
# 96             None      Pittsburgh            PA            15218
# 97             None        Monterey            CA            93940
# 98             None         Houston            TX            77076
# 99             None         Houston            TX            77076
#
#    address.country
# 0               US
# 1               US
# 2               US
# 3               US
# 4               US
# ..             ...
# 95              US
# 96              US
# 97              US
# 98              US
# 99              US
#
# [100 rows x 35 columns]

# %%
photo_dict = []
photo_df = pd.DataFrame()
test = {}
for x,y in zip(df['photos'],df['id']):
#     print(x,y)
    photo_dict = {'id':y,'photos':x}
    pd.json_normalize(photo_dict)
#     print(photo_dict)
    for i in photo_dict['photos']:
        temp_photo_dict = {'id':y,'small_photo': i['small'],'medium_photo': i['medium'],'large_photo': i['large']}
#         print(test)
        df_photos = pd.DataFrame(pd.json_normalize(temp_photo_dict))
        photo_df = photo_df.append(df_photos)
photo_df

# merging the breeds and address df to the photos df - this is the final cleaned df
cleaned_pet_df = address_and_breeds_df.merge(photo_df,how='left',left_on='id',right_on='id')
cleaned_pet_df
# Out:
#            id organization_id  \
# 0    59395942           CA765
# 1    59395940           GA697
# 2    59395938           VA789
# 3    59395939           KY102
# 4    59395929           FL275
# ..        ...             ...
# 120  59395821           PA497
# 121  59395821           PA497
# 122  59395820          CA1164
# 123  59395818           TX424
# 124  59395812           TX424
#
#                                                    url type species  \
# 0    https://www.petfinder.com/dog/champy-59395942/...  Dog     Dog
# 1    https://www.petfinder.com/cat/wonder-59395940/...  Cat     Cat
# 2    https://www.petfinder.com/dog/cassie-59395938/...  Dog     Dog
# 3    https://www.petfinder.com/cat/miracle-59395939...  Cat     Cat
# 4    https://www.petfinder.com/dog/a506253-59395929...  Dog     Dog
# ..                                                 ...  ...     ...
# 120  https://www.petfinder.com/cat/betz-59395821/pa...  Cat     Cat
# 121  https://www.petfinder.com/cat/betz-59395821/pa...  Cat     Cat
# 122  https://www.petfinder.com/dog/bako-59395820/ca...  Dog     Dog
# 123  https://www.petfinder.com/dog/a603243-59395818...  Dog     Dog
# 124  https://www.petfinder.com/dog/a603246-59395812...  Dog     Dog
#
#                                                 breeds  \
# 0    {'primary': 'Mixed Breed', 'secondary': None, ...
# 1    {'primary': 'Siamese', 'secondary': 'Domestic ...
# 2    {'primary': 'Terrier', 'secondary': 'Hound', '...
# 3    {'primary': 'Domestic Short Hair', 'secondary'...
# 4    {'primary': 'Beagle', 'secondary': 'Pointer', ...
# ..                                                 ...
# 120  {'primary': 'Tuxedo', 'secondary': 'Domestic S...
# 121  {'primary': 'Tuxedo', 'secondary': 'Domestic S...
# 122  {'primary': 'Australian Shepherd', 'secondary'...
# 123  {'primary': 'German Shepherd Dog', 'secondary'...
# 124  {'primary': 'German Shepherd Dog', 'secondary'...
#
#                                                 colors    age  gender    size  \
# 0    {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 1    {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2    {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 3    {'primary': None, 'secondary': None, 'tertiary...  Young  Female  Medium
# 4    {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# ..                                                 ...    ...     ...     ...
# 120  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby  Female   Small
# 121  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby  Female   Small
# 122  {'primary': None, 'secondary': None, 'tertiary...  Adult    Male  Medium
# 123  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 124  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
#
#      ...  mixed      address.address1 address.address2    address.city  \
# 0    ...  False  20655 Plummer Street             None      Chatsworth
# 1    ...   True                  None             None  Powder Springs
# 2    ...   True                  None             None      Unionville
# 3    ...  False     3528 Newburg Road             None      Louisville
# 4    ...   True      2769 Conroy Road             None         Orlando
# ..   ...    ...                   ...              ...             ...
# 120  ...   True                  None             None      Pittsburgh
# 121  ...   True                  None             None      Pittsburgh
# 122  ...   True       1002 Highway 68             None        Monterey
# 123  ...   True         612 Canino Rd             None         Houston
# 124  ...  False         612 Canino Rd             None         Houston
#
#     address.state address.postcode address.country  \
# 0              CA            91311              US
# 1              GA            30127              US
# 2              VA            22567              US
# 3              KY            40218              US
# 4              FL            32839              US
# ..            ...              ...             ...
# 120            PA            15218              US
# 121            PA            15218              US
# 122            CA            93940              US
# 123            TX            77076              US
# 124            TX            77076              US
#
#                                            small_photo  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 120  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 121  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#                                           medium_photo  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 120  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 121  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#                                            large_photo
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 120  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 121  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
# [125 rows x 38 columns]

# %%
# Cleaning the final DF to only the data we need
cleaned_pet_df.head()
cleaned_pet_df.dtypes
cleaned_pet_df = cleaned_pet_df.rename(columns={'address.address1':'address1',"address.address2":"address2",'address.city':"city",
                              "address.state":'state',"address.postcode":"zip","address.country":"country"
                              })
cleaned_pet_df = cleaned_pet_df[['id','url','age','gender','name','description','status','status_changed_at'
                                ,'published_at','primary','secondary','mixed','address1','address2','city','state',
                                 'zip','country','small_photo','medium_photo','large_photo'
                                ]]
cleaned_pet_df
# Out:
#            id                                                url    age  \
# 0    59395942  https://www.petfinder.com/dog/champy-59395942/...  Adult
# 1    59395940  https://www.petfinder.com/cat/wonder-59395940/...   Baby
# 2    59395938  https://www.petfinder.com/dog/cassie-59395938/...  Young
# 3    59395939  https://www.petfinder.com/cat/miracle-59395939...  Young
# 4    59395929  https://www.petfinder.com/dog/a506253-59395929...  Adult
# ..        ...                                                ...    ...
# 120  59395821  https://www.petfinder.com/cat/betz-59395821/pa...   Baby
# 121  59395821  https://www.petfinder.com/cat/betz-59395821/pa...   Baby
# 122  59395820  https://www.petfinder.com/dog/bako-59395820/ca...  Adult
# 123  59395818  https://www.petfinder.com/dog/a603243-59395818...   Baby
# 124  59395812  https://www.petfinder.com/dog/a603246-59395812...   Baby
#
#      gender     name                                        description  \
# 0      Male   CHAMPY                                               None
# 1    Female   Wonder                                               None
# 2    Female   Cassie  This sweet mama came to rescue with a litter o...
# 3    Female  MIRACLE                                               None
# 4      Male  A506253                                               None
# ..      ...      ...                                                ...
# 120  Female     Betz  Betz is a cutie ready for adoption at 10 weeks...
# 121  Female     Betz  Betz is a cutie ready for adoption at 10 weeks...
# 122    Male     Bako  Hi humans, my name is Bako. I came to the SPCA...
# 123  Female  A603243                                               None
# 124  Female  A603246                                               None
#
#         status         status_changed_at              published_at  \
# 0    adoptable  2023-01-09T22:57:19+0000  2023-01-09T22:57:18+0000
# 1    adoptable  2023-01-09T22:57:06+0000  2023-01-09T22:57:05+0000
# 2    adoptable  2023-01-09T22:57:00+0000  2023-01-09T22:56:59+0000
# 3    adoptable  2023-01-09T22:56:59+0000  2023-01-09T22:56:58+0000
# 4    adoptable  2023-01-09T22:56:55+0000  2023-01-09T22:56:54+0000
# ..         ...                       ...                       ...
# 120  adoptable  2023-01-09T22:50:21+0000  2023-01-09T22:50:17+0000
# 121  adoptable  2023-01-09T22:50:21+0000  2023-01-09T22:50:17+0000
# 122  adoptable  2023-01-09T22:49:54+0000  2023-01-09T22:49:53+0000
# 123  adoptable  2023-01-09T22:49:51+0000  2023-01-09T22:49:50+0000
# 124  adoptable  2023-01-09T22:49:50+0000  2023-01-09T22:49:49+0000
#
#                  primary  ...  mixed              address1 address2  \
# 0            Mixed Breed  ...  False  20655 Plummer Street     None
# 1                Siamese  ...   True                  None     None
# 2                Terrier  ...   True                  None     None
# 3    Domestic Short Hair  ...  False     3528 Newburg Road     None
# 4                 Beagle  ...   True      2769 Conroy Road     None
# ..                   ...  ...    ...                   ...      ...
# 120               Tuxedo  ...   True                  None     None
# 121               Tuxedo  ...   True                  None     None
# 122  Australian Shepherd  ...   True       1002 Highway 68     None
# 123  German Shepherd Dog  ...   True         612 Canino Rd     None
# 124  German Shepherd Dog  ...  False         612 Canino Rd     None
#
#                city state    zip country  \
# 0        Chatsworth    CA  91311      US
# 1    Powder Springs    GA  30127      US
# 2        Unionville    VA  22567      US
# 3        Louisville    KY  40218      US
# 4           Orlando    FL  32839      US
# ..              ...   ...    ...     ...
# 120      Pittsburgh    PA  15218      US
# 121      Pittsburgh    PA  15218      US
# 122        Monterey    CA  93940      US
# 123         Houston    TX  77076      US
# 124         Houston    TX  77076      US
#
#                                            small_photo  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 120  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 121  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#                                           medium_photo  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 120  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 121  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
#                                            large_photo
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 120  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 121  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
#
# [125 rows x 21 columns]
