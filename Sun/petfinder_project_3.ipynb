# %%
# checking to see what the version of pandas i have for petpy
# !pip install petpy
# import pandas as pd
# pd.__version__

# %%
# upgrades to the lastest version of pandas
# !pip install -U pandas --user

# %%
# pd.__version__

# %%
import requests
import json
import pandas as pd
import petpy

# %%
key ="cKesBThlyw3n6lxFW4AXbsntBRK0CLEbAC5yzv6m4kZjjUYrp7"
secret ="Kbmyyp9Tkd3pWPT4NRorK5m7RrU7QOe1CWkGpHeA"
url = "https://api.petfinder.com/v2/oauth2/token"

# %%
# gets the access token using credentials
def get_access_token(url, client_id, client_secret):
    response = requests.post(
        url,
        data={"grant_type": "client_credentials"},
        auth=(key, secret),
    )
    return response.json()["access_token"]



token = get_access_token(url,key,secret)
get_access_token(url,key,secret)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..NTa8Pg3BWSVM0cMNi5ND3_5fG48ddtFaMAgP36pF3I4lOcSGFeBNitr_dEmCcALoy-Wsaa_d6v0opWeNiqOMelsNq07xPHeHmWCXQuWbffvt2EQCX6i6mp_sV5nMx0e9WvIJckxHMu5jdC0nHOGpD2-kxo3My-2LGXkZDxrUsyKg3FLwPE9yktNpHd5OhBDhpgQJTq5IaTV5C86pIrZkVlU7J3KM4csPCLVzmsoY3mezIC2kG8IzqctDefqbCRXjhHsXgLUnqJRoYq8xpMy_zxBRGppLef7kvq3zO38LGpKgectv2v-LZJi4iDTVX0yT7V4VWB4qKatyhfmW9pxK-w'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }

param = {
   "page": 1,
    "limit": 100
    #these are not indented, so no problem there.
    }#close param

response = requests.get('https://api.petfinder.com/v2/animals', headers=headers, 
        params=param)
response = response.json()
response
# Out:
# {'animals': [{'id': 59396845,
#    'organization_id': 'MI363',
#    'url': 'https://www.petfinder.com/cat/rafiq-59396845/mi/wyandotte/wyandotte-animal-adoption-center-mi363/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black & White / Tuxedo',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': ['Playful', 'Smart', 'Funny'],
#    'name': 'RAFIQ',
#    'description': 'Rafiq and his sister were found outside in rough shape, but thanks to the care of a medical foster home,...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/1/?bust=1673311029&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/1/?bust=1673311029&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/1/?bust=1673311029&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/1/?bust=1673311029'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/3/?bust=1673311031&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/3/?bust=1673311031&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/3/?bust=1673311031&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/3/?bust=1673311031'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/4/?bust=1673311031&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/4/?bust=1673311031&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/4/?bust=1673311031&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/4/?bust=1673311031'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/5/?bust=1673311032&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/5/?bust=1673311032&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/5/?bust=1673311032&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/5/?bust=1673311032'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396845/2/?bust=1673311030'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:37:14+0000',
#    'published_at': '2023-01-10T00:37:13+0000',
#    'distance': None,
#    'contact': {'email': 'wacvolunteers@gmail.com',
#     'phone': None,
#     'address': {'address1': '1170 GROVE STREET',
#      'address2': None,
#      'city': 'Wyandotte',
#      'state': 'MI',
#      'postcode': '48192',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396845'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/mi363'}}},
#   {'id': 59396843,
#    'organization_id': 'CO316',
#    'url': 'https://www.petfinder.com/cat/mrs-puff-59396843/co/denver/dumb-friends-league-co316/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Medium Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'MRS. PUFF',
#    'description': None,
#    'organization_animal_id': 'A0885368',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:37:01+0000',
#    'published_at': '2023-01-10T00:37:00+0000',
#    'distance': None,
#    'contact': {'email': 'customercare@ddfl.org',
#     'phone': '303-751-5772  ',
#     'address': {'address1': '2080 S. Quebec St.',
#      'address2': None,
#      'city': 'Denver',
#      'state': 'CO',
#      'postcode': '80231',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396843'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/co316'}}},
#   {'id': 59396831,
#    'organization_id': 'GA680',
#    'url': 'https://www.petfinder.com/dog/chloe-59396831/ga/atlanta/orphan-annie-rescue-ga680/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Cavachon',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Chloe',
#    'description': 'Chloe is a shy but cuddly 13 lb, 8 mo old girl who recently came to us from a breeder...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/1/?bust=1673311006&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/1/?bust=1673311006&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/1/?bust=1673311006&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/1/?bust=1673311006'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/2/?bust=1673311009&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/2/?bust=1673311009&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/2/?bust=1673311009&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/2/?bust=1673311009'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/4/?bust=1673311014&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/4/?bust=1673311014&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/4/?bust=1673311014&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/4/?bust=1673311014'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396831/3/?bust=1673311011'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:56+0000',
#    'published_at': '2023-01-10T00:36:55+0000',
#    'distance': None,
#    'contact': {'email': 'orphanannierescue@gmail.com',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Atlanta',
#      'state': 'GA',
#      'postcode': '30350',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396831'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ga680'}}},
#   {'id': 59396829,
#    'organization_id': 'TX2322',
#    'url': 'https://www.petfinder.com/cat/birdie-59396829/tx/schertz/city-of-schertz-tx2322/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': None, 'cats': True},
#    'tags': ['Friendly',
#     'Affectionate',
#     'Gentle',
#     'Loves kisses',
#     'Couch potato',
#     'Quiet'],
#    'name': 'Birdie',
#    'description': None,
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/2/?bust=1673311003&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/2/?bust=1673311003&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/2/?bust=1673311003&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/2/?bust=1673311003'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/3/?bust=1673311003&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/3/?bust=1673311003&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/3/?bust=1673311003&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/3/?bust=1673311003'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/4/?bust=1673311004&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/4/?bust=1673311004&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/4/?bust=1673311004&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/4/?bust=1673311004'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/5/?bust=1673311005&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/5/?bust=1673311005&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/5/?bust=1673311005&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/5/?bust=1673311005'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396829/1/?bust=1673311002'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:47+0000',
#    'published_at': '2023-01-10T00:36:46+0000',
#    'distance': None,
#    'contact': {'email': 'AnimalServices@Schertz.com',
#     'phone': '(210) 619-1550',
#     'address': {'address1': '800 Community Circle',
#      'address2': None,
#      'city': 'Schertz',
#      'state': 'TX',
#      'postcode': '78154',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396829'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx2322'}}},
#   {'id': 59396828,
#    'organization_id': 'NC965',
#    'url': 'https://www.petfinder.com/dog/sky-59396828/nc/pittsboro/farm-friends-rescue-nc965/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Chihuahua',
#     'secondary': 'Dachshund',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Brown / Chocolate',
#     'tertiary': 'White / Cream'},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Sky',
#    'description': 'Sky is a very sweet little girl.  She loves to snuggle.  She also loves to play with her brothers. She...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/2/?bust=1673311000&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/2/?bust=1673311000&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/2/?bust=1673311000&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/2/?bust=1673311000'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/3/?bust=1673311000&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/3/?bust=1673311000&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/3/?bust=1673311000&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/3/?bust=1673311000'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396828/1/?bust=1673310998'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:42+0000',
#    'published_at': '2023-01-10T00:36:41+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@farmfriendsrescue.org',
#     'phone': None,
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Pittsboro',
#      'state': 'NC',
#      'postcode': '27312',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396828'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/nc965'}}},
#   {'id': 59396823,
#    'organization_id': 'NV39',
#    'url': 'https://www.petfinder.com/small-furry/pumpkin-59396823/nv/las-vegas/nevada-society-for-the-prevention-of-cruelty-to-animals-nevada-spca-nv39/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Small & Furry',
#    'species': 'Guinea Pig',
#    'breeds': {'primary': 'Guinea Pig',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': ['Bonded'],
#    'name': 'PUMPKIN',
#    'description': 'Pumpkin and Skunk are a bonded pair of female guinea pigs. They are looking for a new loving home together.',
#    'organization_animal_id': 'LVS-A-1596',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:32+0000',
#    'published_at': '2023-01-10T00:36:31+0000',
#    'distance': None,
#    'contact': {'email': 'info@nevadaspca.org',
#     'phone': '(702) 873-7722',
#     'address': {'address1': '5375 Procyon Street, Suite 108',
#      'address2': None,
#      'city': 'Las Vegas',
#      'state': 'NV',
#      'postcode': '89118',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396823'},
#     'type': {'href': '/v2/types/small-furry'},
#     'organization': {'href': '/v2/organizations/nv39'}}},
#   {'id': 59396824,
#    'organization_id': 'NV39',
#    'url': 'https://www.petfinder.com/small-furry/coco-59396824/nv/las-vegas/nevada-society-for-the-prevention-of-cruelty-to-animals-nevada-spca-nv39/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Small & Furry',
#    'species': 'Guinea Pig',
#    'breeds': {'primary': 'Guinea Pig',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': ['Bonded'],
#    'name': 'COCO',
#    'description': 'Smorey and Coco are a pair of friendly, bonded female guinea pigs. They are looking for a loving new home...',
#    'organization_animal_id': 'LVS-A-1001',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:32+0000',
#    'published_at': '2023-01-10T00:36:31+0000',
#    'distance': None,
#    'contact': {'email': 'info@nevadaspca.org',
#     'phone': '(702) 873-7722',
#     'address': {'address1': '5375 Procyon Street, Suite 108',
#      'address2': None,
#      'city': 'Las Vegas',
#      'state': 'NV',
#      'postcode': '89118',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396824'},
#     'type': {'href': '/v2/types/small-furry'},
#     'organization': {'href': '/v2/organizations/nv39'}}},
#   {'id': 59396825,
#    'organization_id': 'NV39',
#    'url': 'https://www.petfinder.com/small-furry/smorey-59396825/nv/las-vegas/nevada-society-for-the-prevention-of-cruelty-to-animals-nevada-spca-nv39/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Small & Furry',
#    'species': 'Guinea Pig',
#    'breeds': {'primary': 'Guinea Pig',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': ['Bonded'],
#    'name': 'SMOREY',
#    'description': 'Smorey and Coco are a pair of friendly, bonded female guinea pigs. They are looking for a loving new home...',
#    'organization_animal_id': 'LVS-A-1000',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:32+0000',
#    'published_at': '2023-01-10T00:36:31+0000',
#    'distance': None,
#    'contact': {'email': 'info@nevadaspca.org',
#     'phone': '(702) 873-7722',
#     'address': {'address1': '5375 Procyon Street, Suite 108',
#      'address2': None,
#      'city': 'Las Vegas',
#      'state': 'NV',
#      'postcode': '89118',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396825'},
#     'type': {'href': '/v2/types/small-furry'},
#     'organization': {'href': '/v2/organizations/nv39'}}},
#   {'id': 59396826,
#    'organization_id': 'NV39',
#    'url': 'https://www.petfinder.com/dog/gunner-59396826/nv/las-vegas/nevada-society-for-the-prevention-of-cruelty-to-animals-nevada-spca-nv39/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Caucasian Sheepdog / Caucasian Ovtcharka',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream', 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': False, 'cats': None},
#    'tags': ['Kids six positive',
#     'Single Dog Home',
#     'Toy Driven',
#     'Treat Driven'],
#    'name': 'GUNNER',
#    'description': 'Gunner is a very big and handsome boy that needs a special home. Gunner is a young boy that needs...',
#    'organization_animal_id': 'LVS-A-185',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:32+0000',
#    'published_at': '2023-01-10T00:36:31+0000',
#    'distance': None,
#    'contact': {'email': 'info@nevadaspca.org',
#     'phone': '(702) 873-7722',
#     'address': {'address1': '5375 Procyon Street, Suite 108',
#      'address2': None,
#      'city': 'Las Vegas',
#      'state': 'NV',
#      'postcode': '89118',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396826'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/nv39'}}},
#   {'id': 59396827,
#    'organization_id': 'NV39',
#    'url': 'https://www.petfinder.com/small-furry/skunk-59396827/nv/las-vegas/nevada-society-for-the-prevention-of-cruelty-to-animals-nevada-spca-nv39/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Small & Furry',
#    'species': 'Guinea Pig',
#    'breeds': {'primary': 'Guinea Pig',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': ['Bonded'],
#    'name': 'SKUNK',
#    'description': 'Pumpkin and Skunk are a bonded pair of female guinea pigs. They are looking for a new loving home together.',
#    'organization_animal_id': 'LVS-A-1595',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:32+0000',
#    'published_at': '2023-01-10T00:36:31+0000',
#    'distance': None,
#    'contact': {'email': 'info@nevadaspca.org',
#     'phone': '(702) 873-7722',
#     'address': {'address1': '5375 Procyon Street, Suite 108',
#      'address2': None,
#      'city': 'Las Vegas',
#      'state': 'NV',
#      'postcode': '89118',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396827'},
#     'type': {'href': '/v2/types/small-furry'},
#     'organization': {'href': '/v2/organizations/nv39'}}},
#   {'id': 59396821,
#    'organization_id': 'NJ826',
#    'url': 'https://www.petfinder.com/cat/elton-john-59396821/nj/west-orange/west-orange-tnvr-nj826/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Elton John',
#    'description': 'Elton John is an adorable black male kitten who is looking for his forever home.  His foster family reports that...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396821/1/?bust=1673310973'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:15+0000',
#    'published_at': '2023-01-10T00:36:14+0000',
#    'distance': None,
#    'contact': {'email': 'wotnvr@gmail.com',
#     'phone': '973-324-1346',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'West Orange',
#      'state': 'NJ',
#      'postcode': '07052',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396821'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/nj826'}}},
#   {'id': 59396816,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/spree-8-59396816/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': 'White',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Spree 8',
#    'description': 'Lovey, Bold, Confident\n\nSpree recently earned the nickname &amp;#34;Spree-na Warrior Princess&amp;#34; in her foster home by successfully jumping off a...',
#    'organization_animal_id': 'APA-A-107547',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:08+0000',
#    'published_at': '2023-01-10T00:36:07+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396816'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396817,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/neeps-59396817/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Brittany Spaniel',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream', 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Neeps',
#    'description': 'I&amp;#39;m currently in foster! Submit an adoption inquiry to learn more about me!',
#    'organization_animal_id': 'APA-A-116473',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:08+0000',
#    'published_at': '2023-01-10T00:36:07+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396817'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396818,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/spirit-pup-5-59396818/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Shepherd',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Yellow / Tan / Blond / Fawn',
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Spirit pup 5',
#    'description': None,
#    'organization_animal_id': 'APA-A-115399',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:08+0000',
#    'published_at': '2023-01-10T00:36:07+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396818'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396819,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/kovu-59396819/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Belgian Shepherd / Malinois',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Brindle', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Kovu',
#    'description': None,
#    'organization_animal_id': 'APA-A-116754',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:08+0000',
#    'published_at': '2023-01-10T00:36:07+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396819'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396820,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/spirit-pup-2-59396820/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Shepherd',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Yellow / Tan / Blond / Fawn',
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Spirit pup 2',
#    'description': None,
#    'organization_animal_id': 'APA-A-115396',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:08+0000',
#    'published_at': '2023-01-10T00:36:07+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396820'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396812,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/cinnamon-ranger-59396812/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Brown / Chocolate',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Cinnamon Ranger',
#    'description': 'Loving, Chill, Sweetheart \n\nCinnamon Ranger is in charge of affection maintenance, spreading love and ensuring happiness flourishes. We can tell...',
#    'organization_animal_id': 'APA-A-114283',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:07+0000',
#    'published_at': '2023-01-10T00:36:06+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396812'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396813,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/kite-hill-59396813/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Kite Hill',
#    'description': 'Introducing Kite Hill! This handsome kitty recently arrived to APA! and is the talk of the cattery! We can&amp;#39;t wait...',
#    'organization_animal_id': 'APA-A-116725',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:07+0000',
#    'published_at': '2023-01-10T00:36:06+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396813'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396814,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/miyokos-59396814/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Miyokos',
#    'description': 'Look who&amp;#39;s here, it&amp;#39;s Miyokos! She&amp;#39;s a newcomer to APA! and we can&amp;#39;t wait to get to know her. When...',
#    'organization_animal_id': 'APA-A-116728',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:07+0000',
#    'published_at': '2023-01-10T00:36:06+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396814'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396815,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/tofutti-59396815/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Tofutti',
#    'description': 'Let&amp;#39;s give a big Texas welcome to Tofutti! She&amp;#39;s a recent arrival to APA! and we want to make her...',
#    'organization_animal_id': 'APA-A-116721',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:07+0000',
#    'published_at': '2023-01-10T00:36:06+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396815'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396803,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/san-benito-pup-2-59396803/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'San Benito pup 2',
#    'description': None,
#    'organization_animal_id': 'APA-A-116790',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:06+0000',
#    'published_at': '2023-01-10T00:36:05+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396803'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396804,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/spirit-pup-3-59396804/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Shepherd',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Yellow / Tan / Blond / Fawn',
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Spirit pup 3',
#    'description': None,
#    'organization_animal_id': 'APA-A-115397',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:06+0000',
#    'published_at': '2023-01-10T00:36:05+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396804'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396805,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/daiya-59396805/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Daiya',
#    'description': 'Introducing Daiya! This pretty kitty recently arrived to APA! and is the talk of the cattery! We can&amp;#39;t wait to...',
#    'organization_animal_id': 'APA-A-116726',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:06+0000',
#    'published_at': '2023-01-10T00:36:05+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396805'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396806,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/dog/san-benito-pup-1-59396806/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Labrador Retriever',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'San Benito pup 1',
#    'description': None,
#    'organization_animal_id': 'APA-A-116789',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:06+0000',
#    'published_at': '2023-01-10T00:36:05+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396806'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396807,
#    'organization_id': 'TX1218',
#    'url': 'https://www.petfinder.com/cat/violife-59396807/tx/austin/austin-pets-alive-tx1218/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Gray / Blue / Silver',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Violife',
#    'description': 'Introducing Violife! This handsome kitty recently arrived to APA! and is the talk of the cattery! We can&amp;#39;t wait to...',
#    'organization_animal_id': 'APA-A-116724',
#    'photos': [],
#    'primary_photo_cropped': None,
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:36:06+0000',
#    'published_at': '2023-01-10T00:36:05+0000',
#    'distance': None,
#    'contact': {'email': 'adopt@austinpetsalive.org',
#     'phone': None,
#     'address': {'address1': '1156 West Cesar Chavez',
#      'address2': None,
#      'city': 'Austin',
#      'state': 'TX',
#      'postcode': '78704',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396807'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx1218'}}},
#   {'id': 59396808,
#    'organization_id': 'TX1218',
# ...
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:26:46+0000',
#    'published_at': '2023-01-10T00:26:45+0000',
#    'distance': None,
#    'contact': {'email': 'wotnvr@gmail.com',
#     'phone': '973-324-1346',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'West Orange',
#      'state': 'NJ',
#      'postcode': '07052',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396708'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/nj826'}}},
#   {'id': 59396707,
#    'organization_id': 'OH185',
#    'url': 'https://www.petfinder.com/cat/blossom-59396707/oh/cincinnati/the-scratching-post-oh185/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Calico',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Dilute Calico', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': ['Friendly',
#     'Affectionate',
#     'Curious',
#     'Loves kisses',
#     'Playful',
#     'Lapcat'],
#    'name': 'Blossom',
#    'description': 'Blossom is very friendly and affectionate. She loves sitting on laps and giving kisses. It took her a few days...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396707/1/?bust=1673310948'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:26:08+0000',
#    'published_at': '2023-01-10T00:26:04+0000',
#    'distance': None,
#    'contact': {'email': 'adoptions@thescratchingpost.org',
#     'phone': '(513) 984-6369',
#     'address': {'address1': '6948 Plainfield Road',
#      'address2': None,
#      'city': 'Cincinnati',
#      'state': 'OH',
#      'postcode': '45236',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396707'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/oh185'}}},
#   {'id': 59396705,
#    'organization_id': 'MI363',
#    'url': 'https://www.petfinder.com/cat/asher-survivor-59396705/mi/wyandotte/wyandotte-animal-adoption-center-mi363/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Tabby (Gray / Blue / Silver)',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': [],
#    'name': 'ASHER (Survivor) ',
#    'description': 'Asher is one of 14 cats and kittens left in a box on a porch for 30 minutes in ZERO...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/1/?bust=1673310329&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/1/?bust=1673310329&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/1/?bust=1673310329&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/1/?bust=1673310329'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/3/?bust=1673310330&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/3/?bust=1673310330&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/3/?bust=1673310330&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/3/?bust=1673310330'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396705/2/?bust=1673310330'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:25:33+0000',
#    'published_at': '2023-01-10T00:25:32+0000',
#    'distance': None,
#    'contact': {'email': 'wacvolunteers@gmail.com',
#     'phone': None,
#     'address': {'address1': '1170 GROVE STREET',
#      'address2': None,
#      'city': 'Wyandotte',
#      'state': 'MI',
#      'postcode': '48192',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396705'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/mi363'}}},
#   {'id': 59396706,
#    'organization_id': 'PA405',
#    'url': 'https://www.petfinder.com/cat/jibber-jabber-59396706/pa/brownsville/m-sorokas-angel-rescue-pa405/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'American Shorthair',
#     'secondary': 'Domestic Short Hair',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Tabby (Orange / Red)',
#     'secondary': 'Orange & White',
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': ['Friendly',
#     'Affectionate',
#     'Loyal',
#     'Gentle',
#     'Playful',
#     'Brave',
#     'Curious',
#     'Funny',
#     'Athletic',
#     'Loves kisses'],
#    'name': 'Jibber Jabber',
#    'description': 'He is all kitten! Talkative and wants to be with you at all times!\n\nhttps://www.facebook.com/groups/3045147149143060/permalink/3467171323607305/?mibextid=Nif5oz',
#    'organization_animal_id': 'PA12262023',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396706/1/?bust=1673310330'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:25:32+0000',
#    'published_at': '2023-01-10T00:25:31+0000',
#    'distance': None,
#    'contact': {'email': 'familiespride2@aol.com',
#     'phone': '(724) 710-2590',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Brownsville',
#      'state': 'PA',
#      'postcode': '15417',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396706'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/pa405'}}},
#   {'id': 59396704,
#    'organization_id': 'NE169',
#    'url': 'https://www.petfinder.com/cat/oteil-59396704/ne/kearney/kearney-rescue-cats-ne169/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Cream / Ivory', 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': False,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': ['Affectionate', 'Playful', 'Friendly'],
#    'name': 'Oteil',
#    'description': 'Oteil was born about October 1, 2022.  He loves to cuddle and play with his catnip mice toys.  He was...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396704/1/?bust=1673310305'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:25:11+0000',
#    'published_at': '2023-01-10T00:25:10+0000',
#    'distance': None,
#    'contact': {'email': None,
#     'phone': '(308) 440-5384',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'Kearney',
#      'state': 'NE',
#      'postcode': '68845',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396704'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/ne169'}}},
#   {'id': 59396703,
#    'organization_id': 'NJ826',
#    'url': 'https://www.petfinder.com/cat/cece-59396703/nj/west-orange/west-orange-tnvr-nj826/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black & White / Tuxedo',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': [],
#    'name': 'Cece',
#    'description': 'Cece is an adorable male tuxedo kitten who is looking for his forever home. \n His foster family says that he...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396703/1/?bust=1673310297'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:25:00+0000',
#    'published_at': '2023-01-10T00:24:59+0000',
#    'distance': None,
#    'contact': {'email': 'wotnvr@gmail.com',
#     'phone': '973-324-1346',
#     'address': {'address1': None,
#      'address2': None,
#      'city': 'West Orange',
#      'state': 'NJ',
#      'postcode': '07052',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396703'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/nj826'}}},
#   {'id': 59396702,
#    'organization_id': 'NJ817',
#    'url': 'https://www.petfinder.com/dog/uncle-fester-59396702/nj/ringwood/southern-paws-inc-nj817/?referrer_id=4a089e77-7bde-4381-8146-0f6365a64c76',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'German Shepherd Dog',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'White / Cream',
#     'secondary': 'Brindle',
#     'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': 'Medium',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': True, 'dogs': True, 'cats': True},
#    'tags': [],
#    'name': 'Uncle Fester',
#    'description': 'Meet Uncle Fester! This handsome little man is a 10 week old male German Shepherd mix. He is super friendly...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59396702/1/?bust=1673310281'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T00:24:43+0000',
#    'published_at': '2023-01-10T00:24:42+0000',
#    'distance': None,
#    'contact': {'email': 'southernpawsrescue@gmail.com',
#     'phone': '(973) 556-5885',
#     'address': {'address1': '1159 Greenwood Lake Tpk.',
#      'address2': None,
#      'city': 'Ringwood',
#      'state': 'NJ',
#      'postcode': '07456',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59396702'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/nj817'}}}],
#  'pagination': {'count_per_page': 100,
#   'total_count': 252402,
#   'current_page': 1,
#   'total_pages': 2525,
#   '_links': {'next': {'href': '/v2/animals?limit=100&page=2'}}}}

# %%
response.keys()
# Out:
# dict_keys(['animals', 'pagination'])

# %%
df = pd.DataFrame(response['animals'])
df.head()
# Out:
#          id organization_id  \
# 0  59396845           MI363
# 1  59396843           CO316
# 2  59396831           GA680
# 3  59396829          TX2322
# 4  59396828           NC965
#
#                                                  url type species  \
# 0  https://www.petfinder.com/cat/rafiq-59396845/m...  Cat     Cat
# 1  https://www.petfinder.com/cat/mrs-puff-5939684...  Cat     Cat
# 2  https://www.petfinder.com/dog/chloe-59396831/g...  Dog     Dog
# 3  https://www.petfinder.com/cat/birdie-59396829/...  Cat     Cat
# 4  https://www.petfinder.com/dog/sky-59396828/nc/...  Dog     Dog
#
#                                               breeds  \
# 0  {'primary': 'Domestic Short Hair', 'secondary'...
# 1  {'primary': 'Domestic Medium Hair', 'secondary...
# 2  {'primary': 'Cavachon', 'secondary': None, 'mi...
# 3  {'primary': 'Domestic Short Hair', 'secondary'...
# 4  {'primary': 'Chihuahua', 'secondary': 'Dachshu...
#
#                                               colors    age  gender    size  \
# 0  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 1  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2  {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 3  {'primary': None, 'secondary': None, 'tertiary...  Adult  Female  Medium
# 4  {'primary': 'Black', 'secondary': 'Brown / Cho...   Baby  Female   Small
#
#    ... organization_animal_id  \
# 0  ...                   None
# 1  ...               A0885368
# 2  ...                   None
# 3  ...                   None
# 4  ...                   None
#
#                                               photos  \
# 0  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 1                                                 []
# 2  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 3  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
# 4  [{'small': 'https://dl5zpyw5k3jeb.cloudfront.n...
#
#                                primary_photo_cropped videos     status  \
# 0  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 1                                               None     []  adoptable
# 2  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 3  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
# 4  {'small': 'https://dl5zpyw5k3jeb.cloudfront.ne...     []  adoptable
#
#           status_changed_at              published_at distance  \
# 0  2023-01-10T00:37:14+0000  2023-01-10T00:37:13+0000     None
# 1  2023-01-10T00:37:01+0000  2023-01-10T00:37:00+0000     None
# 2  2023-01-10T00:36:56+0000  2023-01-10T00:36:55+0000     None
# 3  2023-01-10T00:36:47+0000  2023-01-10T00:36:46+0000     None
# 4  2023-01-10T00:36:42+0000  2023-01-10T00:36:41+0000     None
#
#                                              contact  \
# 0  {'email': 'wacvolunteers@gmail.com', 'phone': ...
# 1  {'email': 'customercare@ddfl.org', 'phone': '3...
# 2  {'email': 'orphanannierescue@gmail.com', 'phon...
# 3  {'email': 'AnimalServices@Schertz.com', 'phone...
# 4  {'email': 'adopt@farmfriendsrescue.org', 'phon...
#
#                                               _links
# 0  {'self': {'href': '/v2/animals/59396845'}, 'ty...
# 1  {'self': {'href': '/v2/animals/59396843'}, 'ty...
# 2  {'self': {'href': '/v2/animals/59396831'}, 'ty...
# 3  {'self': {'href': '/v2/animals/59396829'}, 'ty...
# 4  {'self': {'href': '/v2/animals/59396828'}, 'ty...
#
# [5 rows x 26 columns]

# %%
# Breaking out the primary,secondary and mixed (T/F) breeds from the tuple in df column 'breeds'
primary_breeds_dict = {}
primary_breeds = []
secondary_breeds_dict = {}
secondary_breeds = []
mixed_breeds_dict = {}
mixed_breeds = []

for x,y in zip(df['breeds'],df['id']):
#     print(x,y)
    primary_breeds_dict = {'id':y}
    secondary_breeds_dict = {'id':y}
    mixed_breeds_dict = {'id':y}
    if 'primary' in x:
        primary_breeds_dict['primary'] =x['primary']
#         print(primary_breeds_dict)
        primary_breeds.append(primary_breeds_dict)
    if 'secondary' in x:
        secondary_breeds_dict['secondary'] =x['secondary']
        secondary_breeds.append(secondary_breeds_dict) 
    if 'mixed' in x:
        mixed_breeds_dict['mixed'] =x['mixed']
        mixed_breeds.append(mixed_breeds_dict) 
# print(breeds)
breed_1_df = pd.DataFrame(primary_breeds)
breed_2_df = pd.DataFrame(secondary_breeds)
breed_3_df = pd.DataFrame(mixed_breeds)

df_breeds_incorp = df.merge(breed_1_df,on='id').merge(breed_2_df,on='id').merge(breed_3_df,on='id')
# df_breeds_incorp.dtypes
df_breeds_incorp
# Out:
#           id organization_id  \
# 0   59396845           MI363
# 1   59396843           CO316
# 2   59396831           GA680
# 3   59396829          TX2322
# 4   59396828           NC965
# ..       ...             ...
# 95  59396705           MI363
# 96  59396706           PA405
# 97  59396704           NE169
# 98  59396703           NJ826
# 99  59396702           NJ817
#
#                                                   url type species  \
# 0   https://www.petfinder.com/cat/rafiq-59396845/m...  Cat     Cat
# 1   https://www.petfinder.com/cat/mrs-puff-5939684...  Cat     Cat
# 2   https://www.petfinder.com/dog/chloe-59396831/g...  Dog     Dog
# 3   https://www.petfinder.com/cat/birdie-59396829/...  Cat     Cat
# 4   https://www.petfinder.com/dog/sky-59396828/nc/...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/cat/asher-survivor-5...  Cat     Cat
# 96  https://www.petfinder.com/cat/jibber-jabber-59...  Cat     Cat
# 97  https://www.petfinder.com/cat/oteil-59396704/n...  Cat     Cat
# 98  https://www.petfinder.com/cat/cece-59396703/nj...  Cat     Cat
# 99  https://www.petfinder.com/dog/uncle-fester-593...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Domestic Short Hair', 'secondary'...
# 1   {'primary': 'Domestic Medium Hair', 'secondary...
# 2   {'primary': 'Cavachon', 'secondary': None, 'mi...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'Chihuahua', 'secondary': 'Dachshu...
# ..                                                ...
# 95  {'primary': 'Domestic Short Hair', 'secondary'...
# 96  {'primary': 'American Shorthair', 'secondary':...
# 97  {'primary': 'Domestic Short Hair', 'secondary'...
# 98  {'primary': 'Domestic Short Hair', 'secondary'...
# 99  {'primary': 'German Shepherd Dog', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 1   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 3   {'primary': None, 'secondary': None, 'tertiary...  Adult  Female  Medium
# 4   {'primary': 'Black', 'secondary': 'Brown / Cho...   Baby  Female   Small
# ..                                                ...    ...     ...     ...
# 95  {'primary': 'Tabby (Gray / Blue / Silver)', 's...  Young    Male   Small
# 96  {'primary': 'Tabby (Orange / Red)', 'secondary...   Baby    Male   Large
# 97  {'primary': 'Cream / Ivory', 'secondary': None...   Baby    Male  Medium
# 98  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 99  {'primary': 'White / Cream', 'secondary': 'Bri...   Baby    Male   Large
#
#     ... videos     status         status_changed_at              published_at  \
# 0   ...     []  adoptable  2023-01-10T00:37:14+0000  2023-01-10T00:37:13+0000
# 1   ...     []  adoptable  2023-01-10T00:37:01+0000  2023-01-10T00:37:00+0000
# 2   ...     []  adoptable  2023-01-10T00:36:56+0000  2023-01-10T00:36:55+0000
# 3   ...     []  adoptable  2023-01-10T00:36:47+0000  2023-01-10T00:36:46+0000
# 4   ...     []  adoptable  2023-01-10T00:36:42+0000  2023-01-10T00:36:41+0000
# ..  ...    ...        ...                       ...                       ...
# 95  ...     []  adoptable  2023-01-10T00:25:33+0000  2023-01-10T00:25:32+0000
# 96  ...     []  adoptable  2023-01-10T00:25:32+0000  2023-01-10T00:25:31+0000
# 97  ...     []  adoptable  2023-01-10T00:25:11+0000  2023-01-10T00:25:10+0000
# 98  ...     []  adoptable  2023-01-10T00:25:00+0000  2023-01-10T00:24:59+0000
# 99  ...     []  adoptable  2023-01-10T00:24:43+0000  2023-01-10T00:24:42+0000
#
#    distance                                            contact  \
# 0      None  {'email': 'wacvolunteers@gmail.com', 'phone': ...
# 1      None  {'email': 'customercare@ddfl.org', 'phone': '3...
# 2      None  {'email': 'orphanannierescue@gmail.com', 'phon...
# 3      None  {'email': 'AnimalServices@Schertz.com', 'phone...
# 4      None  {'email': 'adopt@farmfriendsrescue.org', 'phon...
# ..      ...                                                ...
# 95     None  {'email': 'wacvolunteers@gmail.com', 'phone': ...
# 96     None  {'email': 'familiespride2@aol.com', 'phone': '...
# 97     None  {'email': None, 'phone': '(308) 440-5384', 'ad...
# 98     None  {'email': 'wotnvr@gmail.com', 'phone': '973-32...
# 99     None  {'email': 'southernpawsrescue@gmail.com', 'pho...
#
#                                                _links               primary  \
# 0   {'self': {'href': '/v2/animals/59396845'}, 'ty...   Domestic Short Hair
# 1   {'self': {'href': '/v2/animals/59396843'}, 'ty...  Domestic Medium Hair
# 2   {'self': {'href': '/v2/animals/59396831'}, 'ty...              Cavachon
# 3   {'self': {'href': '/v2/animals/59396829'}, 'ty...   Domestic Short Hair
# 4   {'self': {'href': '/v2/animals/59396828'}, 'ty...             Chihuahua
# ..                                                ...                   ...
# 95  {'self': {'href': '/v2/animals/59396705'}, 'ty...   Domestic Short Hair
# 96  {'self': {'href': '/v2/animals/59396706'}, 'ty...    American Shorthair
# 97  {'self': {'href': '/v2/animals/59396704'}, 'ty...   Domestic Short Hair
# 98  {'self': {'href': '/v2/animals/59396703'}, 'ty...   Domestic Short Hair
# 99  {'self': {'href': '/v2/animals/59396702'}, 'ty...   German Shepherd Dog
#
#               secondary  mixed
# 0                  None  False
# 1                  None  False
# 2                  None   True
# 3                  None  False
# 4             Dachshund   True
# ..                  ...    ...
# 95                 None  False
# 96  Domestic Short Hair   True
# 97                 None  False
# 98                 None  False
# 99                 None   True
#
# [100 rows x 29 columns]

# %%
# Breaking out the address from the contact info nested dict into a dataframe and joining to breeds
address1_dict = {}

address_df = pd.DataFrame()

for x,y in zip(df['contact'],df['id']):
#     print(x,y)
    address1_dict = {'id':y}
    if 'address' in x:
        address1_dict['address'] =x['address']
#         print(address1_dict)
        test_df = pd.DataFrame(pd.json_normalize(address1_dict))
        address_df = address_df.append(test_df)
address_df.dtypes
address_and_breeds_df = df_breeds_incorp.merge(address_df,left_on='id',right_on='id')

# Most current df with relevant data
address_and_breeds_df
# Out:
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2402903202.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   address_df = address_df.append(test_df)
#           id organization_id  \
# 0   59396845           MI363
# 1   59396843           CO316
# 2   59396831           GA680
# 3   59396829          TX2322
# 4   59396828           NC965
# ..       ...             ...
# 95  59396705           MI363
# 96  59396706           PA405
# 97  59396704           NE169
# 98  59396703           NJ826
# 99  59396702           NJ817
#
#                                                   url type species  \
# 0   https://www.petfinder.com/cat/rafiq-59396845/m...  Cat     Cat
# 1   https://www.petfinder.com/cat/mrs-puff-5939684...  Cat     Cat
# 2   https://www.petfinder.com/dog/chloe-59396831/g...  Dog     Dog
# 3   https://www.petfinder.com/cat/birdie-59396829/...  Cat     Cat
# 4   https://www.petfinder.com/dog/sky-59396828/nc/...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/cat/asher-survivor-5...  Cat     Cat
# 96  https://www.petfinder.com/cat/jibber-jabber-59...  Cat     Cat
# 97  https://www.petfinder.com/cat/oteil-59396704/n...  Cat     Cat
# 98  https://www.petfinder.com/cat/cece-59396703/nj...  Cat     Cat
# 99  https://www.petfinder.com/dog/uncle-fester-593...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Domestic Short Hair', 'secondary'...
# 1   {'primary': 'Domestic Medium Hair', 'secondary...
# 2   {'primary': 'Cavachon', 'secondary': None, 'mi...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'Chihuahua', 'secondary': 'Dachshu...
# ..                                                ...
# 95  {'primary': 'Domestic Short Hair', 'secondary'...
# 96  {'primary': 'American Shorthair', 'secondary':...
# 97  {'primary': 'Domestic Short Hair', 'secondary'...
# 98  {'primary': 'Domestic Short Hair', 'secondary'...
# 99  {'primary': 'German Shepherd Dog', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 1   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 3   {'primary': None, 'secondary': None, 'tertiary...  Adult  Female  Medium
# 4   {'primary': 'Black', 'secondary': 'Brown / Cho...   Baby  Female   Small
# ..                                                ...    ...     ...     ...
# 95  {'primary': 'Tabby (Gray / Blue / Silver)', 's...  Young    Male   Small
# 96  {'primary': 'Tabby (Orange / Red)', 'secondary...   Baby    Male   Large
# 97  {'primary': 'Cream / Ivory', 'secondary': None...   Baby    Male  Medium
# 98  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 99  {'primary': 'White / Cream', 'secondary': 'Bri...   Baby    Male   Large
#
#     ...                                             _links  \
# 0   ...  {'self': {'href': '/v2/animals/59396845'}, 'ty...
# 1   ...  {'self': {'href': '/v2/animals/59396843'}, 'ty...
# 2   ...  {'self': {'href': '/v2/animals/59396831'}, 'ty...
# 3   ...  {'self': {'href': '/v2/animals/59396829'}, 'ty...
# 4   ...  {'self': {'href': '/v2/animals/59396828'}, 'ty...
# ..  ...                                                ...
# 95  ...  {'self': {'href': '/v2/animals/59396705'}, 'ty...
# 96  ...  {'self': {'href': '/v2/animals/59396706'}, 'ty...
# 97  ...  {'self': {'href': '/v2/animals/59396704'}, 'ty...
# 98  ...  {'self': {'href': '/v2/animals/59396703'}, 'ty...
# 99  ...  {'self': {'href': '/v2/animals/59396702'}, 'ty...
#
#                  primary            secondary  mixed  \
# 0    Domestic Short Hair                 None  False
# 1   Domestic Medium Hair                 None  False
# 2               Cavachon                 None   True
# 3    Domestic Short Hair                 None  False
# 4              Chihuahua            Dachshund   True
# ..                   ...                  ...    ...
# 95   Domestic Short Hair                 None  False
# 96    American Shorthair  Domestic Short Hair   True
# 97   Domestic Short Hair                 None  False
# 98   Domestic Short Hair                 None  False
# 99   German Shepherd Dog                 None   True
#
#             address.address1 address.address2 address.city address.state  \
# 0          1170 GROVE STREET             None    Wyandotte            MI
# 1         2080 S. Quebec St.             None       Denver            CO
# 2                       None             None      Atlanta            GA
# 3       800 Community Circle             None      Schertz            TX
# 4                       None             None    Pittsboro            NC
# ..                       ...              ...          ...           ...
# 95         1170 GROVE STREET             None    Wyandotte            MI
# 96                      None             None  Brownsville            PA
# 97                      None             None      Kearney            NE
# 98                      None             None  West Orange            NJ
# 99  1159 Greenwood Lake Tpk.             None     Ringwood            NJ
#
#    address.postcode address.country
# 0             48192              US
# 1             80231              US
# 2             30350              US
# 3             78154              US
# 4             27312              US
# ..              ...             ...
# 95            48192              US
# 96            15417              US
# 97            68845              US
# 98            07052              US
# 99            07456              US
#
# [100 rows x 35 columns]

# %%
photo_dict = []
photo_df = pd.DataFrame()
test = {}
for x,y in zip(df['photos'],df['id']):
#     print(x,y)
    photo_dict = {'id':y,'photos':x}
    pd.json_normalize(photo_dict)
#     print(photo_dict)
    for i in photo_dict['photos']:
        temp_photo_dict = {'id':y,'small_photo': i['small'],'medium_photo': i['medium'],'large_photo': i['large']}
#         print(test)
        df_photos = pd.DataFrame(pd.json_normalize(temp_photo_dict))
        photo_df = photo_df.append(df_photos)
photo_df
photo_df = photo_df.groupby(['id'],sort=True).max()

# merging the breeds and address df to the photos df - this is the final cleaned df
cleaned_pet_df = address_and_breeds_df.merge(photo_df,how='left',left_on='id',right_on='id')
cleaned_pet_df
# Out:
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
# /var/folders/vc/z_x4c0yx2cs_6rwx2wcj_sqm0000gn/T/ipykernel_38893/2110876327.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   photo_df = photo_df.append(df_photos)
#           id organization_id  \
# 0   59396845           MI363
# 1   59396843           CO316
# 2   59396831           GA680
# 3   59396829          TX2322
# 4   59396828           NC965
# ..       ...             ...
# 95  59396705           MI363
# 96  59396706           PA405
# 97  59396704           NE169
# 98  59396703           NJ826
# 99  59396702           NJ817
#
#                                                   url type species  \
# 0   https://www.petfinder.com/cat/rafiq-59396845/m...  Cat     Cat
# 1   https://www.petfinder.com/cat/mrs-puff-5939684...  Cat     Cat
# 2   https://www.petfinder.com/dog/chloe-59396831/g...  Dog     Dog
# 3   https://www.petfinder.com/cat/birdie-59396829/...  Cat     Cat
# 4   https://www.petfinder.com/dog/sky-59396828/nc/...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/cat/asher-survivor-5...  Cat     Cat
# 96  https://www.petfinder.com/cat/jibber-jabber-59...  Cat     Cat
# 97  https://www.petfinder.com/cat/oteil-59396704/n...  Cat     Cat
# 98  https://www.petfinder.com/cat/cece-59396703/nj...  Cat     Cat
# 99  https://www.petfinder.com/dog/uncle-fester-593...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Domestic Short Hair', 'secondary'...
# 1   {'primary': 'Domestic Medium Hair', 'secondary...
# 2   {'primary': 'Cavachon', 'secondary': None, 'mi...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'Chihuahua', 'secondary': 'Dachshu...
# ..                                                ...
# 95  {'primary': 'Domestic Short Hair', 'secondary'...
# 96  {'primary': 'American Shorthair', 'secondary':...
# 97  {'primary': 'Domestic Short Hair', 'secondary'...
# 98  {'primary': 'Domestic Short Hair', 'secondary'...
# 99  {'primary': 'German Shepherd Dog', 'secondary'...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 1   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 2   {'primary': None, 'secondary': None, 'tertiary...   Baby  Female   Small
# 3   {'primary': None, 'secondary': None, 'tertiary...  Adult  Female  Medium
# 4   {'primary': 'Black', 'secondary': 'Brown / Cho...   Baby  Female   Small
# ..                                                ...    ...     ...     ...
# 95  {'primary': 'Tabby (Gray / Blue / Silver)', 's...  Young    Male   Small
# 96  {'primary': 'Tabby (Orange / Red)', 'secondary...   Baby    Male   Large
# 97  {'primary': 'Cream / Ivory', 'secondary': None...   Baby    Male  Medium
# 98  {'primary': 'Black & White / Tuxedo', 'seconda...   Baby    Male   Small
# 99  {'primary': 'White / Cream', 'secondary': 'Bri...   Baby    Male   Large
#
#     ...  mixed          address.address1 address.address2 address.city  \
# 0   ...  False         1170 GROVE STREET             None    Wyandotte
# 1   ...  False        2080 S. Quebec St.             None       Denver
# 2   ...   True                      None             None      Atlanta
# 3   ...  False      800 Community Circle             None      Schertz
# 4   ...   True                      None             None    Pittsboro
# ..  ...    ...                       ...              ...          ...
# 95  ...  False         1170 GROVE STREET             None    Wyandotte
# 96  ...   True                      None             None  Brownsville
# 97  ...  False                      None             None      Kearney
# 98  ...  False                      None             None  West Orange
# 99  ...   True  1159 Greenwood Lake Tpk.             None     Ringwood
#
#    address.state address.postcode address.country  \
# 0             MI            48192              US
# 1             CO            80231              US
# 2             GA            30350              US
# 3             TX            78154              US
# 4             NC            27312              US
# ..           ...              ...             ...
# 95            MI            48192              US
# 96            PA            15417              US
# 97            NE            68845              US
# 98            NJ            07052              US
# 99            NJ            07456              US
#
#                                           small_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                 NaN
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                          medium_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                 NaN
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                           large_photo
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                 NaN
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
# [100 rows x 38 columns]

# %%
# Cleaning the final DF to only the data we need
cleaned_pet_df.head()
cleaned_pet_df.dtypes
cleaned_pet_df = cleaned_pet_df.rename(columns={'address.address1':'address1',"address.address2":"address2",'address.city':"city",
                              "address.state":'state',"address.postcode":"zip","address.country":"country"
                              })
cleaned_pet_df = cleaned_pet_df[['id','url','age','gender','name','description','status','status_changed_at'
                                ,'published_at','primary','secondary','mixed','address1','address2','city','state',
                                 'zip','country','small_photo','medium_photo','large_photo'
                                ]]
cleaned_pet_df
# Out:
#           id                                                url    age  \
# 0   59396845  https://www.petfinder.com/cat/rafiq-59396845/m...   Baby
# 1   59396843  https://www.petfinder.com/cat/mrs-puff-5939684...   Baby
# 2   59396831  https://www.petfinder.com/dog/chloe-59396831/g...   Baby
# 3   59396829  https://www.petfinder.com/cat/birdie-59396829/...  Adult
# 4   59396828  https://www.petfinder.com/dog/sky-59396828/nc/...   Baby
# ..       ...                                                ...    ...
# 95  59396705  https://www.petfinder.com/cat/asher-survivor-5...  Young
# 96  59396706  https://www.petfinder.com/cat/jibber-jabber-59...   Baby
# 97  59396704  https://www.petfinder.com/cat/oteil-59396704/n...   Baby
# 98  59396703  https://www.petfinder.com/cat/cece-59396703/nj...   Baby
# 99  59396702  https://www.petfinder.com/dog/uncle-fester-593...   Baby
#
#     gender               name  \
# 0     Male              RAFIQ
# 1   Female          MRS. PUFF
# 2   Female              Chloe
# 3   Female             Birdie
# 4   Female                Sky
# ..     ...                ...
# 95    Male  ASHER (Survivor)
# 96    Male      Jibber Jabber
# 97    Male              Oteil
# 98    Male               Cece
# 99    Male       Uncle Fester
#
#                                           description     status  \
# 0   Rafiq and his sister were found outside in rou...  adoptable
# 1                                                None  adoptable
# 2   Chloe is a shy but cuddly 13 lb, 8 mo old girl...  adoptable
# 3                                                None  adoptable
# 4   Sky is a very sweet little girl.  She loves to...  adoptable
# ..                                                ...        ...
# 95  Asher is one of 14 cats and kittens left in a ...  adoptable
# 96  He is all kitten! Talkative and wants to be wi...  adoptable
# 97  Oteil was born about October 1, 2022.  He love...  adoptable
# 98  Cece is an adorable male tuxedo kitten who is ...  adoptable
# 99  Meet Uncle Fester! This handsome little man is...  adoptable
#
#            status_changed_at              published_at               primary  \
# 0   2023-01-10T00:37:14+0000  2023-01-10T00:37:13+0000   Domestic Short Hair
# 1   2023-01-10T00:37:01+0000  2023-01-10T00:37:00+0000  Domestic Medium Hair
# 2   2023-01-10T00:36:56+0000  2023-01-10T00:36:55+0000              Cavachon
# 3   2023-01-10T00:36:47+0000  2023-01-10T00:36:46+0000   Domestic Short Hair
# 4   2023-01-10T00:36:42+0000  2023-01-10T00:36:41+0000             Chihuahua
# ..                       ...                       ...                   ...
# 95  2023-01-10T00:25:33+0000  2023-01-10T00:25:32+0000   Domestic Short Hair
# 96  2023-01-10T00:25:32+0000  2023-01-10T00:25:31+0000    American Shorthair
# 97  2023-01-10T00:25:11+0000  2023-01-10T00:25:10+0000   Domestic Short Hair
# 98  2023-01-10T00:25:00+0000  2023-01-10T00:24:59+0000   Domestic Short Hair
# 99  2023-01-10T00:24:43+0000  2023-01-10T00:24:42+0000   German Shepherd Dog
#
#     ...  mixed                  address1 address2         city state    zip  \
# 0   ...  False         1170 GROVE STREET     None    Wyandotte    MI  48192
# 1   ...  False        2080 S. Quebec St.     None       Denver    CO  80231
# 2   ...   True                      None     None      Atlanta    GA  30350
# 3   ...  False      800 Community Circle     None      Schertz    TX  78154
# 4   ...   True                      None     None    Pittsboro    NC  27312
# ..  ...    ...                       ...      ...          ...   ...    ...
# 95  ...  False         1170 GROVE STREET     None    Wyandotte    MI  48192
# 96  ...   True                      None     None  Brownsville    PA  15417
# 97  ...  False                      None     None      Kearney    NE  68845
# 98  ...  False                      None     None  West Orange    NJ  07052
# 99  ...   True  1159 Greenwood Lake Tpk.     None     Ringwood    NJ  07456
#
#    country                                        small_photo  \
# 0       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1       US                                                NaN
# 2       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..     ...                                                ...
# 95      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 98      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                          medium_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                 NaN
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                           large_photo
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1                                                 NaN
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
# [100 rows x 21 columns]

# %% [markdown]
# # Establishing a Connection to SQL for Data Organization

# %%
#Establish a connection to SQL: 
from sqlalchemy import create_engine

# Creating connection object
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5433
database_name = 'postgres'

# %%
#Create engine connection:
connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'

engine = create_engine(connection_string)

# %%
cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
engine.execute("SELECT name, age, gender, primary, city, state FROM adoptees ORDER BY state ASC").fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     254 """Called by subclasses to create a new ConnectionRecord."""
# --> 256 return _ConnectionRecord(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     660 self.starttime = time.time()
# --> 661 self.dbapi_connection = connection = pool._invoke_creator(self)
#     662 pool.logger.debug("Created new connection %r", connection)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
#       2 engine.execute("SELECT name, age, gender, primary, city, state FROM adoptees ORDER BY state ASC").fetchall()
#
# File ~/.local/lib/python3.9/site-packages/pandas/core/generic.py:2987, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2830 """
#    2831 Write records stored in a DataFrame to a SQL database.
#    2832
#    (...)
#    2983 [(1,), (None,), (2,)]
#    2984 """  # noqa:E501
#    2985 from pandas.io import sql
# -> 2987 return sql.to_sql(
#    2988     self,
#    2989     name,
#    2990     con,
#    2991     schema=schema,
#    2992     if_exists=if_exists,
#    2993     index=index,
#    2994     index_label=index_label,
#    2995     chunksize=chunksize,
#    2996     dtype=dtype,
#    2997     method=method,
#    2998 )
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:695, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     690 elif not isinstance(frame, DataFrame):
#     691     raise NotImplementedError(
#     692         "'frame' argument should be either a Series or a DataFrame"
#     693     )
# --> 695 return pandas_sql.to_sql(
#     696     frame,
#     697     name,
#     698     if_exists=if_exists,
#     699     index=index,
#     700     index_label=index_label,
#     701     schema=schema,
#     702     chunksize=chunksize,
#     703     dtype=dtype,
#     704     method=method,
#     705     engine=engine,
#     706     **engine_kwargs,
#     707 )
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:1728, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1678 """
#    1679 Write records stored in a DataFrame to a SQL database.
#    1680
#    (...)
#    1724     Any additional kwargs are passed to the engine.
#    1725 """
#    1726 sql_engine = get_engine(engine)
# -> 1728 table = self.prep_table(
#    1729     frame=frame,
#    1730     name=name,
#    1731     if_exists=if_exists,
#    1732     index=index,
#    1733     index_label=index_label,
#    1734     schema=schema,
#    1735     dtype=dtype,
#    1736 )
#    1738 total_inserted = sql_engine.insert_records(
#    1739     table=table,
#    1740     con=self.connectable,
#    (...)
#    1747     **engine_kwargs,
#    1748 )
#    1750 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:827, in SQLTable.create(self)
#     826 def create(self) -> None:
# --> 827     if self.exists():
#     828         if self.if_exists == "fail":
#     829             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:814, in SQLTable.exists(self)
#     813 def exists(self):
# --> 814     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~/.local/lib/python3.9/site-packages/pandas/io/sql.py:1760, in SQLDatabase.has_table(self, name, schema)
#    1757 def has_table(self, name: str, schema: str | None = None):
#    1758     from sqlalchemy import inspect as sqlalchemy_inspect
# -> 1760     insp = sqlalchemy_inspect(self.connectable)
#    1761     return insp.has_table(name, schema or self.meta.schema)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/inspection.py:64, in inspect(subject, raiseerr)
#      62 if reg is True:
#      63     return subject
# ---> 64 ret = reg(subject)
#      65 if ret is not None:
#      66     break
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:182, in Inspector._engine_insp(bind)
#     180 @inspection._inspects(Engine)
#     181 def _engine_insp(bind):
# --> 182     return Inspector._construct(Inspector._init_engine, bind)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:117, in Inspector._construct(cls, init, bind)
#     114     cls = bind.dialect.inspector
#     116 self = cls.__new__(cls)
# --> 117 init(self, bind)
#     118 return self
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py:128, in Inspector._init_engine(self, engine)
#     126 def _init_engine(self, engine):
#     127     self.bind = self.engine = engine
# --> 128     engine.connect().close()
#     129     self._op_context_requires_connect = True
#     130     self.dialect = self.engine.dialect
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3210, in Engine.connect(self, close_with_result)
#    3195 def connect(self, close_with_result=False):
#    3196     """Return a new :class:`_engine.Connection` object.
#    3197
#    3198     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3207
#    3208     """
# -> 3210     return self._connection_cls(self, close_with_result=close_with_result)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3289, in Engine.raw_connection(self, _connection)
#    3267 def raw_connection(self, _connection=None):
#    3268     """Return a "raw" DBAPI connection from the connection pool.
#    3269
#    3270     The returned object is a proxied version of the DBAPI
#    (...)
#    3287
#    3288     """
# -> 3289     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3259, in Engine._wrap_pool_connect(self, fn, connection)
#    3257 except dialect.dbapi.Error as e:
#    3258     if connection is None:
# -> 3259         Connection._handle_dbapi_exception_noconnection(
#    3260             e, dialect, self
#    3261         )
#    3262     else:
#    3263         util.raise_(
#    3264             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3265         )
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2106, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2104     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2105 elif should_wrap:
# -> 2106     util.raise_(
#    2107         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2108     )
#    2109 else:
#    2110     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3254 dialect = self.dialect
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#    3258     if connection is None:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     302 def connect(self):
#     303     """Return a DBAPI connection from the pool.
#     304
#     305     The connection is instrumented such that when its
#    (...)
#     308
#     309     """
# --> 310     return _ConnectionFairy._checkout(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     865 @classmethod
#     866 def _checkout(cls, pool, threadconns=None, fairy=None):
#     867     if not fairy:
# --> 868         fairy = _ConnectionRecord.checkout(pool)
#     870         fairy._pool = pool
#     871         fairy._counter = 0
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#     478         dbapi_connection = rec.get_connection()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:146, in QueuePool._do_get(self)
#     144     except:
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#     148     return self._do_get()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     253 def _create_connection(self):
#     254     """Called by subclasses to create a new ConnectionRecord."""
# --> 256     return _ConnectionRecord(self)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     369 self.__pool = pool
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:666, in _ConnectionRecord.__connect(self)
#     664 except Exception as e:
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#     670     if pool.dispatch.first_connect:
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:661, in _ConnectionRecord.__connect(self)
#     659 try:
#     660     self.starttime = time.time()
# --> 661     self.dbapi_connection = connection = pool._invoke_creator(self)
#     662     pool.logger.debug("Created new connection %r", connection)
#     663     self.fresh = True
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py:590, in create_engine.<locals>.connect(connection_record)
#     588         if connection is not None:
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~/.local/lib/python3.9/site-packages/psycopg2/__init__.py:122, in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     119     kwasync['async_'] = kwargs.pop('async_')
#     121 dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122 conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123 if cursor_factory is not None:
#     124     conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
# connection to server at "localhost" (127.0.0.1), port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
