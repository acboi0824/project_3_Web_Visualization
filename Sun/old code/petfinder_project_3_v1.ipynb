# %%
# checking to see what the version of pandas i have for petpy
# !pip install petpy
# import pandas as pd
# pd.__version__

# %%
# upgrades to the lastest version of pandas
# !pip install -U pandas --user

# %%
# pd.__version__

# %%
import requests
import json
import pandas as pd
import petpy
# Out:
# C:\Users\alexc\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
key="norgPOLa7iXU0O2nSaqV1N2pu7AE3mq2o4U576yoFbyvFKGxQJ"
secret="yAyJRAVHwwzmADTe7pRIFnjOZ5Lecf25UsbZnVaC"
url = "https://api.petfinder.com/v2/oauth2/token"

# %%
# gets the access token using credentials
def get_access_token(url, client_id, client_secret):
    response = requests.post(
        url,
        data={"grant_type": "client_credentials"},
        auth=(key, secret),
    )
    return response.json()["access_token"]



token = get_access_token(url,key,secret)
get_access_token(url,key,secret)
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..wgWyVLoXuN1d9TygR973bpArG9yJlcid9LZqcRCVplTc0Ug-ztwOp9gbcAO3AiFzwfIEi5DHKlAjVXh38AD7065fmnHAgExzhA36dwFJZx3Ya2bxdvXKhmF_asEi3TYPGGuA_MmMfjr9Fi3uSOrvpSYcXCBFe663VD-Op0YDs9a5gIoncSRtiuQNyZm3ThOcEHuuefujl6ryPQbtroFBXXjsoAInsedxCSiP3MHRuVDOwmqN9S4qXxCzWGIIZ1mpa_AVy2jCqF1TvwY0B7-F6om2HUiPbEVR2oLidim-Z_dGnDxJ_SEi7k-i3_eEMwB_UIDrmBcHx8Vmams23Y0tsA'

# %%
headers = {
        'Authorization': 'Bearer {0}'.format(token),
    }

param = {
   "page": 4,
    "limit": 100
    #these are not indented, so no problem there.
    }#close param

response = requests.get('https://api.petfinder.com/v2/animals', headers=headers, 
        params=param)
response = response.json()
response
# Out:
# {'animals': [{'id': 59397970,
#    'organization_id': 'CA736',
#    'url': 'https://www.petfinder.com/dog/smokey-59397970/ca/newport-beach/newport-beach-animal-shelter-ca736/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Brindle',
#     'tertiary': 'White / Cream'},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Smokey',
#    'description': None,
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397970/1/?bust=1673322269'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:44:32+0000',
#    'published_at': '2023-01-10T03:44:31+0000',
#    'distance': None,
#    'contact': {'email': 'vschomburg@nbpd.org',
#     'phone': '(949) 718-3454',
#     'address': {'address1': '20302 Riverside Dr',
#      'address2': None,
#      'city': 'Newport Beach',
#      'state': 'CA',
#      'postcode': '92660',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397970'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/ca736'}}},
#   {'id': 59397969,
#    'organization_id': 'CA2509',
#    'url': 'https://www.petfinder.com/cat/espurr-59397969/ca/sacramento/sacramento-spca-ca2509/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': 'Black',
#     'secondary': 'Orange / Red',
#     'tertiary': None},
#    'age': 'Young',
#    'gender': 'Female',
#    'size': 'Small',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Espurr',
#    'description': 'Espurr is a 1 year old and 6 pound cat who is looking for her forever home.\n\nIf you are...',
#    'organization_animal_id': '51820373',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397969/1/?bust=1673322251'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03
?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Orange / Red',
#     'secondary': 'Cream / Ivory',
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Sundance',
#    'description': '*Adoptions are by appointment. If you&amp;#39;d like to learn more, or you are interested in adopting, please click the &amp;#34;Apply...',
#    'organization_animal_id': 'CAR-A-3421',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/2/?bust=1673322728&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/2/?bust=1673322728&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/2/?bust=1673322728&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/2/?bust=1673322728'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397963/1/?bust=1673322728'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:42:03+0000',
#    'published_at': '2023-01-10T03:42:01+0000',
#    'distance': None,
#    'contact': {'email': 'info@coloradoanimalrescue.org',
#     'phone': '(970) 947-9173',
#     'address': {'address1': '2801 County Road 114',
#      'address2': None,
#      'city': 'Glenwood Springs',
#      'state': 'CO',
#      'postcode': '81601',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397963'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/co45'}}},
#   {'id': 59397964,
#    'organization_id': 'CO45',
#    'url': 'https://www.petfinder.com/cat/martha-59397964/co/glenwood-springs/colorado-animal-rescue-co45/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Tortoiseshell', 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Medium',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Martha',
#    'description': '*Adoptions are by appointment. If you&amp;#39;d like to learn more, or you are interested in adopting, please click the &amp;#34;Apply...',
#    'organization_animal_id': 'CAR-A-3424',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397964/1/?bust=1673322729'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:42:03+0000',
#    'published_at': '2023-01-10T03:42:01+0000',
#    'distance': None,
#    'contact': {'email': 'info@coloradoanimalrescue.org',
#     'phone': '(970) 947-9173',
#     'address': {'address1': '2801 County Road 114',
#      'address2': None,
#      'city': 'Glenwood Springs',
#      'state': 'CO',
#      'postcode': '81601',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397964'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/co45'}}},
#   {'id': 59397958,
#    'organization_id': 'TX2018',
#    'url': 'https://www.petfinder.com/dog/a040197-59397958/tx/rosenberg/fort-bend-county-animal-services-tx2018/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Rottweiler',
#     'secondary': 'German Shepherd Dog',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'A040197',
#    'description': None,
#    'organization_animal_id': 'A040197',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397958/1/?bust=1673322706'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:41:45+0000',
#    'published_at': '2023-01-10T03:41:43+0000',
#    'distance': None,
#    'contact': {'email': 'barbara.vass@fortbendcountytx.gov',
#     'phone': '(281) 342-1512',
#     'address': {'address1': '1210 Blume Rd.',
#      'address2': None,
#      'city': 'Rosenberg',
#      'state': 'TX',
#      'postcode': '77471',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397958'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx2018'}}},
#   {'id': 59397957,
#    'organization_id': 'OH1306',
#    'url': 'https://www.petfinder.com/cat/sonny-59397957/oh/columbus/ark-of-redemption-oh1306/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'American Shorthair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Tabby (Tiger Striped)',
#     'secondary': None,
#     'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Medium',
#    'coat': 'Short',
#    'attributes': {'spayed_neutered': True,
#     'house_trained': True,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': True},
#    'environment': {'children': None, 'dogs': None, 'cats': True},
#    'tags': ['Friendly',
#     'Affectionate',
#     'Curious',
#     'Independent',
#     'Athletic',
#     'Loves kisses',
#     'Smart'],
#    'name': 'Sonny',
#    'description': 'Sonny is a laid back cat. He likes lounging on higher ground and loves getting pets and cuddles. He is...',
#    'organization_animal_id': None,
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397957
},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx236'}}},
#   {'id': 59397953,
#    'organization_id': 'TX236',
#    'url': 'https://www.petfinder.com/dog/athena-59397953/tx/dallas/dallas-animal-services-and-adoption-center-tx236/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Great Dane',
#     'secondary': 'Mixed Breed',
#     'mixed': True,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'ATHENA',
#    'description': None,
#    'organization_animal_id': 'A1166547',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397953/1/?bust=1673322593'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:39:48+0000',
#    'published_at': '2023-01-10T03:39:46+0000',
#    'distance': None,
#    'contact': {'email': 'dasadopt@dallascityhall.com',
#     'phone': '(214) 671-0249',
#     'address': {'address1': '1818 N. Westmoreland',
#      'address2': None,
#      'city': 'Dallas',
#      'state': 'TX',
#      'postcode': '75212',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397953'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx236'}}},
#   {'id': 59397949,
#    'organization_id': 'TX236',
#    'url': 'https://www.petfinder.com/cat/midnight-59397949/tx/dallas/dallas-animal-services-and-adoption-center-tx236/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'MIDNIGHT',
#    'description': None,
#    'organization_animal_id': 'A1166544',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397949/1/?bust=1673322594'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:39:48+0000',
#    'published_at': '2023-01-10T03:39:46+0000',
#    'distance': None,
#    'contact': {'email': 'dasadopt@dallascityhall.com',
#     'phone': '(214) 671-0249',
#     'address': {'address1': '1818 N. Westmoreland',
#      'address2': None,
#      'city': 'Dallas',
#      'state': 'TX',
#      'postcode': '75212',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397949'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx236'}}},
#   {'id': 59397948,
#    'organization_id': 'TX236',
#    'url': 'https://www.petfinder.com/cat/sally-59397948/tx/dallas/dallas-animal-services-and-adoption-center-tx236/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Cat',
#    'species': 'Cat',
#    'breeds': {'primary': 'Domestic Short Hair',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Baby',
#    'gender': 'Female',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': False,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'SALLY',
#    'description': None,
#    'organization_animal_id': 'A1166545',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397948/1/?bust=1673322596'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:39:48+0000',
#    'published_at': '2023-01-10T03:39:46+0000',
#    'distance': None,
#    'contact': {'email': 'dasadopt@dallascityhall.com',
#     'phone': '(214) 671-0249',
#     'address': {'address1': '1818 N. Westmoreland',
#      'address2': None,
#      'city': 'Dallas',
#      'state': 'TX',
#      'postcode': '75212',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397948'},
#     'type': {'href': '/v2/types/cat'},
#     'organization': {'href': '/v2/organizations/tx236'}}},
#   {'id': 59397945,
#    'organization_id': 'TX236',
#    'url': 'https://www.petfinder.com/dog/blitz-59397945/tx/dallas/dallas-animal-services-and-adoption-center-tx236/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Pit Bull Terrier',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': None, 'secondary': None, 'tertiary': None},
#    'age': 'Adult',
#    'gender': 'Male',
#    'size': 'Large',
#    'coat': None,
#    'attributes': {'spayed_neutered': True,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'BLITZ',
#    'description': 'Meet Blitz! Shelter staff say he is easy to handle and hes easy on the eyes too! Hes quite a...',
#    'organization_animal_id': 'A1049147',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397945/1/?bust=1673322597&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397945/1/?bust=1673322597&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59
width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397860/1/?bust=1673322136'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397860/1/?bust=1673322136&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397860/1/?bust=1673322136&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397860/1/?bust=1673322136&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397860/1/?bust=1673322136'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:31:58+0000',
#    'published_at': '2023-01-10T03:31:56+0000',
#    'distance': None,
#    'contact': {'email': 'larashouse2021@gmail.com',
#     'phone': '(254) 292-9552',
#     'address': {'address1': '1517 Hwy 171 N',
#      'address2': 'P.O. BOX 1568',
#      'city': 'Mexia',
#      'state': 'TX',
#      'postcode': '76667',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397860'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1275'}}},
#   {'id': 59397859,
#    'organization_id': 'TX1275',
#    'url': 'https://www.petfinder.com/dog/toby-59397859/tx/mexia/laras-house-tx1275/?referrer_id=76e1c2be-b77d-4d4c-a604-76e8c8523327',
#    'type': 'Dog',
#    'species': 'Dog',
#    'breeds': {'primary': 'Mixed Breed',
#     'secondary': None,
#     'mixed': False,
#     'unknown': False},
#    'colors': {'primary': 'Black', 'secondary': None, 'tertiary': None},
#    'age': 'Young',
#    'gender': 'Male',
#    'size': 'Small',
#    'coat': None,
#    'attributes': {'spayed_neutered': False,
#     'house_trained': False,
#     'declawed': None,
#     'special_needs': False,
#     'shots_current': False},
#    'environment': {'children': None, 'dogs': None, 'cats': None},
#    'tags': [],
#    'name': 'Toby',
#    'description': None,
#    'organization_animal_id': '56850',
#    'photos': [{'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124'},
#     {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/2/?bust=1673322124&width=100',
#      'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/2/?bust=1673322124&width=300',
#      'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/2/?bust=1673322124&width=600',
#      'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/2/?bust=1673322124'}],
#    'primary_photo_cropped': {'small': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124&width=300',
#     'medium': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124&width=450',
#     'large': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124&width=600',
#     'full': 'https://dl5zpyw5k3jeb.cloudfront.net/photos/pets/59397859/1/?bust=1673322124'},
#    'videos': [],
#    'status': 'adoptable',
#    'status_changed_at': '2023-01-10T03:31:58+0000',
#    'published_at': '2023-01-10T03:31:56+0000',
#    'distance': None,
#    'contact': {'email': 'larashouse2021@gmail.com',
#     'phone': '(254) 292-9552',
#     'address': {'address1': '1517 Hwy 171 N',
#      'address2': 'P.O. BOX 1568',
#      'city': 'Mexia',
#      'state': 'TX',
#      'postcode': '76667',
#      'country': 'US'}},
#    '_links': {'self': {'href': '/v2/animals/59397859'},
#     'type': {'href': '/v2/types/dog'},
#     'organization': {'href': '/v2/organizations/tx1275'}}}],
#  'pagination': {'count_per_page': 100,
#   'total_count': 252404,
#   'current_page': 4,
#   'total_pages': 2525,
#   '_links': {'previous': {'href': '/v2/animals?limit=100&page=3'},
#    'next': {'href': '/v2/animals?limit=100&page=5'}}}}

# %%
response.keys()
# Out:
# dict_keys(['animals', 'pagination'])

# %%
df = pd.DataFrame(response['animals'])

# %%
# Breaking out the primary,secondary and mixed (T/F) breeds from the tuple in df column 'breeds'
primary_breeds_dict = {}
primary_breeds = []
secondary_breeds_dict = {}
secondary_breeds = []
mixed_breeds_dict = {}
mixed_breeds = []

for x,y in zip(df['breeds'],df['id']):
#     print(x,y)
    primary_breeds_dict = {'id':y}
    secondary_breeds_dict = {'id':y}
    mixed_breeds_dict = {'id':y}
    if 'primary' in x:
        primary_breeds_dict['primary'] =x['primary']
#         print(primary_breeds_dict)
        primary_breeds.append(primary_breeds_dict)
    if 'secondary' in x:
        secondary_breeds_dict['secondary'] =x['secondary']
        secondary_breeds.append(secondary_breeds_dict) 
    if 'mixed' in x:
        mixed_breeds_dict['mixed'] =x['mixed']
        mixed_breeds.append(mixed_breeds_dict) 
# print(breeds)
breed_1_df = pd.DataFrame(primary_breeds)
breed_2_df = pd.DataFrame(secondary_breeds)
breed_3_df = pd.DataFrame(mixed_breeds)

df_breeds_incorp = df.merge(breed_1_df,on='id').merge(breed_2_df,on='id').merge(breed_3_df,on='id')
# df_breeds_incorp.dtypes
df_breeds_incorp
# Out:
#           id organization_id  \
# 0   59397970           CA736
# 1   59397969          CA2509
# 2   59397968           VA600
# 3   59397967           MO769
# 4   59397966           IN719
# ..       ...             ...
# 95  59397861          TX2498
# 96  59397853           CA736
# 97  59397857          TX1275
# 98  59397860          TX1275
# 99  59397859          TX1275
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/smokey-59397970/...  Dog     Dog
# 1   https://www.petfinder.com/cat/espurr-59397969/...  Cat     Cat
# 2   https://www.petfinder.com/dog/virtue-v-pups-li...  Dog     Dog
# 3   https://www.petfinder.com/cat/olaf-59397967/mo...  Cat     Cat
# 4   https://www.petfinder.com/dog/bruno-59397966/i...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/dog/little-louie-593...  Dog     Dog
# 96  https://www.petfinder.com/dog/montana-59397853...  Dog     Dog
# 97  https://www.petfinder.com/dog/shiloh-59397857/...  Dog     Dog
# 98  https://www.petfinder.com/dog/maggie-59397860/...  Dog     Dog
# 99  https://www.petfinder.com/dog/toby-59397859/tx...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Pit Bull Terrier', 'secondary': N...
# 1   {'primary': 'Domestic Short Hair', 'secondary'...
# 2   {'primary': 'Labrador Retriever', 'secondary':...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'German Shepherd Dog', 'secondary'...
# ..                                                ...
# 95  {'primary': 'English Pointer', 'secondary': 'G...
# 96  {'primary': 'Husky', 'secondary': None, 'mixed...
# 97  {'primary': 'Pit Bull Terrier', 'secondary': '...
# 98  {'primary': 'Pit Bull Terrier', 'secondary': '...
# 99  {'primary': 'Mixed Breed', 'secondary': None, ...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Black', 'secondary': 'Brindle', '...  Adult    Male   Large
# 1   {'primary': 'Black', 'secondary': 'Orange / Re...  Young  Female   Small
# 2   {'primary': 'Golden', 'secondary': None, 'tert...   Baby    Male  Medium
# 3   {'primary': 'Tabby (Gray / Blue / Silver)', 's...   Baby    Male  Medium
# 4   {'primary': 'Sable', 'secondary': None, 'terti...  Young    Male   Large
# ..                                                ...    ...     ...     ...
# 95  {'primary': 'Black', 'secondary': 'White / Cre...  Young    Male  Medium
# 96  {'primary': 'Apricot / Beige', 'secondary': 'W...   Baby  Female  Medium
# 97  {'primary': 'Brindle', 'secondary': None, 'ter...  Adult  Female   Large
# 98  {'primary': 'Black', 'secondary': None, 'terti...  Young  Female  Medium
# 99  {'primary': 'Black', 'secondary': None, 'terti...  Young    Male   Small
#
#     ... videos     status         status_changed_at              published_at  \
# 0   ...     []  adoptable  2023-01-10T03:44:32+0000  2023-01-10T03:44:31+0000
# 1   ...     []  adoptable  2023-01-10T03:44:13+0000  2023-01-10T03:44:12+0000
# 2   ...     []  adoptable  2023-01-10T03:43:33+0000  2023-01-10T03:43:32+0000
# 3   ...     []  adoptable  2023-01-10T03:43:20+0000  2023-01-10T03:43:18+0000
# 4   ...     []  adoptable  2023-01-10T03:43:03+0000  2023-01-10T03:43:02+0000
# ..  ...    ...        ...                       ...                       ...
# 95  ...     []  adoptable  2023-01-10T03:32:46+0000  2023-01-10T03:32:45+0000
# 96  ...     []  adoptable  2023-01-10T03:31:57+0000  2023-01-10T03:31:56+0000
# 97  ...     []  adoptable  2023-01-10T03:31:57+0000  2023-01-10T03:31:56+0000
# 98  ...     []  adoptable  2023-01-10T03:31:58+0000  2023-01-10T03:31:56+0000
# 99  ...     []  adoptable  2023-01-10T03:31:58+0000  2023-01-10T03:31:56+0000
#
#    distance                                            contact  \
# 0      None  {'email': 'vschomburg@nbpd.org', 'phone': '(94...
# 1      None  {'email': 'adoptions@sspca.org', 'phone': '(91...
# 2      None  {'email': 'adopt@ophrescue.org', 'phone': None...
# 3      None  {'email': 'ittybittykittycitymissouri@gmail.co...
# 4      None  {'email': 'hswcadopt@gmail.com', 'phone': '(81...
# ..      ...                                                ...
# 95     None  {'email': 'luckytailsinc@gmail.com', 'phone': ...
# 96     None  {'email': 'vschomburg@nbpd.org', 'phone': '(94...
# 97     None  {'email': 'larashouse2021@gmail.com', 'phone':...
# 98     None  {'email': 'larashouse2021@gmail.com', 'phone':...
# 99     None  {'email': 'larashouse2021@gmail.com', 'phone':...
#
#                                                _links              primary  \
# 0   {'self': {'href': '/v2/animals/59397970'}, 'ty...     Pit Bull Terrier
# 1   {'self': {'href': '/v2/animals/59397969'}, 'ty...  Domestic Short Hair
# 2   {'self': {'href': '/v2/animals/59397968'}, 'ty...   Labrador Retriever
# 3   {'self': {'href': '/v2/animals/59397967'}, 'ty...  Domestic Short Hair
# 4   {'self': {'href': '/v2/animals/59397966'}, 'ty...  German Shepherd Dog
# ..                                                ...                  ...
# 95  {'self': {'href': '/v2/animals/59397861'}, 'ty...      English Pointer
# 96  {'self': {'href': '/v2/animals/59397853'}, 'ty...                Husky
# 97  {'self': {'href': '/v2/animals/59397857'}, 'ty...     Pit Bull Terrier
# 98  {'self': {'href': '/v2/animals/59397860'}, 'ty...     Pit Bull Terrier
# 99  {'self': {'href': '/v2/animals/59397859'}, 'ty...          Mixed Breed
#
#                          secondary  mixed
# 0                             None   True
# 1                             None   True
# 2                             None   True
# 3               American Shorthair   True
# 4                             None  False
# ..                             ...    ...
# 95      German Shorthaired Pointer   True
# 96                            None  False
# 97  American Staffordshire Terrier   True
# 98              Labrador Retriever   True
# 99                            None  False
#
# [100 rows x 29 columns]

# %%
# Breaking out the address from the contact info nested dict into a dataframe and joining to breeds
address1_dict = {}

address_df = pd.DataFrame()

for x,y in zip(df['contact'],df['id']):
#     print(x,y)
    address1_dict = {'id':y}
    if 'address' in x:
        address1_dict['address'] =x['address']
#         print(address1_dict)
        test_df = pd.DataFrame(pd.json_normalize(address1_dict))
        address_df = address_df.append(test_df)
address_df.dtypes
address_and_breeds_df = df_breeds_incorp.merge(address_df,left_on='id',right_on='id')

# Most current df with relevant data
address_and_breeds_df
# Out:
#           id organization_id  \
# 0   59397970           CA736
# 1   59397969          CA2509
# 2   59397968           VA600
# 3   59397967           MO769
# 4   59397966           IN719
# ..       ...             ...
# 95  59397861          TX2498
# 96  59397853           CA736
# 97  59397857          TX1275
# 98  59397860          TX1275
# 99  59397859          TX1275
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/smokey-59397970/...  Dog     Dog
# 1   https://www.petfinder.com/cat/espurr-59397969/...  Cat     Cat
# 2   https://www.petfinder.com/dog/virtue-v-pups-li...  Dog     Dog
# 3   https://www.petfinder.com/cat/olaf-59397967/mo...  Cat     Cat
# 4   https://www.petfinder.com/dog/bruno-59397966/i...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/dog/little-louie-593...  Dog     Dog
# 96  https://www.petfinder.com/dog/montana-59397853...  Dog     Dog
# 97  https://www.petfinder.com/dog/shiloh-59397857/...  Dog     Dog
# 98  https://www.petfinder.com/dog/maggie-59397860/...  Dog     Dog
# 99  https://www.petfinder.com/dog/toby-59397859/tx...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Pit Bull Terrier', 'secondary': N...
# 1   {'primary': 'Domestic Short Hair', 'secondary'...
# 2   {'primary': 'Labrador Retriever', 'secondary':...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'German Shepherd Dog', 'secondary'...
# ..                                                ...
# 95  {'primary': 'English Pointer', 'secondary': 'G...
# 96  {'primary': 'Husky', 'secondary': None, 'mixed...
# 97  {'primary': 'Pit Bull Terrier', 'secondary': '...
# 98  {'primary': 'Pit Bull Terrier', 'secondary': '...
# 99  {'primary': 'Mixed Breed', 'secondary': None, ...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Black', 'secondary': 'Brindle', '...  Adult    Male   Large
# 1   {'primary': 'Black', 'secondary': 'Orange / Re...  Young  Female   Small
# 2   {'primary': 'Golden', 'secondary': None, 'tert...   Baby    Male  Medium
# 3   {'primary': 'Tabby (Gray / Blue / Silver)', 's...   Baby    Male  Medium
# 4   {'primary': 'Sable', 'secondary': None, 'terti...  Young    Male   Large
# ..                                                ...    ...     ...     ...
# 95  {'primary': 'Black', 'secondary': 'White / Cre...  Young    Male  Medium
# 96  {'primary': 'Apricot / Beige', 'secondary': 'W...   Baby  Female  Medium
# 97  {'primary': 'Brindle', 'secondary': None, 'ter...  Adult  Female   Large
# 98  {'primary': 'Black', 'secondary': None, 'terti...  Young  Female  Medium
# 99  {'primary': 'Black', 'secondary': None, 'terti...  Young    Male   Small
#
#     ...                                             _links  \
# 0   ...  {'self': {'href': '/v2/animals/59397970'}, 'ty...
# 1   ...  {'self': {'href': '/v2/animals/59397969'}, 'ty...
# 2   ...  {'self': {'href': '/v2/animals/59397968'}, 'ty...
# 3   ...  {'self': {'href': '/v2/animals/59397967'}, 'ty...
# 4   ...  {'self': {'href': '/v2/animals/59397966'}, 'ty...
# ..  ...                                                ...
# 95  ...  {'self': {'href': '/v2/animals/59397861'}, 'ty...
# 96  ...  {'self': {'href': '/v2/animals/59397853'}, 'ty...
# 97  ...  {'self': {'href': '/v2/animals/59397857'}, 'ty...
# 98  ...  {'self': {'href': '/v2/animals/59397860'}, 'ty...
# 99  ...  {'self': {'href': '/v2/animals/59397859'}, 'ty...
#
#                 primary                       secondary  mixed  \
# 0      Pit Bull Terrier                            None   True
# 1   Domestic Short Hair                            None   True
# 2    Labrador Retriever                            None   True
# 3   Domestic Short Hair              American Shorthair   True
# 4   German Shepherd Dog                            None  False
# ..                  ...                             ...    ...
# 95      English Pointer      German Shorthaired Pointer   True
# 96                Husky                            None  False
# 97     Pit Bull Terrier  American Staffordshire Terrier   True
# 98     Pit Bull Terrier              Labrador Retriever   True
# 99          Mixed Breed                            None  False
#
#       address.address1 address.address2   address.city address.state  \
# 0   20302 Riverside Dr             None  Newport Beach            CA
# 1                 None             None     Sacramento            CA
# 2               Rescue             None        Fairfax            VA
# 3           2791 Hwy Y             None      Ellington            MO
# 4                 None             None          Salem            IN
# ..                 ...              ...            ...           ...
# 95                None             None       seabrook            NH
# 96  20302 Riverside Dr             None  Newport Beach            CA
# 97      1517 Hwy 171 N    P.O. BOX 1568          Mexia            TX
# 98      1517 Hwy 171 N    P.O. BOX 1568          Mexia            TX
# 99      1517 Hwy 171 N    P.O. BOX 1568          Mexia            TX
#
#    address.postcode address.country
# 0             92660              US
# 1             95828              US
# 2             22032              US
# 3             63638              US
# 4             47167              US
# ..              ...             ...
# 95            03874              US
# 96            92660              US
# 97            76667              US
# 98            76667              US
# 99            76667              US
#
# [100 rows x 35 columns]

# %%
photo_dict = []
photo_df = pd.DataFrame()
test = {}
for x,y in zip(df['photos'],df['id']):
#     print(x,y)
    photo_dict = {'id':y,'photos':x}
    pd.json_normalize(photo_dict)
#     print(photo_dict)
    for i in photo_dict['photos']:
        temp_photo_dict = {'id':y,'small_photo': i['small'],'medium_photo': i['medium'],'large_photo': i['large']}
#         print(test)
        df_photos = pd.DataFrame(pd.json_normalize(temp_photo_dict))
        photo_df = photo_df.append(df_photos)
photo_df
photo_df = photo_df.groupby(['id'],sort=True).max()

# merging the breeds and address df to the photos df - this is the final cleaned df
cleaned_pet_df = address_and_breeds_df.merge(photo_df,how='left',left_on='id',right_on='id')
cleaned_pet_df
# Out:
#           id organization_id  \
# 0   59397970           CA736
# 1   59397969          CA2509
# 2   59397968           VA600
# 3   59397967           MO769
# 4   59397966           IN719
# ..       ...             ...
# 95  59397861          TX2498
# 96  59397853           CA736
# 97  59397857          TX1275
# 98  59397860          TX1275
# 99  59397859          TX1275
#
#                                                   url type species  \
# 0   https://www.petfinder.com/dog/smokey-59397970/...  Dog     Dog
# 1   https://www.petfinder.com/cat/espurr-59397969/...  Cat     Cat
# 2   https://www.petfinder.com/dog/virtue-v-pups-li...  Dog     Dog
# 3   https://www.petfinder.com/cat/olaf-59397967/mo...  Cat     Cat
# 4   https://www.petfinder.com/dog/bruno-59397966/i...  Dog     Dog
# ..                                                ...  ...     ...
# 95  https://www.petfinder.com/dog/little-louie-593...  Dog     Dog
# 96  https://www.petfinder.com/dog/montana-59397853...  Dog     Dog
# 97  https://www.petfinder.com/dog/shiloh-59397857/...  Dog     Dog
# 98  https://www.petfinder.com/dog/maggie-59397860/...  Dog     Dog
# 99  https://www.petfinder.com/dog/toby-59397859/tx...  Dog     Dog
#
#                                                breeds  \
# 0   {'primary': 'Pit Bull Terrier', 'secondary': N...
# 1   {'primary': 'Domestic Short Hair', 'secondary'...
# 2   {'primary': 'Labrador Retriever', 'secondary':...
# 3   {'primary': 'Domestic Short Hair', 'secondary'...
# 4   {'primary': 'German Shepherd Dog', 'secondary'...
# ..                                                ...
# 95  {'primary': 'English Pointer', 'secondary': 'G...
# 96  {'primary': 'Husky', 'secondary': None, 'mixed...
# 97  {'primary': 'Pit Bull Terrier', 'secondary': '...
# 98  {'primary': 'Pit Bull Terrier', 'secondary': '...
# 99  {'primary': 'Mixed Breed', 'secondary': None, ...
#
#                                                colors    age  gender    size  \
# 0   {'primary': 'Black', 'secondary': 'Brindle', '...  Adult    Male   Large
# 1   {'primary': 'Black', 'secondary': 'Orange / Re...  Young  Female   Small
# 2   {'primary': 'Golden', 'secondary': None, 'tert...   Baby    Male  Medium
# 3   {'primary': 'Tabby (Gray / Blue / Silver)', 's...   Baby    Male  Medium
# 4   {'primary': 'Sable', 'secondary': None, 'terti...  Young    Male   Large
# ..                                                ...    ...     ...     ...
# 95  {'primary': 'Black', 'secondary': 'White / Cre...  Young    Male  Medium
# 96  {'primary': 'Apricot / Beige', 'secondary': 'W...   Baby  Female  Medium
# 97  {'primary': 'Brindle', 'secondary': None, 'ter...  Adult  Female   Large
# 98  {'primary': 'Black', 'secondary': None, 'terti...  Young  Female  Medium
# 99  {'primary': 'Black', 'secondary': None, 'terti...  Young    Male   Small
#
#     ...  mixed    address.address1 address.address2   address.city  \
# 0   ...   True  20302 Riverside Dr             None  Newport Beach
# 1   ...   True                None             None     Sacramento
# 2   ...   True              Rescue             None        Fairfax
# 3   ...   True          2791 Hwy Y             None      Ellington
# 4   ...  False                None             None          Salem
# ..  ...    ...                 ...              ...            ...
# 95  ...   True                None             None       seabrook
# 96  ...  False  20302 Riverside Dr             None  Newport Beach
# 97  ...   True      1517 Hwy 171 N    P.O. BOX 1568          Mexia
# 98  ...   True      1517 Hwy 171 N    P.O. BOX 1568          Mexia
# 99  ...  False      1517 Hwy 171 N    P.O. BOX 1568          Mexia
#
#    address.state address.postcode address.country  \
# 0             CA            92660              US
# 1             CA            95828              US
# 2             VA            22032              US
# 3             MO            63638              US
# 4             IN            47167              US
# ..           ...              ...             ...
# 95            NH            03874              US
# 96            CA            92660              US
# 97            TX            76667              US
# 98            TX            76667              US
# 99            TX            76667              US
#
#                                           small_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97                                                NaN
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                          medium_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97                                                NaN
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                           large_photo
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97                                                NaN
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
# [100 rows x 38 columns]

# %%
# Cleaning the final DF to only the data we need
cleaned_pet_df.head()
cleaned_pet_df.dtypes
cleaned_pet_df = cleaned_pet_df.rename(columns={'address.address1':'address1',"address.address2":"address2",'address.city':"city",
                              "address.state":'state',"address.postcode":"zip","address.country":"country"
                              })
cleaned_pet_df = cleaned_pet_df[['id','url','age','gender','name','description','status','status_changed_at'
                                ,'published_at','primary','secondary','mixed','address1','address2','city','state',
                                 'zip','country','small_photo','medium_photo','large_photo'
                                ]]
cleaned_pet_df
# Out:
#           id                                                url    age  \
# 0   59397970  https://www.petfinder.com/dog/smokey-59397970/...  Adult
# 1   59397969  https://www.petfinder.com/cat/espurr-59397969/...  Young
# 2   59397968  https://www.petfinder.com/dog/virtue-v-pups-li...   Baby
# 3   59397967  https://www.petfinder.com/cat/olaf-59397967/mo...   Baby
# 4   59397966  https://www.petfinder.com/dog/bruno-59397966/i...  Young
# ..       ...                                                ...    ...
# 95  59397861  https://www.petfinder.com/dog/little-louie-593...  Young
# 96  59397853  https://www.petfinder.com/dog/montana-59397853...   Baby
# 97  59397857  https://www.petfinder.com/dog/shiloh-59397857/...  Adult
# 98  59397860  https://www.petfinder.com/dog/maggie-59397860/...  Young
# 99  59397859  https://www.petfinder.com/dog/toby-59397859/tx...  Young
#
#     gender                    name  \
# 0     Male                  Smokey
# 1   Female                  Espurr
# 2     Male  Virtue (V Pups Litter)
# 3     Male                    Olaf
# 4     Male                  Bruno
# ..     ...                     ...
# 95    Male            Little Louie
# 96  Female                 Montana
# 97  Female                  Shiloh
# 98  Female                  Maggie
# 99    Male                    Toby
#
#                                           description     status  \
# 0                                                None  adoptable
# 1   Espurr is a 1 year old and 6 pound cat who is ...  adoptable
# 2   ADOPT ME ONLINE: https://ophrescue.org/dogs/12...  adoptable
# 3   Meet Olaf! He loves warm hugs.  He was rescued...  adoptable
# 4   Bruno was born in March 2022. He is good with ...  adoptable
# ..                                                ...        ...
# 95  Little Louis is a sweet boy. He likes to play....  adoptable
# 96                        Fun, playful  Super Fun dog  adoptable
# 97                                               None  adoptable
# 98                                               None  adoptable
# 99                                               None  adoptable
#
#            status_changed_at              published_at              primary  \
# 0   2023-01-10T03:44:32+0000  2023-01-10T03:44:31+0000     Pit Bull Terrier
# 1   2023-01-10T03:44:13+0000  2023-01-10T03:44:12+0000  Domestic Short Hair
# 2   2023-01-10T03:43:33+0000  2023-01-10T03:43:32+0000   Labrador Retriever
# 3   2023-01-10T03:43:20+0000  2023-01-10T03:43:18+0000  Domestic Short Hair
# 4   2023-01-10T03:43:03+0000  2023-01-10T03:43:02+0000  German Shepherd Dog
# ..                       ...                       ...                  ...
# 95  2023-01-10T03:32:46+0000  2023-01-10T03:32:45+0000      English Pointer
# 96  2023-01-10T03:31:57+0000  2023-01-10T03:31:56+0000                Husky
# 97  2023-01-10T03:31:57+0000  2023-01-10T03:31:56+0000     Pit Bull Terrier
# 98  2023-01-10T03:31:58+0000  2023-01-10T03:31:56+0000     Pit Bull Terrier
# 99  2023-01-10T03:31:58+0000  2023-01-10T03:31:56+0000          Mixed Breed
#
#     ...  mixed            address1       address2           city state    zip  \
# 0   ...   True  20302 Riverside Dr           None  Newport Beach    CA  92660
# 1   ...   True                None           None     Sacramento    CA  95828
# 2   ...   True              Rescue           None        Fairfax    VA  22032
# 3   ...   True          2791 Hwy Y           None      Ellington    MO  63638
# 4   ...  False                None           None          Salem    IN  47167
# ..  ...    ...                 ...            ...            ...   ...    ...
# 95  ...   True                None           None       seabrook    NH  03874
# 96  ...  False  20302 Riverside Dr           None  Newport Beach    CA  92660
# 97  ...   True      1517 Hwy 171 N  P.O. BOX 1568          Mexia    TX  76667
# 98  ...   True      1517 Hwy 171 N  P.O. BOX 1568          Mexia    TX  76667
# 99  ...  False      1517 Hwy 171 N  P.O. BOX 1568          Mexia    TX  76667
#
#    country                                        small_photo  \
# 0       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4       US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..     ...                                                ...
# 95      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97      US                                                NaN
# 98      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99      US  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                          medium_photo  \
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97                                                NaN
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
#                                           large_photo
# 0   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 1   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 2   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 3   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 4   https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# ..                                                ...
# 95  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 96  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 97                                                NaN
# 98  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
# 99  https://dl5zpyw5k3jeb.cloudfront.net/photos/pe...
#
# [100 rows x 21 columns]

# %% [markdown]
# # Establishing a Connection to SQL for Data Organization

# %%
#Establish a connection to SQL: 
from sqlalchemy import create_engine

# Creating connection object
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5433
database_name = 'postgres'

# %%
#Create engine connection:
connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'

engine = create_engine(connection_string)

# %%
cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
engine.execute("SELECT name, age, gender, primary, city, state FROM adoptees ORDER BY state ASC").fetchall()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-82d729f7550f> in <module>
# ----> 1 cleaned_pet_df.to_sql(name='adoptees', con=engine, if_exists='replace', index=False)
#       2 engine.execute("SELECT name, age, gender, primary, city, state FROM adoptees ORDER BY state ASC").fetchall()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1747             Any additional kwargs are passed to the engine.
#    1748         """
# -> 1749         sql_engine = get_engine(engine)
#    1750
#    1751         table = self.prep_table(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in get_engine(engine)
#    1368
#    1369         raise ImportError(
# -> 1370             "Unable to find a usable engine; "
#    1371             "tried using: 'sqlalchemy'.\n"
#    1372             "A suitable version of "
#
# ImportError: Unable to find a usable engine; tried using: 'sqlalchemy'.
# A suitable version of sqlalchemy is required for sql I/O support.
# Trying to import the above resulted in these errors:
#  - Pandas requires version '1.3.0' or newer of 'sqlalchemy' (version '1.2.15' currently installed).
